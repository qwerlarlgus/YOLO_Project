# %% [markdown]
# <a href="https://colab.research.google.com/github/qwerlarlgus/YOLO_Project/blob/main/Parking_lot_YOLOv5%5B0%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Train YOLOv5 on Custom Objects
#
# This tutorial is based on the [YOLOv5 repository](https://github.com/ultralytics/yolov5) by [Ultralytics](https://www.ultralytics.com/). This notebook shows training on **your own custom objects**. Many thanks to Ultralytics for putting this repository together - we hope that in combination with clean data management tools at Roboflow, this technologoy will become easily accessible to any developer wishing to use computer vision in their projects.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train YOLOv5](https://blog.roboflow.ai/how-to-train-yolov5-on-a-custom-dataset/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train YOLOv5 on your custom objects. We use a [public blood cell detection dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our detector we take the following steps:
#
# * Install YOLOv5 dependencies
# * Download custom YOLOv5 object detection data
# * Write our YOLOv5 Training configuration
# * Run YOLOv5 training
# * Evaluate YOLOv5 performance
# * Visualize YOLOv5 training data
# * Run YOLOv5 inference on test images
# * Export saved YOLOv5 weights for future inference
#
#
#
# ### **About**
#
# [Roboflow](https://roboflow.com) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# **Looking for a vision model available via API without hassle? Try Roboflow Train.**
#
# ![Roboflow Wordmark](https://i.imgur.com/dcLNMhV.png)

# %% [markdown]
# #Install Dependencies
#
# _(Remember to choose GPU in Runtime if not already selected. Runtime --> Change Runtime Type --> Hardware accelerator --> GPU)_

# %%
# !curl -L "https://public.roboflow.com/ds/QlrpazCAUF?key=p0fiPChE9L" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: train/labels/2013-04-16_07_45_02_jpg.rf.e428ec70fb7e2a848817466c725bcb04.txt
#  extracting: train/labels/2013-04-16_07_55_02_jpg.rf.a6624571b2833dc996fce24b98eac1fc.txt
#  extracting: train/labels/2013-04-16_08_00_02_jpg.rf.b4b059ed577a72101d500dc8285d8d30.txt
#  extracting: train/labels/2013-04-16_08_05_02_jpg.rf.891be3b531b85840ee7af9d5cb4a467a.txt
#  extracting: train/labels/2013-04-16_08_10_02_jpg.rf.ed972f4caf46e296305c834938b09e7d.txt
#  extracting: train/labels/2013-04-16_08_15_02_jpg.rf.a45f2ababd324f6a461eab73fd61e5fc.txt
#  extracting: train/labels/2013-04-16_08_20_02_jpg.rf.35409a67291d756343c31cac3bc3e0e0.txt
#  extracting: train/labels/2013-04-16_08_25_02_jpg.rf.68ee10dba825ec434be0c3c1efcfdceb.txt
#  extracting: train/labels/2013-04-16_08_30_02_jpg.rf.d1ac2036f74f2acd0f57f1e89b41576a.txt
#  extracting: train/labels/2013-04-16_08_35_02_jpg.rf.5e7ed9679d1245b51788cdfee9dda708.txt
#  extracting: train/labels/2013-04-16_08_40_03_jpg.rf.ff970f902ddac0ddbf3beabddc4fc7d0.txt
#  extracting: train/labels/2013-04-16_08_50_03_jpg.rf.4970d0f821e5dba617fbf99c32c1c698.txt
#  extracting: train/labels/2013-04-16_08_55_03_jpg.rf.b40a934e38ffa5de2e9e98c3dc7680ec.txt
#  extracting: train/labels/2013-04-16_09_00_03_jpg.rf.a4ba97b39e63b6bde95b004946bf1b4e.txt
#  extracting: train/labels/2013-04-16_09_05_03_jpg.rf.d164bef1bc534464b6f0ec463f304e9a.txt
#  extracting: train/labels/2013-04-16_09_10_03_jpg.rf.7db5a114ccfae822d1383859b23e980d.txt
#  extracting: train/labels/2013-04-16_09_15_03_jpg.rf.2841c105214151dd698e049fa8b20603.txt
#  extracting: train/labels/2013-04-16_09_20_03_jpg.rf.248cfeeb1c8dcba55005234a1f083f0a.txt
#  extracting: train/labels/2013-04-16_09_25_03_jpg.rf.aee919def5c7a54ab2eebe3b75856a39.txt
#  extracting: train/labels/2013-04-16_09_30_03_jpg.rf.ef95d10f4662f29a4fb7515d22402d96.txt
#  extracting: train/labels/2013-04-16_09_35_04_jpg.rf.dafc5cf766ec7ebed2b1b62753dea8f2.txt
#  extracting: train/labels/2013-04-16_09_40_04_jpg.rf.3a60f0fee4c8ba535daa45dc144ce211.txt
#  extracting: train/labels/2013-04-16_09_50_04_jpg.rf.fb6e9b1b02d883c7c39993dd5fb90dd0.txt
#  extracting: train/labels/2013-04-16_10_10_04_jpg.rf.269c62f61ecafc89427ab247d9eb260f.txt
#  extracting: train/labels/2013-04-16_10_15_04_jpg.rf.27f17d354cb4bcb1f10dbb886f277839.txt
#  extracting: train/labels/2013-04-16_10_25_04_jpg.rf.df4df85be1002787e9d0799f4a265c73.txt
#  extracting: train/labels/2013-04-16_10_30_05_jpg.rf.da1a752b6a0e016416d54b258fd2b74e.txt
#  extracting: train/labels/2013-04-16_10_35_05_jpg.rf.7c844923f1f3acf7ab0dee3793e47228.txt
#  extracting: train/labels/2013-04-16_10_40_05_jpg.rf.76d0f9b229a91463eafb1cd59027a281.txt
#  extracting: train/labels/2013-04-16_10_45_05_jpg.rf.5da911108efae4dfc90fce2c5620ac2c.txt
#  extracting: train/labels/2013-04-16_10_50_05_jpg.rf.68f9b50c97defe38440a0493f99d2a0b.txt
#    creating: valid/
#    creating: valid/images/
#  extracting: valid/images/2012-09-11_15_36_32_jpg.rf.b2b1767cafabff6378468d0d71c1ecd2.jpg
#  extracting: valid/images/2012-09-11_15_45_57_jpg.rf.01d1052a2938ca83e8bdb05e2f86c6b4.jpg
#  extracting: valid/images/2012-09-11_17_12_07_jpg.rf.e73a27714868ec27c08e1960bfa4130f.jpg
#  extracting: valid/images/2012-09-11_17_31_01_jpg.rf.2e04e95005bf92a48a74f0275087d0cb.jpg
#  extracting: valid/images/2012-09-11_17_35_44_jpg.rf.5663fefeb1afb80585d5245bf811b9e8.jpg
#  extracting: valid/images/2012-09-11_17_59_15_jpg.rf.29ca7e6dbc33db072c02399a0fa45b0c.jpg
#  extracting: valid/images/2012-09-11_18_03_58_jpg.rf.b9ac8b4e0bc746f70a759da8d7126f3d.jpg
#  extracting: valid/images/2012-09-11_18_08_41_jpg.rf.580b43c2b4db21e0f8c3bfc6cf81993f.jpg
#  extracting: valid/images/2012-09-12_06_26_11_jpg.rf.7ff1217fe3f62dcfe37be6ad7fd1a334.jpg
#  extracting: valid/images/2012-09-12_06_31_24_jpg.rf.11cca31cda632773940bb17f821a38ab.jpg
#  extracting: valid/images/2012-09-12_07_07_55_jpg.rf.689b63c9f15f53cf654de3f26335b9e1.jpg
#  extracting: valid/images/2012-09-12_07_13_08_jpg.rf.a995d10c6c6257053506c36359b4d682.jpg
#  extracting: valid/images/2012-09-12_07_18_22_jpg.rf.79ce4671b826968ea404225a994906d8.jpg
#  extracting: valid/images/2012-09-12_08_21_07_jpg.rf.2bfc45a77b65a2bf172b747bd40ba3d8.jpg
#  extracting: valid/images/2012-09-12_08_26_22_jpg.rf.fa2ee0e3bc124415a65327a4074e9b02.jpg
#  extracting: valid/images/2012-09-12_08_42_04_jpg.rf.a0fe7251e5ff9b25cc52ecffbf48419c.jpg
#  extracting: valid/images/2012-09-12_08_47_19_jpg.rf.14dc9d3f9af1070a6cb445fddc1d02f7.jpg
#  extracting: valid/images/2012-09-12_09_08_18_jpg.rf.170491e001f14f230acb53df8438af19.jpg
#  extracting: valid/images/2012-09-12_09_13_32_jpg.rf.50cfd804f8512af6e98b3841a75d6628.jpg
#  extracting: valid/images/2012-09-12_09_29_16_jpg.rf.2edcf60dad2c06e207a1941c56f51b79.jpg
#  extracting: valid/images/2012-09-12_09_44_59_jpg.rf.12796f9c9cc3b4b0de1f448aa8a216af.jpg
#  extracting: valid/images/2012-09-12_10_00_43_jpg.rf.87e2b8b66155acfb3d7f1ab25a092569.jpg
#  extracting: valid/images/2012-09-12_10_37_26_jpg.rf.570d349065a721e62d4f9c0bf23522ce.jpg
#  extracting: valid/images/2012-09-12_10_42_40_jpg.rf.ce0f0b8d575fd34b2c0aa045014dc222.jpg
#  extracting: valid/images/2012-09-12_10_47_54_jpg.rf.de5711e4c10e3d38a3385a96e27c49d4.jpg
#  extracting: valid/images/2012-09-12_10_58_24_jpg.rf.aff9469eef821efef1fac5428f59e866.jpg
#  extracting: valid/images/2012-09-12_11_03_39_jpg.rf.4d72addd3c32ee29448b1e29182f4dec.jpg
#  extracting: valid/images/2012-09-12_11_24_37_jpg.rf.09f2eaba56fd75d3ba2670ea645e3843.jpg
#  extracting: valid/images/2012-09-12_11_45_32_jpg.rf.e69b3556ea8745ccc45c045c5e375cc1.jpg
#  extracting: valid/images/2012-09-12_12_16_56_jpg.rf.63035c9fd47dc1422cfab65d6659dcf3.jpg
#  extracting: valid/images/2012-09-12_12_27_24_jpg.rf.30363cfc041688aee1b7735db184f41b.jpg
#  extracting: valid/images/2012-09-12_12_43_06_jpg.rf.c120394c44ef56dc4ac76a5911acd7c3.jpg
#  extracting: valid/images/2012-09-12_12_58_47_jpg.rf.ea1fbade61631e7c41d211d548615e74.jpg
#  extracting: valid/images/2012-09-12_14_06_53_jpg.rf.93a9223175367b62f39b39c83023193b.jpg
#  extracting: valid/images/2012-09-12_14_22_37_jpg.rf.fe839e823301e43e06b1948ca7af8628.jpg
#  extracting: valid/images/2012-09-12_14_27_51_jpg.rf.74e4e40102ba5b62c471b09b90e2eb8b.jpg
#  extracting: valid/images/2012-09-12_14_43_35_jpg.rf.ee895a8390ba7baa2b68a60040c7e762.jpg
#  extracting: valid/images/2012-09-12_14_59_18_jpg.rf.9cd825dace8214ec83c234f1ee8059dd.jpg
#  extracting: valid/images/2012-09-12_15_04_33_jpg.rf.1d68ff94ef1fa180c9ac34a03764b140.jpg
#  extracting: valid/images/2012-09-12_17_04_49_jpg.rf.387d84d18dfbbdd069dc3110f2159561.jpg
#  extracting: valid/images/2012-09-12_17_10_02_jpg.rf.c5987055afea0dbc6e9a50ce2680c265.jpg
#  extracting: valid/images/2012-09-12_17_30_55_jpg.rf.20e0e61085082c15fd788f18f38b9856.jpg
#  extracting: valid/images/2012-09-12_17_41_22_jpg.rf.ad6bc4f45feee5d215b9bee2deca62b7.jpg
#  extracting: valid/images/2012-09-13_07_18_15_jpg.rf.23f09c08bf066a2647279a3bc039a1fc.jpg
#  extracting: valid/images/2012-09-13_07_23_29_jpg.rf.7c131205bb18dd5d9e8a7c0ba67715f5.jpg
#  extracting: valid/images/2012-09-13_07_39_09_jpg.rf.2701370235fc1bd26d115fe3f14ab7d7.jpg
#  extracting: valid/images/2012-09-13_07_54_51_jpg.rf.535b616f65c0db00ce6ac33750aa1ba1.jpg
#  extracting: valid/images/2012-09-13_08_26_21_jpg.rf.1591f45d634e4c01036f2be3abda8c06.jpg
#  extracting: valid/images/2012-09-13_10_30_17_jpg.rf.b10b7b51807edff5dddcf930dec05e8a.jpg
#  extracting: valid/images/2012-09-13_10_50_18_jpg.rf.dc1afa323c4a719a3e0b8feb28a4f5c2.jpg
#  extracting: valid/images/2012-09-13_11_00_19_jpg.rf.425aa6e384d5b84d92e0fc99555d0b53.jpg
#  extracting: valid/images/2012-09-13_11_05_19_jpg.rf.565848532c88908a8e4c533faf7528e4.jpg
#  extracting: valid/images/2012-09-13_11_30_20_jpg.rf.6d857d85120b6a2a57251061964e60e3.jpg
#  extracting: valid/images/2012-09-13_11_55_21_jpg.rf.0bf1f67c2c3d3d896bd1d5a3c216f0c3.jpg
#  extracting: valid/images/2012-09-13_12_10_21_jpg.rf.f895d1dec9da37254df6b46575f19f19.jpg
#  extracting: valid/images/2012-09-13_13_50_25_jpg.rf.018134367f19adadc83de8772099790c.jpg
#  extracting: valid/images/2012-09-13_14_15_27_jpg.rf.67f72563c44baa8aecfa64afedc95401.jpg
#  extracting: valid/images/2012-09-13_14_20_27_jpg.rf.fb3699ab32bcda5a8af324fecebc8a6a.jpg
#  extracting: valid/images/2012-09-13_14_40_28_jpg.rf.27e4b06cce05b79a95517bc94bcf2ef3.jpg
#  extracting: valid/images/2012-09-13_14_45_28_jpg.rf.bd6ae58224a0446b8859c645e2982cb4.jpg
#  extracting: valid/images/2012-09-13_15_00_29_jpg.rf.b0213359878d572dc0ddddca908acca5.jpg
#  extracting: valid/images/2012-09-13_15_10_29_jpg.rf.a5d3cfcdd6679c86c9ffb043efd9a936.jpg
#  extracting: valid/images/2012-09-13_15_30_30_jpg.rf.0bc01104bed2b252ecb5040fd236892d.jpg
#  extracting: valid/images/2012-09-13_15_45_30_jpg.rf.11a6e9808ecf72cedf8b84de7a8d5f52.jpg
#  extracting: valid/images/2012-09-13_15_50_31_jpg.rf.5a11159a61b2a8fcd9e13ca9e347fb7f.jpg
#  extracting: valid/images/2012-09-13_16_45_33_jpg.rf.c8a9343d14d1d300910fbd365b9bb33c.jpg
#  extracting: valid/images/2012-09-13_17_35_35_jpg.rf.83b03fbd7550f1dddd26a8106c163988.jpg
#  extracting: valid/images/2012-09-14_09_01_10_jpg.rf.a03259374c746372a4698f81665b6e16.jpg
#  extracting: valid/images/2012-09-14_09_16_11_jpg.rf.51940a8c5e9e897af3467f26aba01292.jpg
#  extracting: valid/images/2012-09-14_09_26_11_jpg.rf.0ed7304f6f60c9898decc9c24feaffd7.jpg
#  extracting: valid/images/2012-09-14_09_51_12_jpg.rf.9e6d5d739c39462fef261fb2708ed9eb.jpg
#  extracting: valid/images/2012-09-14_10_51_15_jpg.rf.3662453edd84c4f40444dc00ce21a0ab.jpg
#  extracting: valid/images/2012-09-14_11_01_16_jpg.rf.8d799be5d87a92524a917c37f4b816c6.jpg
#  extracting: valid/images/2012-09-14_11_46_18_jpg.rf.ae5b21510f91820f09156a879d0d4772.jpg
#  extracting: valid/images/2012-09-14_12_21_19_jpg.rf.f9639f7acfb8b21b2c4d8d0af037885c.jpg
#  extracting: valid/images/2012-09-14_12_31_20_jpg.rf.9b8496394f67d657d8dd2dc1b270d916.jpg
#  extracting: valid/images/2012-09-14_13_11_21_jpg.rf.1b2b3f16c196aef6f34ae35927e088e3.jpg
#  extracting: valid/images/2012-09-14_13_36_22_jpg.rf.8469c07adf7202b123f6f5e52bd4fd74.jpg
#  extracting: valid/images/2012-09-14_14_26_24_jpg.rf.510203d05330ef72fe37cb9231e61045.jpg
#  extracting: valid/images/2012-09-14_15_01_25_jpg.rf.ac1e64d4e2fdf96fc2d9ff5f957b15d4.jpg
#  extracting: valid/images/2012-09-14_15_06_26_jpg.rf.c8ac6fb1929b6910cd1af3acd0a3bf44.jpg
#  extracting: valid/images/2012-09-14_15_21_26_jpg.rf.f8698c093627a43c1df40e24fda21cec.jpg
#  extracting: valid/images/2012-09-14_15_31_27_jpg.rf.02946e33a9c6f6a9ccd2d1959c79b7b8.jpg
#  extracting: valid/images/2012-09-14_16_21_28_jpg.rf.80027c85bdcd869690829629ec02ade6.jpg
#  extracting: valid/images/2012-09-14_16_31_29_jpg.rf.1ba9282ac9d690aecb778971d4ba9d2f.jpg
#  extracting: valid/images/2012-09-14_16_41_29_jpg.rf.6a5d5d38befc571bfc8560c2e2d2b523.jpg
#  extracting: valid/images/2012-09-14_16_46_29_jpg.rf.46be4f08d15a2735f2958d6212e8a101.jpg
#  extracting: valid/images/2012-09-14_16_51_30_jpg.rf.6d8919b25504c836b619e4e27ec8730b.jpg
#  extracting: valid/images/2012-09-14_17_01_30_jpg.rf.5e724ef296598a9747cb74201c24ddcc.jpg
#  extracting: valid/images/2012-09-14_17_21_31_jpg.rf.0216c72dda54cdca52a8c9ee37a31e5f.jpg
#  extracting: valid/images/2012-09-14_17_46_32_jpg.rf.cbaedc09d19e2bdffa756c2e8fa10d50.jpg
#  extracting: valid/images/2012-09-15_06_01_59_jpg.rf.dc9325332a3ba00625e3c69b6f47ea1d.jpg
#  extracting: valid/images/2012-09-15_06_37_01_jpg.rf.55c626e707c7e0b47233cc9c95ba9f64.jpg
#  extracting: valid/images/2012-09-15_07_32_03_jpg.rf.6476d7d045164b7c42ed25f511c304cb.jpg
#  extracting: valid/images/2012-09-15_07_37_03_jpg.rf.8bea694589a4d086c7c778f5971bc463.jpg
#  extracting: valid/images/2012-09-15_08_02_04_jpg.rf.cfdb1dc5fd413b907468316b0d503c92.jpg
#  extracting: valid/images/2012-09-15_08_12_04_jpg.rf.ececb0e6208f1cebc64501fff5fc10c5.jpg
#  extracting: valid/images/2012-09-15_08_17_04_jpg.rf.4f6c840b8855cc57de86f7bacc11b5eb.jpg
#  extracting: valid/images/2012-09-15_08_37_05_jpg.rf.708b2761dce3ba0152ff45f3427b7d90.jpg
#  extracting: valid/images/2012-09-15_09_37_08_jpg.rf.5a4dcccc262ce9206f4ba43bd60cbbf3.jpg
#  extracting: valid/images/2012-09-15_11_02_11_jpg.rf.aafed6421796d7c11b87279bdeee06d7.jpg
#  extracting: valid/images/2012-09-15_11_12_12_jpg.rf.26b3e8dfa41c9a65b1adc13f5f0d955f.jpg
#  extracting: valid/images/2012-09-15_11_27_12_jpg.rf.e9132e5c0caeb06ac489790b3069155c.jpg
#  extracting: valid/images/2012-09-15_11_37_13_jpg.rf.1c822888308269dbb5b95e7fbbe203a7.jpg
#  extracting: valid/images/2012-09-15_11_52_13_jpg.rf.60f2819ef704872a1f9628aba65473c0.jpg
#  extracting: valid/images/2012-09-15_12_57_16_jpg.rf.d9d5f6ec86628c6570712fdbc3c6312e.jpg
#  extracting: valid/images/2012-09-15_13_12_17_jpg.rf.ebffdedf419a31afc2d81d71c3e75ddc.jpg
#  extracting: valid/images/2012-09-15_13_47_18_jpg.rf.5653329e9aa58c7455eee2bbf3a78609.jpg
#  extracting: valid/images/2012-09-15_14_07_19_jpg.rf.4cc831b805e1b489583806c537af00be.jpg
#  extracting: valid/images/2012-09-15_14_12_19_jpg.rf.482c75ae085998be45bfe56a1beddc20.jpg
#  extracting: valid/images/2012-09-15_14_27_20_jpg.rf.32ff95f346c55a4b9bdf2e2342860383.jpg
#  extracting: valid/images/2012-09-15_14_42_20_jpg.rf.66cc328bcf83b16d3d113a235ebbe014.jpg
#  extracting: valid/images/2012-09-15_15_37_23_jpg.rf.c6d12f75ba0a2f2956b30dc484ca8646.jpg
#  extracting: valid/images/2012-09-15_15_52_23_jpg.rf.5a0b87ba2075574ac019b5820ece9bb0.jpg
#  extracting: valid/images/2012-09-15_16_12_24_jpg.rf.62cad6664ba98b5cc336481d266ee85b.jpg
#  extracting: valid/images/2012-09-15_16_32_25_jpg.rf.baa42d6b998390194fdffba5fa22de67.jpg
#  extracting: valid/images/2012-09-15_16_47_25_jpg.rf.33f8e194d8cb8bc042b23affcd8e84cf.jpg
#  extracting: valid/images/2012-09-15_17_52_28_jpg.rf.40361cb8c5d520d574f7d2d8f5968677.jpg
#  extracting: valid/images/2012-09-15_18_02_28_jpg.rf.f8240b0f2696fe78f4320bea0aa1dba8.jpg
#  extracting: valid/images/2012-09-15_18_12_29_jpg.rf.2e35a42351385b93d1b80a22401b7fd8.jpg
#  extracting: valid/images/2012-09-16_06_22_55_jpg.rf.ee4c08bfcc20248a536d12aa09def8b7.jpg
#  extracting: valid/images/2012-09-16_06_42_56_jpg.rf.d501e60c288100776e11466c3d65884a.jpg
#  extracting: valid/images/2012-09-16_07_27_57_jpg.rf.191717707b59b756b12b994598f437bd.jpg
#  extracting: valid/images/2012-09-16_07_37_58_jpg.rf.0b878e29417eec0557a97af0cda550fd.jpg
#  extracting: valid/images/2012-09-16_07_52_58_jpg.rf.e884103dc5246d4e9f0c616b760192ab.jpg
#  extracting: valid/images/2012-09-16_08_07_59_jpg.rf.d3fcf0a4f874a8b2e1bfc8e390f1600f.jpg
#  extracting: valid/images/2012-09-16_08_12_59_jpg.rf.1c7bb2d0244981621193e543be61e78d.jpg
#  extracting: valid/images/2012-09-16_08_23_00_jpg.rf.335b641b4971574b94f31fbf5f65c4f8.jpg
#  extracting: valid/images/2012-09-16_08_28_00_jpg.rf.bdc262221695797d20314351a740175c.jpg
#  extracting: valid/images/2012-09-16_08_43_00_jpg.rf.ecd2ff0db5e2c756a44f29d1fd979f42.jpg
#  extracting: valid/images/2012-09-16_08_53_01_jpg.rf.80dacb6d396bd5b698c3de4ac27a2139.jpg
#  extracting: valid/images/2012-09-16_08_58_01_jpg.rf.7bf70f8d04a0c852b773546d2e20317c.jpg
#  extracting: valid/images/2012-09-16_09_28_03_jpg.rf.f4d5f8acf6c401065dcf0eda7fe7427a.jpg
#  extracting: valid/images/2012-09-16_09_53_04_jpg.rf.225aa1ac9482ae76defc6b7029f3e791.jpg
#  extracting: valid/images/2012-09-16_11_08_07_jpg.rf.e559c7836b679dd48a8bc1456d4218e9.jpg
#  extracting: valid/images/2012-09-16_11_18_07_jpg.rf.6507d5d40d771f77b2f041f5b301d06c.jpg
#  extracting: valid/images/2012-09-16_11_28_08_jpg.rf.7a61d886ac30f125881451b192e7139e.jpg
#  extracting: valid/images/2012-09-16_11_43_08_jpg.rf.9aa187e0b0a3a558023fed49d6789451.jpg
#  extracting: valid/images/2012-09-16_11_48_08_jpg.rf.9be73e78157865029dbb54d87bbb0632.jpg
#  extracting: valid/images/2012-09-16_12_13_09_jpg.rf.7973168b67025a4a54ba5954cf95267b.jpg
#  extracting: valid/images/2012-09-16_12_58_11_jpg.rf.479af9d9f85e514768db72bb5b45ed2d.jpg
#  extracting: valid/images/2012-09-16_13_33_13_jpg.rf.df58345ea48b3c37a9b256fca1e28bfc.jpg
#  extracting: valid/images/2012-09-16_13_43_13_jpg.rf.eaab0bd2093e8ae8987026eb7dd4beab.jpg
#  extracting: valid/images/2012-09-16_13_48_13_jpg.rf.c5f7ee0fdca18e74a04057d20ce5b1a3.jpg
#  extracting: valid/images/2012-09-16_13_53_13_jpg.rf.c0d91fd029c81891fa267f7a67055568.jpg
#  extracting: valid/images/2012-09-16_14_13_14_jpg.rf.71cb073f5cb5831c46685b1300ab1e16.jpg
#  extracting: valid/images/2012-09-16_14_53_16_jpg.rf.ffa8f636509aa28af4f511f498fe6797.jpg
#  extracting: valid/images/2012-09-16_15_13_17_jpg.rf.c5d7527feabd3c31d7f91c7ddf91c8df.jpg
#  extracting: valid/images/2012-09-16_15_38_18_jpg.rf.273cc9be788d02d69036eb650124cdb6.jpg
#  extracting: valid/images/2012-09-16_15_48_18_jpg.rf.cf1a9cbde2e4486811dfe327c92f1625.jpg
#  extracting: valid/images/2012-09-16_16_08_19_jpg.rf.92fc34123454c8f13db177d7642d3228.jpg
#  extracting: valid/images/2012-09-16_16_28_19_jpg.rf.79977dfc1fba7e9956169c074831f4bc.jpg
#  extracting: valid/images/2012-09-16_16_38_20_jpg.rf.1289e7e0c2d6bdd1a6a2873a871dfc15.jpg
#  extracting: valid/images/2012-09-16_16_53_20_jpg.rf.6b46c14a15cd3f00a8f7814d9a3e33ce.jpg
#  extracting: valid/images/2012-09-16_17_03_21_jpg.rf.3d6aade6e79b2e1166eb363d807a4264.jpg
#  extracting: valid/images/2012-09-16_17_13_21_jpg.rf.1e61f44534fa95543879f055c69bf29a.jpg
#  extracting: valid/images/2012-09-16_17_33_22_jpg.rf.6539242c2c5ed22be35621d90475c894.jpg
#  extracting: valid/images/2012-09-17_06_13_49_jpg.rf.04173beae4de47638dfb55d83735314a.jpg
#  extracting: valid/images/2012-09-17_06_33_50_jpg.rf.4cd069e22458854b5b856a7cb08f4c13.jpg
#  extracting: valid/images/2012-09-17_06_43_50_jpg.rf.7e29a0ee1fb837aa1fa337158f73b945.jpg
#  extracting: valid/images/2012-09-17_07_03_51_jpg.rf.4c4e9ef251f7590dbadd2dc8956e598c.jpg
#  extracting: valid/images/2012-09-17_07_53_53_jpg.rf.2799823a1842febc07bc103e4af7ab98.jpg
#  extracting: valid/images/2012-09-17_08_08_54_jpg.rf.e12d013859a754ee37ecf26fd1ac948e.jpg
#  extracting: valid/images/2012-09-17_08_33_55_jpg.rf.0560fdee77ad95fbf0f4f8d61374b553.jpg
#  extracting: valid/images/2012-09-17_08_38_55_jpg.rf.14486457222e2395529db845d0e4573d.jpg
#  extracting: valid/images/2012-09-17_08_43_56_jpg.rf.0d89c8009363fa2823897bfe6e0843fd.jpg
#  extracting: valid/images/2012-09-17_08_53_56_jpg.rf.4d332bbb98249433400b72691f5345e5.jpg
#  extracting: valid/images/2012-09-17_09_03_56_jpg.rf.cb519667fd78ef7a835076b5d38056fb.jpg
#  extracting: valid/images/2012-09-17_09_38_58_jpg.rf.fe41369fcc70fdb33673b5295692a677.jpg
#  extracting: valid/images/2012-09-17_09_58_59_jpg.rf.cbd7bf252d08c21471040751e8a381a9.jpg
#  extracting: valid/images/2012-09-17_10_44_01_jpg.rf.6f7417595c979c3f4c40374e88baaef8.jpg
#  extracting: valid/images/2012-09-17_10_49_01_jpg.rf.7bdd54cf75702a14a600184276cc4202.jpg
#  extracting: valid/images/2012-09-17_11_09_02_jpg.rf.ff05f5936ccbc56786597697a9037ce7.jpg
#  extracting: valid/images/2012-09-17_11_34_04_jpg.rf.3fe06974918f82ab035676ec9ce886ab.jpg
#  extracting: valid/images/2012-09-17_11_59_05_jpg.rf.b0e96157d8934de3467e85b888006a35.jpg
#  extracting: valid/images/2012-09-17_12_54_07_jpg.rf.b9dc57e6835a563f34931ba7287fcb5e.jpg
#  extracting: valid/images/2012-09-17_13_19_08_jpg.rf.635bf4ccf76725b081e67a5005c791e4.jpg
#  extracting: valid/images/2012-09-17_13_29_09_jpg.rf.f3a036b0e464fa11fc93ce18b86ceff2.jpg
#  extracting: valid/images/2012-09-17_13_59_10_jpg.rf.b36fa9f37b6e79f2a3ca3751fb075376.jpg
#  extracting: valid/images/2012-09-17_14_24_11_jpg.rf.63304c351176227663633dc099299cc3.jpg
#  extracting: valid/images/2012-09-17_14_39_12_jpg.rf.4fa244d9940f91882a24249224fdae16.jpg
#  extracting: valid/images/2012-09-17_14_54_12_jpg.rf.4f5f03a1cb18c117d0e32ab90578b01c.jpg
#  extracting: valid/images/2012-09-17_15_29_14_jpg.rf.76bad945ab90501726bcf5a0a6380163.jpg
#  extracting: valid/images/2012-09-17_15_34_14_jpg.rf.0083f8b4c95fc5d1e1be260c41700150.jpg
#  extracting: valid/images/2012-09-17_16_04_15_jpg.rf.b576e9588da4982aa1abafa176265ad8.jpg
#  extracting: valid/images/2012-09-17_16_34_17_jpg.rf.ee27c3b4695ad8f331c09a7de49b008f.jpg
#  extracting: valid/images/2012-09-17_16_39_17_jpg.rf.84238f45fd4ef58a5eaeb43b5cd8cf63.jpg
#  extracting: valid/images/2012-09-17_16_49_17_jpg.rf.c40aee6ab046d011ac773ff33763a1db.jpg
#  extracting: valid/images/2012-09-17_17_14_18_jpg.rf.c83768d14fff9c267def0cad4f9d0cd3.jpg
#  extracting: valid/images/2012-09-17_17_34_19_jpg.rf.056e5435543847d8c4a956486a116e56.jpg
#  extracting: valid/images/2012-09-17_18_04_20_jpg.rf.b4f111c95716530655a9aedb194e8f67.jpg
#  extracting: valid/images/2012-09-18_06_14_48_jpg.rf.c786e3b9fcba8d0892c13ce81a08f774.jpg
#  extracting: valid/images/2012-09-18_06_49_49_jpg.rf.bc4ea19c51132a1b0cfcf6c0bb2746d7.jpg
#  extracting: valid/images/2012-09-18_07_04_50_jpg.rf.adda3cc7c3d87b37cedc3bdc49e4bf98.jpg
#  extracting: valid/images/2012-09-18_07_19_50_jpg.rf.866902b7d7f161cdb5a90121ed20a38a.jpg
#  extracting: valid/images/2012-09-18_07_39_51_jpg.rf.4392943feab744af0f3a1a1574a1f740.jpg
#  extracting: valid/images/2012-09-18_07_49_52_jpg.rf.c7313f3f7bc364a27af71c5af7df6ae1.jpg
#  extracting: valid/images/2012-09-18_07_59_52_jpg.rf.728fa709cd94b56cdf0cbe69a662da5e.jpg
#  extracting: valid/images/2012-09-18_08_09_53_jpg.rf.9d080fd71dfdd1bec9dce86bd9da73f4.jpg
#  extracting: valid/images/2012-09-18_08_34_54_jpg.rf.e6cb9a26d6124eee1fb1b5e6958659b5.jpg
#  extracting: valid/images/2012-09-18_08_44_54_jpg.rf.2d0db0c25ed2dd34c6c1f5957c1366a9.jpg
#  extracting: valid/images/2012-09-18_10_19_58_jpg.rf.f6ed472e4fc7e5ea9bc772259b7c9e07.jpg
#  extracting: valid/images/2012-09-18_10_34_59_jpg.rf.878b38abc404eb325c563b41df59bf19.jpg
#  extracting: valid/images/2012-09-18_11_30_02_jpg.rf.0ae929fbd855bf03200617f9cd1ee665.jpg
#  extracting: valid/images/2012-09-18_11_55_03_jpg.rf.1d0479653303efffa76d650ad231c5f5.jpg
#  extracting: valid/images/2012-09-18_12_00_03_jpg.rf.a9f319934b0d2e4cf240a36494055198.jpg
#  extracting: valid/images/2012-09-18_12_10_03_jpg.rf.142090b72a65ef909a324cbf0f71c329.jpg
#  extracting: valid/images/2012-09-18_12_25_04_jpg.rf.992fedff8a67750254e93d0d1e3a9f1d.jpg
#  extracting: valid/images/2012-09-18_13_05_06_jpg.rf.f4c76c845c7aeb58c3884ffe381903aa.jpg
#  extracting: valid/images/2012-09-18_13_45_08_jpg.rf.5f85fc4ff688286edfb17902e231affb.jpg
#  extracting: valid/images/2012-09-18_13_50_08_jpg.rf.5c79eb17a71bf5ee9e3ba56ac908f044.jpg
#  extracting: valid/images/2012-09-18_13_55_08_jpg.rf.b697f79338840d631328d77c1a260d85.jpg
#  extracting: valid/images/2012-09-18_14_40_10_jpg.rf.44170be899aeadc5dbcf34ddb54e0ad8.jpg
#  extracting: valid/images/2012-09-18_14_50_10_jpg.rf.458828500b0d402bb510212b6d053a48.jpg
#  extracting: valid/images/2012-09-18_15_20_12_jpg.rf.e97112b9c0dcfa02279250a21094d145.jpg
#  extracting: valid/images/2012-09-18_15_30_13_jpg.rf.bccae51ddf8aae02cca165902c32b6c6.jpg
#  extracting: valid/images/2012-09-18_15_40_13_jpg.rf.222e761452f65884dd23bc680381e8b3.jpg
#  extracting: valid/images/2012-09-18_15_50_13_jpg.rf.060e3617a7e86ad152ac42f8fee9498d.jpg
#  extracting: valid/images/2012-09-18_16_20_15_jpg.rf.f3dc15f4578c2755b665e507b78d2e95.jpg
#  extracting: valid/images/2012-09-18_17_25_18_jpg.rf.e38351f83287794ec05ed68648b6f533.jpg
#  extracting: valid/images/2012-09-18_17_55_19_jpg.rf.3d001898fa9392543f4ee6a7ff2b4079.jpg
#  extracting: valid/images/2012-09-19_06_20_48_jpg.rf.887246a54c1dc60e967dd8979dfe4c00.jpg
#  extracting: valid/images/2012-09-19_06_25_48_jpg.rf.7cfb580e9147387ebc9db92cfacb5b5d.jpg
#  extracting: valid/images/2012-09-19_06_55_50_jpg.rf.c91700439913709b1b8c40f333732f2c.jpg
#  extracting: valid/images/2012-09-19_07_20_51_jpg.rf.4ef28bba278c23e285a63a4a35bef7f6.jpg
#  extracting: valid/images/2012-09-19_09_23_25_jpg.rf.64fa860f75ef44e9abb82a4f5c126967.jpg
#  extracting: valid/images/2012-09-19_09_38_26_jpg.rf.c5f79a76825ddd7f1514fa3e826a52e4.jpg
#  extracting: valid/images/2012-09-19_09_58_27_jpg.rf.0db2f178f7f85875e8b91332f9f46783.jpg
#  extracting: valid/images/2012-09-19_11_18_31_jpg.rf.5ea187838e6b8aaccb433c61909066c5.jpg
#  extracting: valid/images/2012-09-19_11_28_31_jpg.rf.491b058236f59c4d6d006dc9821ae942.jpg
#  extracting: valid/images/2012-09-19_11_38_31_jpg.rf.1eda3b2fca10f6a7f5e77ce32111c882.jpg
#  extracting: valid/images/2012-09-19_12_08_32_jpg.rf.38877181d8cacdfc4a39bfa3ecd73bdd.jpg
#  extracting: valid/images/2012-09-19_12_33_34_jpg.rf.c24104d9fba74dc629729afed7d0b269.jpg
#  extracting: valid/images/2012-09-19_12_43_34_jpg.rf.d65bf63ed5fb8fd0b1e823271577f5c7.jpg
#  extracting: valid/images/2012-09-19_12_48_34_jpg.rf.f4f4a3ccd58a3afcdb8d086ec58ea660.jpg
#  extracting: valid/images/2012-09-19_13_08_35_jpg.rf.3ab30f1ba7aeec3f2dd49aee3d06e7b3.jpg
#  extracting: valid/images/2012-09-19_13_18_36_jpg.rf.f31134f9599d9dc36a074ccfa4b85a8c.jpg
#  extracting: valid/images/2012-09-19_13_28_36_jpg.rf.971276484127a8f159eabf958578595a.jpg
#  extracting: valid/images/2012-09-19_13_33_36_jpg.rf.52e1ba286fbfdc39fec343693d400664.jpg
#  extracting: valid/images/2012-09-19_13_53_37_jpg.rf.aa0bd5264fad61a55963c024952de084.jpg
#  extracting: valid/images/2012-09-19_14_28_39_jpg.rf.ce04c82d9a579ac6da349b00d32f23b2.jpg
#  extracting: valid/images/2012-09-19_14_48_39_jpg.rf.4181312f8998e40ea2cff413314faacb.jpg
#  extracting: valid/images/2012-09-19_15_03_40_jpg.rf.4e2aef9fab696e7cde1cb035dbe0fa10.jpg
#  extracting: valid/images/2012-09-19_15_13_40_jpg.rf.e45cf64f09d89a8b7ffa5804f662716d.jpg
#  extracting: valid/images/2012-09-19_15_43_42_jpg.rf.ab383108389745d6f6699cf9b069f45f.jpg
#  extracting: valid/images/2012-09-19_15_48_42_jpg.rf.d601d2951b0a333a9d6688a7c597f44a.jpg
#  extracting: valid/images/2012-09-19_16_53_44_jpg.rf.0f29904d4a38601c850565f5d162974f.jpg
#  extracting: valid/images/2012-09-19_17_58_47_jpg.rf.b919ab2d5691ff0860f43066c383d855.jpg
#  extracting: valid/images/2012-09-20_05_59_13_jpg.rf.516195316c977435f98dd77d55c40ec7.jpg
#  extracting: valid/images/2012-09-20_06_24_14_jpg.rf.0bc0a1fa3b9aa93f805c70612f5cc8cc.jpg
#  extracting: valid/images/2012-09-20_06_29_14_jpg.rf.db55fba541cbb06bb9c1ae2e196dc2d9.jpg
#  extracting: valid/images/2012-09-20_06_49_15_jpg.rf.27071c33c45937748e647bba32c1413f.jpg
#  extracting: valid/images/2012-09-20_06_59_16_jpg.rf.33b478e4edeb57844dca6938d7362bf5.jpg
#  extracting: valid/images/2012-09-20_07_19_16_jpg.rf.fd9dd2ac2e4670981bf257ec64a6ece6.jpg
#  extracting: valid/images/2012-09-20_07_24_17_jpg.rf.84b178c5322692ed6943c42725d9136b.jpg
#  extracting: valid/images/2012-09-20_08_04_18_jpg.rf.0d3e17f2546faf2560219d865c2b414e.jpg
#  extracting: valid/images/2012-09-20_08_14_19_jpg.rf.63cd23040c59c65eeacaa8f5d252909b.jpg
#  extracting: valid/images/2012-09-20_08_19_19_jpg.rf.d5537884cddef8ea1f57bf2180f502a5.jpg
#  extracting: valid/images/2012-09-20_08_39_20_jpg.rf.717ef1b2b06b05779e2b9529d4c920a2.jpg
#  extracting: valid/images/2012-09-20_08_49_20_jpg.rf.08c3d2e937a06c06e43277e37ec3aff9.jpg
#  extracting: valid/images/2012-09-20_08_59_21_jpg.rf.238cb36b2393db6e6ff5b47d77759bfb.jpg
#  extracting: valid/images/2012-09-20_09_19_22_jpg.rf.1430b1bbb6ee7f345f3e766addcec83d.jpg
#  extracting: valid/images/2012-09-20_09_49_23_jpg.rf.385bb01d9cb9806fcab2eeba7dc52ee7.jpg
#  extracting: valid/images/2012-09-20_10_09_24_jpg.rf.809da849cadce8060e04a73a1746ec7c.jpg
#  extracting: valid/images/2012-09-20_10_14_24_jpg.rf.7149ae38e7bc5a2230622e5126ac74f8.jpg
#  extracting: valid/images/2012-09-20_10_19_25_jpg.rf.223903d7b467c0e4adbe353915c2bd80.jpg
#  extracting: valid/images/2012-09-20_11_04_27_jpg.rf.b646a1bf4c0d22b41901f5d45e1c6f6a.jpg
#  extracting: valid/images/2012-09-20_11_19_27_jpg.rf.74400e6313ac1a5392a031219baa6748.jpg
#  extracting: valid/images/2012-09-20_11_34_28_jpg.rf.f38841fc84a4092ca19d7e1897800d1c.jpg
#  extracting: valid/images/2012-09-20_12_09_30_jpg.rf.b63174db1e28478afd8a2be14d8cafdc.jpg
#  extracting: valid/images/2012-09-20_12_19_30_jpg.rf.013d9e66035d6cf90fa61121ac4a9ee6.jpg
#  extracting: valid/images/2012-09-20_13_29_33_jpg.rf.40ba553d26f595aa7126b4ffc3925316.jpg
#  extracting: valid/images/2012-09-20_13_34_33_jpg.rf.d9b8524a33c00953b89aa0c204f126a2.jpg
#  extracting: valid/images/2012-09-20_13_54_34_jpg.rf.c61a84cc2e3c0d40220d0420a6c389ae.jpg
#  extracting: valid/images/2012-09-20_14_44_36_jpg.rf.0757a407deb85b39f1b173d026132cdc.jpg
#  extracting: valid/images/2012-09-20_14_54_37_jpg.rf.68b46829443b2e8700887abf6a4eeca3.jpg
#  extracting: valid/images/2012-09-20_15_29_38_jpg.rf.5cd5a5a4f00ef10357131262842f3f81.jpg
#  extracting: valid/images/2012-09-20_16_19_40_jpg.rf.06c494afae1ccfdf1efa641efbcc0af5.jpg
#  extracting: valid/images/2012-09-20_17_09_42_jpg.rf.f93f71df784cfed12787920e237d3ab7.jpg
#  extracting: valid/images/2012-09-20_17_14_42_jpg.rf.56aff3ae46d087e679b85e22277aa1f2.jpg
#  extracting: valid/images/2012-09-20_18_04_44_jpg.rf.45c646cd1437f1448fb5ce0a0e61171d.jpg
#  extracting: valid/images/2012-09-20_18_14_45_jpg.rf.58c68aa5219ae151fc16d8ef0c39f82a.jpg
#  extracting: valid/images/2012-09-21_06_10_10_jpg.rf.e095bb264ee6d1b50dd8d9a223f6de79.jpg
#  extracting: valid/images/2012-09-21_06_45_12_jpg.rf.ed69516da716eeebf708e7bc31da058f.jpg
#  extracting: valid/images/2012-09-21_07_10_13_jpg.rf.c6f36d714773c2b93087528e1bf104ef.jpg
#  extracting: valid/images/2012-09-21_07_30_14_jpg.rf.50f72214170952da52817081c8ab18ad.jpg
#  extracting: valid/images/2012-09-21_07_40_14_jpg.rf.b887784f70027be0673aae9298a6dd33.jpg
#  extracting: valid/images/2012-09-21_07_50_15_jpg.rf.dfde88b185e259ceb7e6f98cceb181f0.jpg
#  extracting: valid/images/2012-09-21_07_55_15_jpg.rf.b718d6d28d38a0dbd32ddf4ddb9a7996.jpg
#  extracting: valid/images/2012-09-21_08_00_15_jpg.rf.25ddfd0546ea15ce743f7bcc26b79267.jpg
#  extracting: valid/images/2012-09-21_08_20_16_jpg.rf.4a9e64f404ff7491fda8d76c6cbbeb2c.jpg
#  extracting: valid/images/2012-09-21_08_25_16_jpg.rf.67069962542a1e9d28b1e61cbcb190b6.jpg
#  extracting: valid/images/2012-09-21_08_30_16_jpg.rf.3b86ae828c692e5ff61a18a5c1caae7b.jpg
#  extracting: valid/images/2012-09-21_08_35_16_jpg.rf.8241acc30fc733ef3e2850a172076dc8.jpg
#  extracting: valid/images/2012-09-21_08_55_17_jpg.rf.fac4063d4dd79ec2576dcd306ca6f1d9.jpg
#  extracting: valid/images/2012-09-21_09_10_18_jpg.rf.330bad4e21a1847c92af4ea3b8ef4c74.jpg
#  extracting: valid/images/2012-09-21_09_35_19_jpg.rf.b94800aa1f824ed65039570bf5887052.jpg
#  extracting: valid/images/2012-09-21_09_45_19_jpg.rf.37e10a1a1a14454c35089ab2733afd58.jpg
#  extracting: valid/images/2012-09-21_09_55_20_jpg.rf.16163fb512ad085a2a0f948428ead845.jpg
#  extracting: valid/images/2012-09-21_10_20_21_jpg.rf.57715d5e81aa4cfd0e87a8154d0ec801.jpg
#  extracting: valid/images/2012-09-21_10_25_21_jpg.rf.0e3f5d565c4ad2cb25c9c6414212a6b8.jpg
#  extracting: valid/images/2012-09-21_10_45_22_jpg.rf.ea4329dbbe55d839ea5bbaf6f54e4882.jpg
#  extracting: valid/images/2012-09-21_11_00_23_jpg.rf.6becfe476679089d1e1d6340e2c42f06.jpg
#  extracting: valid/images/2012-09-21_11_50_25_jpg.rf.c4f290916db632b1ba688cb17a5f3da6.jpg
#  extracting: valid/images/2012-09-21_13_20_28_jpg.rf.35993fdc746cd6a0e19b77597be53366.jpg
#  extracting: valid/images/2012-09-21_13_35_29_jpg.rf.df82be43dd22956b5eec84990a105a58.jpg
#  extracting: valid/images/2012-09-21_14_05_30_jpg.rf.dd0d80a1028bcf9d24718030f89ea82a.jpg
#  extracting: valid/images/2012-09-21_14_45_32_jpg.rf.337dc13daefa67666252ae63f45b4bbb.jpg
#  extracting: valid/images/2012-09-21_14_50_32_jpg.rf.cd0423f57f447f2b35ea0eecda94f622.jpg
#  extracting: valid/images/2012-09-21_15_05_33_jpg.rf.389a2510b916c865b35c16e64a9c1dad.jpg
#  extracting: valid/images/2012-09-21_15_30_34_jpg.rf.db69a815b66773a30e81a4d72a043b0e.jpg
#  extracting: valid/images/2012-09-21_15_50_35_jpg.rf.c37a58735696a25b15ef7fcfcb00f88b.jpg
#  extracting: valid/images/2012-09-21_16_10_36_jpg.rf.4980ad4d6e7ad3a9c2b497c6539e772b.jpg
#  extracting: valid/images/2012-09-28_06_35_59_jpg.rf.e0ae7951eea5d19b1218974d3674bf06.jpg
#  extracting: valid/images/2012-09-28_06_50_59_jpg.rf.1cbb9f3ceb379cd16eba8e598863f620.jpg
#  extracting: valid/images/2012-09-28_07_31_01_jpg.rf.30547431b32f00e11844d49d87356668.jpg
#  extracting: valid/images/2012-09-28_08_06_02_jpg.rf.5cbf805d4d899f763c5ffe6f3bd0e948.jpg
#  extracting: valid/images/2012-09-28_08_16_03_jpg.rf.2edac9f134a658f3201c054c83974373.jpg
#  extracting: valid/images/2012-09-28_09_21_06_jpg.rf.3c95068aa1a536688e1e8b8282fa313b.jpg
#  extracting: valid/images/2012-09-28_09_31_07_jpg.rf.d5c15b00e9e311de7f4b5ea296229158.jpg
#  extracting: valid/images/2012-09-28_10_01_08_jpg.rf.e02d88fccc5bd5f4f5a8439a8f3634ae.jpg
#  extracting: valid/images/2012-09-28_10_26_09_jpg.rf.f5f2742f508c8dfba5971e736120d481.jpg
#  extracting: valid/images/2012-09-28_12_36_15_jpg.rf.5fcd44590a29d66bc1de50e2f6fda273.jpg
#  extracting: valid/images/2012-09-28_12_41_16_jpg.rf.e98765f5e2454765ee65ca50792ea7e5.jpg
#  extracting: valid/images/2012-09-28_13_26_18_jpg.rf.c0e47cf3956d4c108b1e98036623c3f6.jpg
#  extracting: valid/images/2012-09-28_13_36_18_jpg.rf.b835ea00e9a676c0dd30f9a41af12669.jpg
#  extracting: valid/images/2012-09-28_14_36_21_jpg.rf.2b90024d8ca0150e387eb3845880bc62.jpg
#  extracting: valid/images/2012-09-28_14_41_21_jpg.rf.072dc23bfc2ab15004d7d6867195ae03.jpg
#  extracting: valid/images/2012-09-28_15_16_22_jpg.rf.36c5fff736785204eaf40e4769cb46ff.jpg
#  extracting: valid/images/2012-09-28_15_31_23_jpg.rf.270b80e120394a2a20c2ab5d08e6cdb1.jpg
#  extracting: valid/images/2012-09-28_15_56_24_jpg.rf.9fb60e821cd89402f87d7a17f2a033f3.jpg
#  extracting: valid/images/2012-09-28_16_21_26_jpg.rf.5cf88d5ab6df5504d368d519bf798da5.jpg
#  extracting: valid/images/2012-09-28_16_31_26_jpg.rf.c58de3facc42ea272d2f7a1ecd635859.jpg
#  extracting: valid/images/2012-09-28_16_41_26_jpg.rf.f960b481d54dcfa5562e467424517471.jpg
#  extracting: valid/images/2012-09-28_17_16_28_jpg.rf.99268222adbc5349a1cb33fb97cb4ef2.jpg
#  extracting: valid/images/2012-09-28_17_41_29_jpg.rf.5c23c47d7eade08d2ce80b46c04f9fb6.jpg
#  extracting: valid/images/2012-09-28_17_46_29_jpg.rf.79edf649ad44ee4b2b695d7743ae7e99.jpg
#  extracting: valid/images/2012-09-28_17_51_30_jpg.rf.b30e55e42b68958384f729c1e1573c5d.jpg
#  extracting: valid/images/2012-09-28_18_11_31_jpg.rf.f655b61cf48159a62d07258d2c9aa911.jpg
#  extracting: valid/images/2012-09-29_06_02_02_jpg.rf.3eb5be304912d0bcdc2a939a65a317ea.jpg
#  extracting: valid/images/2012-09-29_06_07_03_jpg.rf.b0502f4ba9a340a3619335e5a3d78b20.jpg
#  extracting: valid/images/2012-09-29_06_57_05_jpg.rf.7415efb8c05dd43159285cefa8b6cd2f.jpg
#  extracting: valid/images/2012-09-29_07_02_05_jpg.rf.5cfb113dd7a402f83cc79b2d8801887f.jpg
#  extracting: valid/images/2012-09-29_07_12_05_jpg.rf.b4f5342afb19aaaab1293f81613b0cd2.jpg
#  extracting: valid/images/2012-10-05_08_32_49_jpg.rf.66f5334aa4157a7bbadc6f3b003473b3.jpg
#  extracting: valid/images/2012-10-05_08_57_51_jpg.rf.d0fa73f7543ba92eb6684ea81e171f1e.jpg
#  extracting: valid/images/2012-10-05_09_02_51_jpg.rf.1373c15f4a3e60de623660d7a6cb0ec1.jpg
#  extracting: valid/images/2012-10-09_08_08_43_jpg.rf.d028235c0cff856b941c61a8393c6707.jpg
#  extracting: valid/images/2012-10-09_08_18_43_jpg.rf.24ce73ece00e7ea0ebef52d040bb2a5d.jpg
#  extracting: valid/images/2012-10-09_08_23_43_jpg.rf.9333ffc86e9da44797d87a9e0b6d7d28.jpg
#  extracting: valid/images/2012-10-09_08_48_45_jpg.rf.61af265e27b6654ab2a66a18bd52d333.jpg
#  extracting: valid/images/2012-10-09_08_53_45_jpg.rf.29b20642dc2bbe3f08f1c64381dbd16d.jpg
#  extracting: valid/images/2012-10-11_07_56_28_jpg.rf.49a82e99fe27d12b3ce539a7b5387d75.jpg
#  extracting: valid/images/2012-10-11_07_56_44_jpg.rf.18c55b8a978c22ec94bf493ab551aebb.jpg
#  extracting: valid/images/2012-10-11_07_56_55_jpg.rf.397a5001f03b325719eabd22ae58ea18.jpg
#  extracting: valid/images/2012-10-11_07_57_37_jpg.rf.35ec028a4268d42f711f6d074c022d4a.jpg
#  extracting: valid/images/2012-10-11_07_58_04_jpg.rf.3909e91ef7d4d99de93a706cdb9b0ed1.jpg
#  extracting: valid/images/2012-10-11_07_58_20_jpg.rf.2930965555b4635d162b3b1aaa7942d8.jpg
#  extracting: valid/images/2012-10-11_07_58_31_jpg.rf.2c2243a400b97cbe7c3452f40d89a259.jpg
#  extracting: valid/images/2012-10-11_08_00_17_jpg.rf.261be470b56801916c109130f658fafb.jpg
#  extracting: valid/images/2012-10-11_08_00_33_jpg.rf.a84681fd4019e43327a41e887eccf64a.jpg
#  extracting: valid/images/2012-10-11_08_26_33_jpg.rf.ebaaf1c54fa4e28920f1fb3742605fb4.jpg
#  extracting: valid/images/2012-10-11_08_36_33_jpg.rf.e3e0d2a29f9e2a02ec3d76db58fcbf3e.jpg
#  extracting: valid/images/2012-10-11_08_46_33_jpg.rf.a2152084a938ab9208400e46f73c57fc.jpg
#  extracting: valid/images/2012-10-11_08_56_34_jpg.rf.e0374390bd97fbb638d7dbb6f8b81e8a.jpg
#  extracting: valid/images/2012-10-11_09_41_36_jpg.rf.5f13b0b2b1e9232c52fc24b748169f56.jpg
#  extracting: valid/images/2012-10-11_10_01_37_jpg.rf.d5f1fc578c69e804f54774daad1a842e.jpg
#  extracting: valid/images/2012-10-11_11_51_42_jpg.rf.4786316ef335045d138a222a2bf74d5a.jpg
#  extracting: valid/images/2012-10-11_12_56_45_jpg.rf.95805bb16c4f51935e65677345b03299.jpg
#  extracting: valid/images/2012-10-11_13_21_46_jpg.rf.934efe5b741bc8c2626f6d06fdbb5af6.jpg
#  extracting: valid/images/2012-10-11_13_41_47_jpg.rf.0402ba16f5215e5537bcc7b1a3f4fa3f.jpg
#  extracting: valid/images/2012-10-11_13_56_47_jpg.rf.dfe5c99c35b8964a33d8038b92fadb06.jpg
#  extracting: valid/images/2012-10-11_14_01_47_jpg.rf.105bc3bde5bdeb5011f1cfe4ed0eda4e.jpg
#  extracting: valid/images/2012-10-11_14_31_49_jpg.rf.bd3a91456a725659a7f6677b2349aae8.jpg
#  extracting: valid/images/2012-10-11_14_51_49_jpg.rf.cc58eba481879ddd6dc22a1afed2bb3c.jpg
#  extracting: valid/images/2012-10-11_15_01_50_jpg.rf.15af2350f76161462e824aa573be4a05.jpg
#  extracting: valid/images/2012-10-11_15_26_51_jpg.rf.8c8e9c1dfd28d7b3b9244f48166f9bcd.jpg
#  extracting: valid/images/2012-10-11_15_36_51_jpg.rf.31b73cb16cb25c807cb7c020a35140cb.jpg
#  extracting: valid/images/2012-10-11_15_51_52_jpg.rf.6ea4667f79226c303c0e812a5a731ebb.jpg
#  extracting: valid/images/2012-10-11_16_06_52_jpg.rf.27dd1f14db8a5265d3543ebdc2b10650.jpg
#  extracting: valid/images/2012-10-11_16_11_52_jpg.rf.41c09098be3c7fa217a882d878e71e8c.jpg
#  extracting: valid/images/2012-10-11_16_41_54_jpg.rf.3b81468733688f8c3b58937941e8b0c1.jpg
#  extracting: valid/images/2012-10-11_16_51_54_jpg.rf.a94a413a5e25b031193b676ba5d380df.jpg
#  extracting: valid/images/2012-10-11_17_21_56_jpg.rf.5e63a67526e72cb19a5ac1a171f484db.jpg
#  extracting: valid/images/2012-10-11_17_41_56_jpg.rf.ddafb30dfabb752559d027c960863a59.jpg
#  extracting: valid/images/2012-10-12_05_52_29_jpg.rf.f794bd4ddbfbd746949db9d743c7e913.jpg
#  extracting: valid/images/2012-10-12_06_07_30_jpg.rf.c95736056b48c18793ca28f7c0271561.jpg
#  extracting: valid/images/2012-10-12_06_12_30_jpg.rf.0cd0643cf40f67cdfc74b9e46aaec911.jpg
#  extracting: valid/images/2012-10-12_06_37_31_jpg.rf.a62acbe41a3399f0f5c5827fb3966fc4.jpg
#  extracting: valid/images/2012-10-12_06_47_31_jpg.rf.55ab2ec41d63edc0138750cade2a815c.jpg
#  extracting: valid/images/2012-10-12_06_52_32_jpg.rf.df8d7dca8c55a13d019c527221538121.jpg
#  extracting: valid/images/2012-10-12_07_12_33_jpg.rf.599512f7327bfb29a059fae2a6c0f390.jpg
#  extracting: valid/images/2012-10-12_07_22_33_jpg.rf.9c4b590019eb5d0311a14253ad33f7bf.jpg
#  extracting: valid/images/2012-10-12_07_52_34_jpg.rf.38c3605321b672bfab3b397a8f46d013.jpg
#  extracting: valid/images/2012-10-12_08_22_35_jpg.rf.1099e81e74ee92dc4f1ddf4267c19cac.jpg
#  extracting: valid/images/2012-10-12_08_42_36_jpg.rf.e95ae5a76c50052c3d7271a0c7dba8ca.jpg
#  extracting: valid/images/2012-10-12_08_57_37_jpg.rf.2960807268e61bbc397c477d0e64f61b.jpg
#  extracting: valid/images/2012-10-12_09_07_37_jpg.rf.209b451c059fb7554ee3ef4c5de2c1d3.jpg
#  extracting: valid/images/2012-10-12_09_17_38_jpg.rf.d3383b3a41f326e85c7f9bab81070a08.jpg
#  extracting: valid/images/2012-10-12_09_27_38_jpg.rf.dc5b88f3576fd9b6dd0536e6f6ecc062.jpg
#  extracting: valid/images/2012-10-12_10_02_40_jpg.rf.a56dd2c315229ab6388c94e94f633a29.jpg
#  extracting: valid/images/2012-10-12_10_17_41_jpg.rf.2c01b1012d371d13819be5f3b0aa6948.jpg
#  extracting: valid/images/2012-10-12_10_57_42_jpg.rf.76750fb85ea98965eb13facab51008aa.jpg
#  extracting: valid/images/2012-10-12_11_22_44_jpg.rf.252d7df29342b4289219e15f6198774a.jpg
#  extracting: valid/images/2012-10-12_12_02_45_jpg.rf.8bf44cb5d6f691cfe27a16ec10e434b5.jpg
#  extracting: valid/images/2012-10-12_12_57_48_jpg.rf.07c4c6999f94bb4170564c1f394cc652.jpg
#  extracting: valid/images/2012-10-12_13_27_49_jpg.rf.b396c0a25a44e5b71fad3d782dbbd7a3.jpg
#  extracting: valid/images/2012-10-12_13_52_50_jpg.rf.4942174e11e297f06943747990472c8e.jpg
#  extracting: valid/images/2012-10-12_14_07_51_jpg.rf.2afaa8a3ecd51a99dea1b54c3832f938.jpg
#  extracting: valid/images/2012-10-12_14_17_51_jpg.rf.0eb890bcd30a083a33a673e607c583f7.jpg
#  extracting: valid/images/2012-10-12_14_47_52_jpg.rf.72506af2108c33ed9405f29719e495d5.jpg
#  extracting: valid/images/2012-10-12_15_17_54_jpg.rf.d7cf7a3a5f2d1a2377cf40d5316efd1e.jpg
#  extracting: valid/images/2012-10-12_16_12_56_jpg.rf.eff9865d6a5d3026d9dbfcc6408ef768.jpg
#  extracting: valid/images/2012-10-12_16_17_56_jpg.rf.0e8b3deae586fe9c668fd9440506321e.jpg
#  extracting: valid/images/2012-10-12_16_32_57_jpg.rf.1eadd02ff09f72c4c0b126e64567e867.jpg
#  extracting: valid/images/2012-10-12_16_47_57_jpg.rf.3079a2ef2f6cea65b46f7e1e79f95ea6.jpg
#  extracting: valid/images/2012-10-12_17_27_59_jpg.rf.6f8b6cfbe87d34f866662ae9a8653244.jpg
#  extracting: valid/images/2012-10-12_17_53_00_jpg.rf.f7fa5869def21dd3237ec4d74a909b75.jpg
#  extracting: valid/images/2012-10-13_06_03_34_jpg.rf.022d1aed7b64d35aec3a7ba3bf728c55.jpg
#  extracting: valid/images/2012-10-13_06_18_34_jpg.rf.edc9e81f41f4858e1aa8908afc6147b2.jpg
#  extracting: valid/images/2012-10-13_06_48_36_jpg.rf.98af638aed9b48b6108d2e38a2e9e285.jpg
#  extracting: valid/images/2012-10-13_06_53_36_jpg.rf.11cf4128cdfd8a6b6224c0ad7df2bed7.jpg
#  extracting: valid/images/2012-10-13_07_38_38_jpg.rf.04a675f934c2251b6eafe303fba33c5f.jpg
#  extracting: valid/images/2012-10-13_08_18_39_jpg.rf.231e08f03018d067a761c15188f9e610.jpg
#  extracting: valid/images/2012-10-13_10_03_44_jpg.rf.457deab4473df7d10c0e4681bdef0029.jpg
#  extracting: valid/images/2012-10-13_10_08_44_jpg.rf.56b57610b4d6893a8a0aea82a174e59d.jpg
#  extracting: valid/images/2012-10-13_10_43_45_jpg.rf.cf886eeadba43b08e554a1376c09fe62.jpg
#  extracting: valid/images/2012-10-13_11_58_48_jpg.rf.309551798000feb357fc45cf3beb3eac.jpg
#  extracting: valid/images/2012-10-13_12_58_51_jpg.rf.6616f508ec15749365eda9d6a710c06d.jpg
#  extracting: valid/images/2012-10-13_13_38_52_jpg.rf.ad3b76d90055c07763dbe2f4622b34cd.jpg
#  extracting: valid/images/2012-10-13_14_03_53_jpg.rf.08dab21a868b461ee97a7d1c685dcc24.jpg
#  extracting: valid/images/2012-10-13_14_13_54_jpg.rf.908ca91286819d60d1e47c8eb0a0f5d8.jpg
#  extracting: valid/images/2012-10-13_14_48_55_jpg.rf.d4b30df74eccfc9e90e75e63a4469046.jpg
#  extracting: valid/images/2012-10-13_16_18_59_jpg.rf.ad02ed954e7c6e2c2fdad0efe88a3e31.jpg
#  extracting: valid/images/2012-10-13_16_29_00_jpg.rf.0efb4bb3932d26711eae8953345bf8d7.jpg
#  extracting: valid/images/2012-10-13_17_04_01_jpg.rf.bd624d79100c275685c75c9ec32ed36c.jpg
#  extracting: valid/images/2012-10-13_17_19_02_jpg.rf.e49f0792ca2ea9b394c180007a11e4d7.jpg
#  extracting: valid/images/2012-10-13_17_29_02_jpg.rf.af586a7c58d7163a7f8e3c005865006a.jpg
#  extracting: valid/images/2012-10-13_17_54_03_jpg.rf.2bd2cca52e924decb7dc0d91dabea429.jpg
#  extracting: valid/images/2012-10-14_06_09_36_jpg.rf.2d3e7e6436b5c59a032416cc5a935474.jpg
#  extracting: valid/images/2012-10-14_06_39_37_jpg.rf.edc18996f8c690ffdf6252b1f0090fa6.jpg
#  extracting: valid/images/2012-10-14_08_19_41_jpg.rf.2570fd07593bfc2a46ba34e0a0d526d7.jpg
#  extracting: valid/images/2012-10-14_08_54_43_jpg.rf.851f2eb59f5cbf4a174b80e2a0809112.jpg
#  extracting: valid/images/2012-10-14_09_24_44_jpg.rf.bdc56430e81c83e5f74491b6e8059070.jpg
#  extracting: valid/images/2012-10-14_10_04_46_jpg.rf.4ab10020346e36dacc5d5ecaf3c093c3.jpg
#  extracting: valid/images/2012-10-14_10_09_46_jpg.rf.d0e3a96abda480114146ab1b60d390d3.jpg
#  extracting: valid/images/2012-10-14_10_34_47_jpg.rf.881082e9a133e65f687b35a34d232983.jpg
#  extracting: valid/images/2012-10-14_10_54_48_jpg.rf.803f90eea5ebac380d805b22390723ce.jpg
#  extracting: valid/images/2012-10-14_11_04_49_jpg.rf.f70d7d83ef13bde47a0e36b85965604b.jpg
#  extracting: valid/images/2012-10-14_11_14_49_jpg.rf.8672c41f2f50b355aea6381a9ab2402b.jpg
#  extracting: valid/images/2012-10-14_11_19_49_jpg.rf.f725feb4e65411bad2dc40806323bb22.jpg
#  extracting: valid/images/2012-10-14_11_44_50_jpg.rf.f30d0658c11b7c90b63d3d9b40d4320b.jpg
#  extracting: valid/images/2012-10-14_13_44_56_jpg.rf.996de6c0f3ad71d53bf6ef845d74258f.jpg
#  extracting: valid/images/2012-10-14_13_49_56_jpg.rf.ff8680134a0988b0a3049645c43990d9.jpg
#  extracting: valid/images/2012-10-14_14_09_57_jpg.rf.7ffb1905330d11243f970b67fefb6dbe.jpg
#  extracting: valid/images/2012-10-14_14_19_57_jpg.rf.9f39314e5e9753b8f54b499c40453e81.jpg
#  extracting: valid/images/2012-10-14_14_39_58_jpg.rf.7239b52fb79d07bb0176afbdd481d829.jpg
#  extracting: valid/images/2012-10-14_15_25_00_jpg.rf.dee010fde4d6214fcf2badcb6aa35dad.jpg
#  extracting: valid/images/2012-10-14_16_05_02_jpg.rf.d1511e417997c013a25513ec929f360f.jpg
#  extracting: valid/images/2012-10-14_16_40_03_jpg.rf.76a9467aa79d7502b570959cc19422f8.jpg
#  extracting: valid/images/2012-10-14_17_10_05_jpg.rf.44960c2a49a3286036bd1d621da83596.jpg
#  extracting: valid/images/2012-10-14_17_35_06_jpg.rf.21aafc544e2a9a11ba866e951fb0f4cd.jpg
#  extracting: valid/images/2012-10-14_17_45_06_jpg.rf.9330beaf72459b1fe1ae91e089ff439b.jpg
#  extracting: valid/images/2012-10-15_05_55_40_jpg.rf.f468f3acb51a2aca99e37b94861f5cf3.jpg
#  extracting: valid/images/2012-10-15_06_40_42_jpg.rf.fa123ce8f3ea8e501a8e1b394831c72f.jpg
#  extracting: valid/images/2012-10-15_06_55_43_jpg.rf.bdee4276129d894bd8623821b46ebf60.jpg
#  extracting: valid/images/2012-10-15_08_10_46_jpg.rf.bd43c8aac52756123a82aef521621957.jpg
#  extracting: valid/images/2012-10-15_08_25_47_jpg.rf.b5de30ee7682a8c7b06c93a1b84047b0.jpg
#  extracting: valid/images/2012-10-15_08_40_47_jpg.rf.9d65168179adf1c621f260f35eb28739.jpg
#  extracting: valid/images/2012-10-15_09_05_49_jpg.rf.869d37f67aab3ca5ed5ce3661cb5f34f.jpg
#  extracting: valid/images/2012-10-15_10_05_51_jpg.rf.619a95387fabb2d095faa70060338b36.jpg
#  extracting: valid/images/2012-10-15_10_25_52_jpg.rf.b90ec682ae0a6ff267f5ac2b028da1fe.jpg
#  extracting: valid/images/2012-10-15_10_35_52_jpg.rf.5c7fc8ed993eed0c9f2194392b496d52.jpg
#  extracting: valid/images/2012-10-15_11_00_54_jpg.rf.b46100242293a26a1bde0ef64201f288.jpg
#  extracting: valid/images/2012-10-15_11_15_54_jpg.rf.f8a3c8f6135485a3352e6db85f23116a.jpg
#  extracting: valid/images/2012-10-15_11_30_55_jpg.rf.0b111d37acdb5517eae22fa19e1e39dd.jpg
#  extracting: valid/images/2012-10-15_11_40_55_jpg.rf.9b19f7a3d9ec62b74ff0b6d663af5d5d.jpg
#  extracting: valid/images/2012-10-15_12_05_56_jpg.rf.cdc14820e37e1e5c977b0716db197898.jpg
#  extracting: valid/images/2012-10-15_12_15_57_jpg.rf.d172cef1bd0c41559b1768379833abbf.jpg
#  extracting: valid/images/2012-10-15_12_25_57_jpg.rf.7e5bbeae4ee19f28740ac5d83b29c513.jpg
#  extracting: valid/images/2012-10-15_12_30_58_jpg.rf.ee60b17567171e0e55b71e3b3fb06264.jpg
#  extracting: valid/images/2012-10-15_15_36_05_jpg.rf.a58deff0d32fb06c56d4bb602ca2b33b.jpg
#  extracting: valid/images/2012-10-15_15_46_05_jpg.rf.614617a802b4e05697d22cf5a6af4d35.jpg
#  extracting: valid/images/2012-10-15_17_06_08_jpg.rf.49977ecf02b889703e0501ec63355f6c.jpg
#  extracting: valid/images/2012-10-15_17_31_09_jpg.rf.56746f75c14fa6c0b2bd6f811cd5bad5.jpg
#  extracting: valid/images/2012-10-15_17_56_10_jpg.rf.0e084c520e27f7af1737f85e8e02a07b.jpg
#  extracting: valid/images/2012-10-15_18_11_11_jpg.rf.b67ff486a839a723ff750dce812b8f88.jpg
#  extracting: valid/images/2012-10-15_18_21_11_jpg.rf.3c8c3f718ee03c8da40a7df61b2bbfff.jpg
#  extracting: valid/images/2012-10-16_05_51_42_jpg.rf.6ed00797b16d86996f921e75f429d054.jpg
# ...
#  extracting: valid/labels/2013-04-10_08_05_02_jpg.rf.85a43eb61041f5c2447a1cfe3141ff6d.txt
#  extracting: valid/labels/2013-04-10_08_35_02_jpg.rf.9279be6f8c4d1685354e08e0ed8cd17e.txt
#  extracting: valid/labels/2013-04-10_09_20_03_jpg.rf.2df6cd6695d94f60464f561e85eb2598.txt
#  extracting: valid/labels/2013-04-10_09_30_03_jpg.rf.2e7f77ab17a0515a0a524394ba2561af.txt
#  extracting: valid/labels/2013-04-10_09_40_04_jpg.rf.c079bc32de737f3329b047f331fdde99.txt
#  extracting: valid/labels/2013-04-10_09_50_04_jpg.rf.d07553c3e3016d35b51e43baebda19ab.txt
#  extracting: valid/labels/2013-04-10_09_55_04_jpg.rf.75175daf1c05d56ab655eddba28d2b74.txt
#  extracting: valid/labels/2013-04-10_10_05_04_jpg.rf.1e6b6a22313cff98f4c7ae5e39f5be1d.txt
#  extracting: valid/labels/2013-04-10_10_30_05_jpg.rf.6626138665dfec7c74757836b6a3cdd0.txt
#  extracting: valid/labels/2013-04-10_10_45_05_jpg.rf.f50fd50cec35ccf1d61f6d1964ea6163.txt
#  extracting: valid/labels/2013-04-10_11_15_05_jpg.rf.219c83d059697fe4ee4bdc7da376f71b.txt
#  extracting: valid/labels/2013-04-10_11_20_06_jpg.rf.4fdb8ed35288720c9caa2b53ef06279e.txt
#  extracting: valid/labels/2013-04-10_11_30_06_jpg.rf.f4ae0b9bc2f889b4f259e1354a490c4e.txt
#  extracting: valid/labels/2013-04-10_11_45_06_jpg.rf.06e8eea586d3f269362eea29d611cbd0.txt
#  extracting: valid/labels/2013-04-10_12_05_06_jpg.rf.0ab3d31271f9a2e27b80680477d91f9e.txt
#  extracting: valid/labels/2013-04-10_12_30_07_jpg.rf.8a3c64cbe881bb66f0b386d655816e18.txt
#  extracting: valid/labels/2013-04-10_12_55_07_jpg.rf.e283813ef4c3cd3dc730c4c295e6039a.txt
#  extracting: valid/labels/2013-04-10_13_10_08_jpg.rf.dca3e3c95f0874bc7e700746319a6d64.txt
#  extracting: valid/labels/2013-04-10_13_40_08_jpg.rf.2bbbf1827b7aa4022e6475111d6e1220.txt
#  extracting: valid/labels/2013-04-10_14_10_09_jpg.rf.fd7b34c43235c23834ee693580683f56.txt
#  extracting: valid/labels/2013-04-10_14_25_09_jpg.rf.a2f7048ab15cabed7db51ce678ff53bf.txt
#  extracting: valid/labels/2013-04-10_14_35_09_jpg.rf.9a45489d5cc0040de083745a96693758.txt
#  extracting: valid/labels/2013-04-10_15_00_10_jpg.rf.fe10fbc289fa03661c29638234b05c1d.txt
#  extracting: valid/labels/2013-04-10_15_10_10_jpg.rf.4fd7536fbdf4833e6856c75b2a1e2d7e.txt
#  extracting: valid/labels/2013-04-10_15_15_10_jpg.rf.c23844ee5606b18a9b3bc81e8a54d9ac.txt
#  extracting: valid/labels/2013-04-10_15_25_10_jpg.rf.0a9a13d8f976afac4ea736a932b86ed0.txt
#  extracting: valid/labels/2013-04-10_15_55_11_jpg.rf.33a4f1c862f60c278a4a6c68a38cca31.txt
#  extracting: valid/labels/2013-04-10_16_20_11_jpg.rf.5cd95e61f1af22203944aec36f35ca4d.txt
#  extracting: valid/labels/2013-04-10_16_45_12_jpg.rf.67edf0acc7e2f24e8a1426ff7ebec987.txt
#  extracting: valid/labels/2013-04-10_17_00_12_jpg.rf.b1c1aad25a3f7f35524e5fdbc28af504.txt
#  extracting: valid/labels/2013-04-10_18_00_13_jpg.rf.d18ba15ae763e4d018560ade0bf4e0a4.txt
#  extracting: valid/labels/2013-04-11_06_50_00_jpg.rf.f91cbcefc93330b9a96466fe53a6070b.txt
#  extracting: valid/labels/2013-04-11_07_10_01_jpg.rf.07e725556ee663d0a89c7b85e45bc5fc.txt
#  extracting: valid/labels/2013-04-11_07_15_01_jpg.rf.5e73b4515818e7fbc646521d17145a7d.txt
#  extracting: valid/labels/2013-04-11_07_25_01_jpg.rf.01f9517b1756ab4d3a63c3f328e54d30.txt
#  extracting: valid/labels/2013-04-11_07_45_01_jpg.rf.06b1e3d732e81716e8726f5294e810af.txt
#  extracting: valid/labels/2013-04-11_08_00_02_jpg.rf.1e89ccd85c9c042909cd6fcd239b6c4c.txt
#  extracting: valid/labels/2013-04-11_08_10_02_jpg.rf.7ac330e973171e4c4272a118b4348af7.txt
#  extracting: valid/labels/2013-04-11_08_20_02_jpg.rf.9587a82393dfd75be8bebc3e860ca52a.txt
#  extracting: valid/labels/2013-04-11_08_25_02_jpg.rf.51757676d76a67732d72e5c06992eff2.txt
#  extracting: valid/labels/2013-04-11_09_15_03_jpg.rf.b2f6ddbf3f5210c2104775932146fee2.txt
#  extracting: valid/labels/2013-04-11_09_55_04_jpg.rf.b2bcf47bca4d221c44bb87f24b34edcb.txt
#  extracting: valid/labels/2013-04-11_10_25_05_jpg.rf.ccb26ddcc85867adc380af691905c52d.txt
#  extracting: valid/labels/2013-04-11_11_00_05_jpg.rf.9bc71d4c9f0dae1bc576ecd8508dcbb1.txt
#  extracting: valid/labels/2013-04-11_11_25_06_jpg.rf.df4ab9532ef54dbc58ed8308558d664c.txt
#  extracting: valid/labels/2013-04-11_11_50_06_jpg.rf.b4a13ad3a242c043bbac75ca070df405.txt
#  extracting: valid/labels/2013-04-11_11_55_06_jpg.rf.dc049490d84e652725cace22dd8c0a9e.txt
#  extracting: valid/labels/2013-04-11_12_00_06_jpg.rf.c92c24fd8d97b83d3e42efa762dfbcb6.txt
#  extracting: valid/labels/2013-04-11_12_15_06_jpg.rf.a0dc4abdf1a2dc7ecccbe3da3e3cd60d.txt
#  extracting: valid/labels/2013-04-11_12_45_07_jpg.rf.a527d5db7c2018f29fde1abf2655274f.txt
#  extracting: valid/labels/2013-04-11_12_55_07_jpg.rf.0d7ddc23c450b6a9fc9343c08e82a850.txt
#  extracting: valid/labels/2013-04-11_13_35_08_jpg.rf.660c05c68ce7fa5ff27958970cbb6c47.txt
#  extracting: valid/labels/2013-04-11_14_00_08_jpg.rf.8ecb530eff6c17874960fbca93cbea9b.txt
#  extracting: valid/labels/2013-04-11_14_05_09_jpg.rf.6d6d4812de99d2af4bc86bedf8f74a2b.txt
#  extracting: valid/labels/2013-04-11_14_20_09_jpg.rf.df4cb145aada79c0e7a7f4f3dc89ce46.txt
#  extracting: valid/labels/2013-04-11_14_50_09_jpg.rf.58ed0ddbe631f5f333dbcf1f97426d27.txt
#  extracting: valid/labels/2013-04-11_15_10_10_jpg.rf.3a85caccf5b99562e071b3c8da1ed50a.txt
#  extracting: valid/labels/2013-04-11_15_20_10_jpg.rf.23aa28843d66b102299c7b39ab0c9e85.txt
#  extracting: valid/labels/2013-04-11_16_05_11_jpg.rf.859bfd3293c594764fc1e7a0cac59792.txt
#  extracting: valid/labels/2013-04-11_16_40_11_jpg.rf.335cf6da4f63c03d23721aea5c36f9de.txt
#  extracting: valid/labels/2013-04-11_17_00_12_jpg.rf.60c0b1dab962faef2c9ef4f66efd1251.txt
#  extracting: valid/labels/2013-04-11_17_10_12_jpg.rf.e77e9900097b5361412c53d7a2a5de06.txt
#  extracting: valid/labels/2013-04-12_06_50_00_jpg.rf.835cb1d36b6633df98d52edffe964af0.txt
#  extracting: valid/labels/2013-04-12_07_10_01_jpg.rf.56e138eab5148582b2b725b5fd91fabf.txt
#  extracting: valid/labels/2013-04-12_08_15_02_jpg.rf.7b48a8ad08aaf7ccd81143939129109b.txt
#  extracting: valid/labels/2013-04-12_08_35_02_jpg.rf.5db85c13034f9b50841a9af072eda9d6.txt
#  extracting: valid/labels/2013-04-12_09_00_03_jpg.rf.c66046399f86bbfd1dd391eec83e1e84.txt
#  extracting: valid/labels/2013-04-12_10_15_04_jpg.rf.61caac283d63ab78c2f36e85f0aef21d.txt
#  extracting: valid/labels/2013-04-12_11_05_05_jpg.rf.911db5a4702f961dc79699ca83d0584f.txt
#  extracting: valid/labels/2013-04-12_11_20_05_jpg.rf.8e7ddd62e66efc633b2c1176ebafe161.txt
#  extracting: valid/labels/2013-04-12_11_55_06_jpg.rf.19aa923f4cff0210d47de96423b92b61.txt
#  extracting: valid/labels/2013-04-12_12_35_07_jpg.rf.0cb1a56478f876877964542fd9af5716.txt
#  extracting: valid/labels/2013-04-12_12_45_07_jpg.rf.97b83b8bd1584fca10cae916ece1229f.txt
#  extracting: valid/labels/2013-04-12_13_15_07_jpg.rf.cef808bb6271b2447cff45df41643d68.txt
#  extracting: valid/labels/2013-04-12_13_20_08_jpg.rf.fac971d7db6e0564a8f668a05fa35c6d.txt
#  extracting: valid/labels/2013-04-12_13_45_08_jpg.rf.f5b51e4736494bb8ff5661069b2e15d5.txt
#  extracting: valid/labels/2013-04-12_13_55_08_jpg.rf.413752e8b9b1ff4a0d7c91938cc5b114.txt
#  extracting: valid/labels/2013-04-12_14_40_09_jpg.rf.2486c63764fe5c3a4ac09399c146c5be.txt
#  extracting: valid/labels/2013-04-12_15_10_10_jpg.rf.f45f53c43f72b3ea678a3de0a83d331f.txt
#  extracting: valid/labels/2013-04-12_15_45_10_jpg.rf.9fe0da28523281b6fea0267279ee14b9.txt
#  extracting: valid/labels/2013-04-12_15_50_10_jpg.rf.04a2ec13a7960d3a64e932105e8edd33.txt
#  extracting: valid/labels/2013-04-12_15_55_10_jpg.rf.4bd73959ad0c6d7cf01f0d8de96003a4.txt
#  extracting: valid/labels/2013-04-12_16_35_11_jpg.rf.ad929b039e7e238840debb1a36a98540.txt
#  extracting: valid/labels/2013-04-12_16_40_11_jpg.rf.0f1abdeb68e8d84beca171021409f8ee.txt
#  extracting: valid/labels/2013-04-12_17_00_12_jpg.rf.4d4ade83d265a744fe1e87ad8b5dbcd9.txt
#  extracting: valid/labels/2013-04-12_17_15_12_jpg.rf.02855ff896aa98dec056a39c8fc84a05.txt
#  extracting: valid/labels/2013-04-12_17_35_12_jpg.rf.b95dc879570766e22064c251624235d8.txt
#  extracting: valid/labels/2013-04-12_17_50_13_jpg.rf.ff78dd720517b415883a55993f0f3ba7.txt
#  extracting: valid/labels/2013-04-13_06_45_01_jpg.rf.cb70a6338bae8c92bebf6b23ca8d04a8.txt
#  extracting: valid/labels/2013-04-13_07_05_01_jpg.rf.513146ab260df8aae2ccef72bf9d1e71.txt
#  extracting: valid/labels/2013-04-13_07_35_01_jpg.rf.ec647aecdf5d57f89d9fd867ba279718.txt
#  extracting: valid/labels/2013-04-13_08_40_03_jpg.rf.415513a57bc2da5281189244676c3db9.txt
#  extracting: valid/labels/2013-04-13_08_55_03_jpg.rf.2f2203fd1829975c7f30615822ab89cc.txt
#  extracting: valid/labels/2013-04-13_09_20_03_jpg.rf.ca98b73d59bc7a9e0aa88bb2f3715381.txt
#  extracting: valid/labels/2013-04-13_10_55_05_jpg.rf.c88b82a1acb035da4a2e2cad667a84b9.txt
#  extracting: valid/labels/2013-04-13_11_25_06_jpg.rf.2ed377ca1c5f8b023a030f863c05db16.txt
#  extracting: valid/labels/2013-04-13_11_30_06_jpg.rf.da1f19f0946296f089f6f24eb0477282.txt
#  extracting: valid/labels/2013-04-13_12_25_07_jpg.rf.2a64cb27287c6f2e4f26724d110ffb6b.txt
#  extracting: valid/labels/2013-04-13_13_15_08_jpg.rf.6b991eaaea8b74ebac93d01747c2e274.txt
#  extracting: valid/labels/2013-04-13_13_20_08_jpg.rf.b6296b5ce12b83caf1ac3b2663f9aba2.txt
#  extracting: valid/labels/2013-04-13_14_20_09_jpg.rf.799f8314cf50a7e59693d20ff4a49386.txt
#  extracting: valid/labels/2013-04-13_14_40_09_jpg.rf.2541b80caa438512125528bb33c8e5f5.txt
#  extracting: valid/labels/2013-04-13_14_55_09_jpg.rf.8abbe8b3564ea9814a7c3656a4d4e376.txt
#  extracting: valid/labels/2013-04-13_16_05_11_jpg.rf.1f236b211d36377d5845d0c8718b487f.txt
#  extracting: valid/labels/2013-04-13_16_25_11_jpg.rf.92952f22caffdf490c9bac943e067ff4.txt
#  extracting: valid/labels/2013-04-13_17_20_12_jpg.rf.24fc76d517714b215f1882cfed6407a6.txt
#  extracting: valid/labels/2013-04-14_07_05_01_jpg.rf.0d14e31292f06afa66507ec7edcadb90.txt
#  extracting: valid/labels/2013-04-14_07_45_02_jpg.rf.8907612a83b4b3dc40218cf698b7eb28.txt
#  extracting: valid/labels/2013-04-14_07_50_02_jpg.rf.579a009c68740008ef4818643ad1f25e.txt
#  extracting: valid/labels/2013-04-14_08_15_02_jpg.rf.cc909b5a7421924ccbdf08389f709fdf.txt
#  extracting: valid/labels/2013-04-14_08_25_02_jpg.rf.c9f44c09ec6fc370deaa978e82a516f0.txt
#  extracting: valid/labels/2013-04-14_08_40_03_jpg.rf.c1ed885d3108e2a26e5a97c3c0572db5.txt
#  extracting: valid/labels/2013-04-14_09_00_03_jpg.rf.8c861933e4ba9b29326ab2586a521c92.txt
#  extracting: valid/labels/2013-04-14_09_45_04_jpg.rf.28db26e74905e02cf5e07bd63d5eddd8.txt
#  extracting: valid/labels/2013-04-14_10_30_05_jpg.rf.bfededc6e0c28060b5057910fcdb6df3.txt
#  extracting: valid/labels/2013-04-14_10_35_05_jpg.rf.149612156aa77a070a3c0aeb057b0a54.txt
#  extracting: valid/labels/2013-04-14_10_40_05_jpg.rf.c3216757f165d06708264baaa2cc0169.txt
#  extracting: valid/labels/2013-04-14_10_50_05_jpg.rf.dc19615d3fcbe0a35586e770441470da.txt
#  extracting: valid/labels/2013-04-14_11_05_05_jpg.rf.da464a62d29e18ccadab6052cbcf4ce4.txt
#  extracting: valid/labels/2013-04-14_11_15_05_jpg.rf.8b3bb0904f647906ef2566ca94016a27.txt
#  extracting: valid/labels/2013-04-14_11_40_06_jpg.rf.7625a69ae48f09953996c0fed96978f6.txt
#  extracting: valid/labels/2013-04-14_11_45_06_jpg.rf.5e1815234a010cd33e4d88b5a42fb12d.txt
#  extracting: valid/labels/2013-04-14_12_00_06_jpg.rf.90e710a621f938b1cd473be1fc41f5aa.txt
#  extracting: valid/labels/2013-04-14_12_15_06_jpg.rf.4a195916233cf845669f4c24e2e90832.txt
#  extracting: valid/labels/2013-04-14_12_20_06_jpg.rf.308008c4dc3e6973554289afa39d8890.txt
#  extracting: valid/labels/2013-04-14_12_30_07_jpg.rf.35caa9c8833525dbcc57d71314f0acd8.txt
#  extracting: valid/labels/2013-04-14_12_40_07_jpg.rf.9ecf43da11e398e652dd521551151c02.txt
#  extracting: valid/labels/2013-04-14_12_50_07_jpg.rf.022c88ebb6b6b9ed55b63b5b222f1782.txt
#  extracting: valid/labels/2013-04-14_13_20_08_jpg.rf.87a7b3ecbda57d16facf0ea3ccd0b04c.txt
#  extracting: valid/labels/2013-04-14_13_25_08_jpg.rf.72e5bc025db14d22c44f13847e05abd3.txt
#  extracting: valid/labels/2013-04-14_13_50_08_jpg.rf.b0ee775ddf2cfc2c4c409c9abca7f668.txt
#  extracting: valid/labels/2013-04-14_13_55_08_jpg.rf.aae5fe0b263f39ed43a723f016dd7782.txt
#  extracting: valid/labels/2013-04-14_14_05_08_jpg.rf.1dd5d7fab9e63dfb332dc23387315038.txt
#  extracting: valid/labels/2013-04-14_14_30_09_jpg.rf.14a199e9b26e46890ca87d8dcb8b9c8d.txt
#  extracting: valid/labels/2013-04-14_14_55_09_jpg.rf.35b7515943ad8f4eb1f21b470d3f7d38.txt
#  extracting: valid/labels/2013-04-14_15_05_10_jpg.rf.bbc2e5a020fc4ea65cf07af2103b33f0.txt
#  extracting: valid/labels/2013-04-14_15_50_10_jpg.rf.99bf6d05e15af2e57b53474a7c9ab056.txt
#  extracting: valid/labels/2013-04-14_16_30_11_jpg.rf.79f5a9a37117898ff8e495587326b165.txt
#  extracting: valid/labels/2013-04-14_16_50_11_jpg.rf.15e39b9931611791e62b6d837c5766a1.txt
#  extracting: valid/labels/2013-04-14_17_50_13_jpg.rf.e45d2388ce849a0196807ee4c06aa195.txt
#  extracting: valid/labels/2013-04-14_17_55_13_jpg.rf.f242f4401bc3b6b7d08b2b291c13acc1.txt
#  extracting: valid/labels/2013-04-15_06_50_01_jpg.rf.df24b334129cb39f81fee8e34b050dd3.txt
#  extracting: valid/labels/2013-04-15_08_30_02_jpg.rf.7a47251772bc6d52af24f5a0f816332a.txt
#  extracting: valid/labels/2013-04-15_08_35_02_jpg.rf.4da965b032477472738df548aa095eb0.txt
#  extracting: valid/labels/2013-04-15_09_20_03_jpg.rf.c133f91a13e893cd0e867dab43d57f98.txt
#  extracting: valid/labels/2013-04-15_09_25_03_jpg.rf.b64555878e8a96ef6fda448fb606567a.txt
#  extracting: valid/labels/2013-04-15_09_35_04_jpg.rf.003783037bb7be6c48aae14d038666ef.txt
#  extracting: valid/labels/2013-04-15_09_55_04_jpg.rf.beed2cf1f67eeeefc484d36598c4d63c.txt
#  extracting: valid/labels/2013-04-15_10_45_05_jpg.rf.9d87a226f7f87c6eec17cbcbb38c02c8.txt
#  extracting: valid/labels/2013-04-15_10_50_05_jpg.rf.27954aece8cfbfd4ff400a8b3eec0de9.txt
#  extracting: valid/labels/2013-04-15_11_05_05_jpg.rf.bbc4fb2750da3b825326370bc8ce230b.txt
#  extracting: valid/labels/2013-04-15_11_20_05_jpg.rf.57618ae3b0983ab805f5949f1adb61a0.txt
#  extracting: valid/labels/2013-04-15_11_25_05_jpg.rf.27ac2555d67bd110ea48e7430fe3ac25.txt
#  extracting: valid/labels/2013-04-15_11_45_06_jpg.rf.618977743ee7f34de800821608c8de33.txt
#  extracting: valid/labels/2013-04-15_12_00_06_jpg.rf.4ac90e21ab6937f41f8da1405b68bc6d.txt
#  extracting: valid/labels/2013-04-15_12_30_07_jpg.rf.e907c7660ad59cd5a13eb688ec375830.txt
#  extracting: valid/labels/2013-04-15_12_35_07_jpg.rf.a51f4a017dc67d6d52ec9395b06400de.txt
#  extracting: valid/labels/2013-04-15_14_35_09_jpg.rf.ff8c95a4ca2a76b403fe6920ad0e03f0.txt
#  extracting: valid/labels/2013-04-15_14_50_09_jpg.rf.db5e59ae164e036c4357174b05f8d4f8.txt
#  extracting: valid/labels/2013-04-15_15_30_10_jpg.rf.bcc6e9caafb1e28ec9733e6c62da7e79.txt
#  extracting: valid/labels/2013-04-15_16_35_11_jpg.rf.a6754d3cc39898c8d51f05478f2c9621.txt
#  extracting: valid/labels/2013-04-15_17_30_12_jpg.rf.426ab342e403c33a4684eba856b3ff2a.txt
#  extracting: valid/labels/2013-04-16_06_40_00_jpg.rf.265c666e3092649df9a75b424bbce16c.txt
#  extracting: valid/labels/2013-04-16_06_50_01_jpg.rf.bc3bfa5f594522dd197195a6c78a0ca0.txt
#  extracting: valid/labels/2013-04-16_07_10_01_jpg.rf.04fafa7f49020e56b0af5f50d42a193e.txt
#  extracting: valid/labels/2013-04-16_07_15_01_jpg.rf.5a1fa115415d6bf0a2927b51c639e07c.txt
#  extracting: valid/labels/2013-04-16_07_25_01_jpg.rf.0bf91675bc2b2327a7efa840f6b12aa4.txt
#  extracting: valid/labels/2013-04-16_07_40_01_jpg.rf.01c9dc5641bdffdcd6b30bedbe606825.txt
#  extracting: valid/labels/2013-04-16_07_50_02_jpg.rf.1c1601ae5561a457337a3ad9ae0c4720.txt
#  extracting: valid/labels/2013-04-16_08_45_03_jpg.rf.d7ea71daa943da993fe76a5ab5361d88.txt
#  extracting: valid/labels/2013-04-16_09_45_04_jpg.rf.64f9520065035297a2979f198392d136.txt
#  extracting: valid/labels/2013-04-16_09_55_04_jpg.rf.feb6f5d0adb97b72f61aab821d25c9a4.txt
#  extracting: valid/labels/2013-04-16_10_00_04_jpg.rf.00c9af1833d1d2f6634f903f5f080f74.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls -l
# Out:
# total 32
# -rw-r--r-- 1 root root   91 Jan  5 21:45 data.yaml
# drwx------ 5 root root 4096 Feb  2 06:07 drive
# -rw-r--r-- 1 root root 1111 Jan  5 21:45 README.dataset.txt
# -rw-r--r-- 1 root root  403 Jan  5 21:45 README.roboflow.txt
# drwxr-xr-x 1 root root 4096 Jan 20 17:27 sample_data
# drwxr-xr-x 4 root root 4096 Jan  5 21:45 test
# drwxr-xr-x 4 root root 4096 Jan  5 21:45 train
# drwxr-xr-x 4 root root 4096 Jan  5 21:45 valid

# %%
# clone YOLOv5 and reset to a specific git checkpoint that has been verified working
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !git reset --hard 68211f72c99915a15855f7b99bf5d93f5631330f
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 4595 (delta 19), reused 13 (delta 8), pack-reused 4557
# Receiving objects: 100% (4595/4595), 7.47 MiB | 23.46 MiB/s, done.
# Resolving deltas: 100% (3125/3125), done.
# /content/yolov5
# HEAD is now at 68211f7 FROM nvcr.io/nvidia/pytorch:20.10-py3 (#1553)

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
from utils.google_utils import gdrive_download  # to download models/datasets
# Out:
#      |████████████████████████████████| 645kB 9.5MB/s

# %%
# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %% [markdown]
# # Download Correctly Formatted Custom Dataset
#
# We'll download our dataset from Roboflow. Use the "**YOLOv5 PyTorch**" export format. Note that the Ultralytics implementation calls for a YAML file defining where your training and test data is. The Roboflow export also writes this format for us.
#
# To get your data into Roboflow, follow the [Getting Started Guide](https://blog.roboflow.ai/getting-started-with-roboflow/).

# %% [markdown]
# ![YOLOv5 PyTorch export](https://i.imgur.com/5vr9G2u.png)

# %%
# Export code snippet and paste here
# %cd /content
# Out:
# /content

# %%
# %cd /content
# Out:
# /content

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 2
# names: ['space-empty', 'space-occupied']

# %% [markdown]
# # Define Model Configuration and Architecture
#
# We will write a yaml script that defines the parameters for our model like the number of classes, anchors, and each layer.
#
# You do not need to edit these cells, but you may.

# %%
# define number of classes based on YAML
import yaml
with open("data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
#this is the model configuration we will use for our tutorial 
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
####Optional Temp Fix###
#if during training, you get a missing labels error, here is a fix for the data loader

# %%
# temp fix for image_weights=opt.image_weights error, see: https://github.com/ultralytics/yolov5/issues/1550
# %%writefile /content/yolov5/utils/train.py
import argparse
import logging
import math
import os
import random
import time
from pathlib import Path
from warnings import warn

import numpy as np
import torch.distributed as dist
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.utils.data
import yaml
from torch.cuda import amp
from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm

import test  # import test.py to get mAP after each epoch
from models.yolo import Model
from utils.autoanchor import check_anchors
from utils.datasets import create_dataloader
from utils.general import labels_to_class_weights, increment_path, labels_to_image_weights, init_seeds, \
    fitness, strip_optimizer, get_latest_run, check_dataset, check_file, check_git_status, check_img_size, \
    print_mutation, set_logging
from utils.google_utils import attempt_download
from utils.loss import compute_loss
from utils.plots import plot_images, plot_labels, plot_results, plot_evolution
from utils.torch_utils import ModelEMA, select_device, intersect_dicts, torch_distributed_zero_first

logger = logging.getLogger(__name__)

try:
    import wandb
except ImportError:
    wandb = None
    logger.info("Install Weights & Biases for experiment logging via 'pip install wandb' (recommended)")


def train(hyp, opt, device, tb_writer=None, wandb=None):
    logger.info(f'Hyperparameters {hyp}')
    save_dir, epochs, batch_size, total_batch_size, weights, rank = \
        Path(opt.save_dir), opt.epochs, opt.batch_size, opt.total_batch_size, opt.weights, opt.global_rank

    # Directories
    wdir = save_dir / 'weights'
    wdir.mkdir(parents=True, exist_ok=True)  # make dir
    last = wdir / 'last.pt'
    best = wdir / 'best.pt'
    results_file = save_dir / 'results.txt'

    # Save run settings
    with open(save_dir / 'hyp.yaml', 'w') as f:
        yaml.dump(hyp, f, sort_keys=False)
    with open(save_dir / 'opt.yaml', 'w') as f:
        yaml.dump(vars(opt), f, sort_keys=False)

    # Configure
    plots = not opt.evolve  # create plots
    cuda = device.type != 'cpu'
    init_seeds(2 + rank)
    with open(opt.data) as f:
        data_dict = yaml.load(f, Loader=yaml.FullLoader)  # data dict
    with torch_distributed_zero_first(rank):
        check_dataset(data_dict)  # check
    train_path = data_dict['train']
    test_path = data_dict['val']
    nc, names = (1, ['item']) if opt.single_cls else (int(data_dict['nc']), data_dict['names'])  # number classes, names
    assert len(names) == nc, '%g names found for nc=%g dataset in %s' % (len(names), nc, opt.data)  # check

    # Model
    pretrained = weights.endswith('.pt')
    if pretrained:
        with torch_distributed_zero_first(rank):
            attempt_download(weights)  # download if not found locally
        ckpt = torch.load(weights, map_location=device)  # load checkpoint
        if hyp.get('anchors'):
            ckpt['model'].yaml['anchors'] = round(hyp['anchors'])  # force autoanchor
        model = Model(opt.cfg or ckpt['model'].yaml, ch=3, nc=nc).to(device)  # create
        exclude = ['anchor'] if opt.cfg or hyp.get('anchors') else []  # exclude keys
        state_dict = ckpt['model'].float().state_dict()  # to FP32
        state_dict = intersect_dicts(state_dict, model.state_dict(), exclude=exclude)  # intersect
        model.load_state_dict(state_dict, strict=False)  # load
        logger.info('Transferred %g/%g items from %s' % (len(state_dict), len(model.state_dict()), weights))  # report
    else:
        model = Model(opt.cfg, ch=3, nc=nc).to(device)  # create

    # Freeze
    freeze = []  # parameter names to freeze (full or partial)
    for k, v in model.named_parameters():
        v.requires_grad = True  # train all layers
        if any(x in k for x in freeze):
            print('freezing %s' % k)
            v.requires_grad = False

    # Optimizer
    nbs = 64  # nominal batch size
    accumulate = max(round(nbs / total_batch_size), 1)  # accumulate loss before optimizing
    hyp['weight_decay'] *= total_batch_size * accumulate / nbs  # scale weight_decay

    pg0, pg1, pg2 = [], [], []  # optimizer parameter groups
    for k, v in model.named_modules():
        if hasattr(v, 'bias') and isinstance(v.bias, nn.Parameter):
            pg2.append(v.bias)  # biases
        if isinstance(v, nn.BatchNorm2d):
            pg0.append(v.weight)  # no decay
        elif hasattr(v, 'weight') and isinstance(v.weight, nn.Parameter):
            pg1.append(v.weight)  # apply decay

    if opt.adam:
        optimizer = optim.Adam(pg0, lr=hyp['lr0'], betas=(hyp['momentum'], 0.999))  # adjust beta1 to momentum
    else:
        optimizer = optim.SGD(pg0, lr=hyp['lr0'], momentum=hyp['momentum'], nesterov=True)

    optimizer.add_param_group({'params': pg1, 'weight_decay': hyp['weight_decay']})  # add pg1 with weight_decay
    optimizer.add_param_group({'params': pg2})  # add pg2 (biases)
    logger.info('Optimizer groups: %g .bias, %g conv.weight, %g other' % (len(pg2), len(pg1), len(pg0)))
    del pg0, pg1, pg2

    # Scheduler https://arxiv.org/pdf/1812.01187.pdf
    # https://pytorch.org/docs/stable/_modules/torch/optim/lr_scheduler.html#OneCycleLR
    lf = lambda x: ((1 + math.cos(x * math.pi / epochs)) / 2) * (1 - hyp['lrf']) + hyp['lrf']  # cosine
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lf)
    # plot_lr_scheduler(optimizer, scheduler, epochs)

    # Logging
    if wandb and wandb.run is None:
        opt.hyp = hyp  # add hyperparameters
        wandb_run = wandb.init(config=opt, resume="allow",
                               project='YOLOv5' if opt.project == 'runs/train' else Path(opt.project).stem,
                               name=save_dir.stem,
                               id=ckpt.get('wandb_id') if 'ckpt' in locals() else None)

    # Resume
    start_epoch, best_fitness = 0, 0.0
    if pretrained:
        # Optimizer
        if ckpt['optimizer'] is not None:
            optimizer.load_state_dict(ckpt['optimizer'])
            best_fitness = ckpt['best_fitness']

        # Results
        if ckpt.get('training_results') is not None:
            with open(results_file, 'w') as file:
                file.write(ckpt['training_results'])  # write results.txt

        # Epochs
        start_epoch = ckpt['epoch'] + 1
        if opt.resume:
            assert start_epoch > 0, '%s training to %g epochs is finished, nothing to resume.' % (weights, epochs)
        if epochs < start_epoch:
            logger.info('%s has been trained for %g epochs. Fine-tuning for %g additional epochs.' %
                        (weights, ckpt['epoch'], epochs))
            epochs += ckpt['epoch']  # finetune additional epochs

        del ckpt, state_dict

    # Image sizes
    gs = int(max(model.stride))  # grid size (max stride)
    imgsz, imgsz_test = [check_img_size(x, gs) for x in opt.img_size]  # verify imgsz are gs-multiples

    # DP mode
    if cuda and rank == -1 and torch.cuda.device_count() > 1:
        model = torch.nn.DataParallel(model)

    # SyncBatchNorm
    if opt.sync_bn and cuda and rank != -1:
        model = torch.nn.SyncBatchNorm.convert_sync_batchnorm(model).to(device)
        logger.info('Using SyncBatchNorm()')

    # EMA
    ema = ModelEMA(model) if rank in [-1, 0] else None

    # DDP mode
    if cuda and rank != -1:
        model = DDP(model, device_ids=[opt.local_rank], output_device=opt.local_rank)

    # Trainloader
    dataloader, dataset = create_dataloader(train_path, imgsz, batch_size, gs, opt,
                                            hyp=hyp, augment=True, cache=opt.cache_images, rect=opt.rect, rank=rank,
                                            world_size=opt.world_size, workers=opt.workers)
    mlc = np.concatenate(dataset.labels, 0)[:, 0].max()  # max label class
    nb = len(dataloader)  # number of batches
    assert mlc < nc, 'Label class %g exceeds nc=%g in %s. Possible class labels are 0-%g' % (mlc, nc, opt.data, nc - 1)

    # Process 0
    if rank in [-1, 0]:
        ema.updates = start_epoch * nb // accumulate  # set EMA updates
        testloader = create_dataloader(test_path, imgsz_test, total_batch_size, gs, opt,
                                       hyp=hyp, cache=opt.cache_images and not opt.notest, rect=True,
                                       rank=-1, world_size=opt.world_size, workers=opt.workers)[0]  # testloader

        if not opt.resume:
            labels = np.concatenate(dataset.labels, 0)
            c = torch.tensor(labels[:, 0])  # classes
            # cf = torch.bincount(c.long(), minlength=nc) + 1.  # frequency
            # model._initialize_biases(cf.to(device))
            if plots:
                plot_labels(labels, save_dir=save_dir)
                if tb_writer:
                    tb_writer.add_histogram('classes', c, 0)
                if wandb:
                    wandb.log({"Labels": [wandb.Image(str(x), caption=x.name) for x in save_dir.glob('*labels*.png')]})

            # Anchors
            if not opt.noautoanchor:
                check_anchors(dataset, model=model, thr=hyp['anchor_t'], imgsz=imgsz)

    # Model parameters
    hyp['cls'] *= nc / 80.  # scale coco-tuned hyp['cls'] to current dataset
    model.nc = nc  # attach number of classes to model
    model.hyp = hyp  # attach hyperparameters to model
    model.gr = 1.0  # iou loss ratio (obj_loss = 1.0 or iou)
    model.class_weights = labels_to_class_weights(dataset.labels, nc).to(device)  # attach class weights
    model.names = names

    # Start training
    t0 = time.time()
    nw = max(round(hyp['warmup_epochs'] * nb), 1000)  # number of warmup iterations, max(3 epochs, 1k iterations)
    # nw = min(nw, (epochs - start_epoch) / 2 * nb)  # limit warmup to < 1/2 of training
    maps = np.zeros(nc)  # mAP per class
    results = (0, 0, 0, 0, 0, 0, 0)  # P, R, mAP@.5, mAP@.5-.95, val_loss(box, obj, cls)
    scheduler.last_epoch = start_epoch - 1  # do not move
    scaler = amp.GradScaler(enabled=cuda)
    logger.info('Image sizes %g train, %g test\n'
                'Using %g dataloader workers\nLogging results to %s\n'
                'Starting training for %g epochs...' % (imgsz, imgsz_test, dataloader.num_workers, save_dir, epochs))
    for epoch in range(start_epoch, epochs):  # epoch ------------------------------------------------------------------
        model.train()

        # Update image weights (optional)
        if opt.image_weights:
            # Generate indices
            if rank in [-1, 0]:
                cw = model.class_weights.cpu().numpy() * (1 - maps) ** 2  # class weights
                iw = labels_to_image_weights(dataset.labels, nc=nc, class_weights=cw)  # image weights
                dataset.indices = random.choices(range(dataset.n), weights=iw, k=dataset.n)  # rand weighted idx
            # Broadcast if DDP
            if rank != -1:
                indices = (torch.tensor(dataset.indices) if rank == 0 else torch.zeros(dataset.n)).int()
                dist.broadcast(indices, 0)
                if rank != 0:
                    dataset.indices = indices.cpu().numpy()

        # Update mosaic border
        # b = int(random.uniform(0.25 * imgsz, 0.75 * imgsz + gs) // gs * gs)
        # dataset.mosaic_border = [b - imgsz, -b]  # height, width borders

        mloss = torch.zeros(4, device=device)  # mean losses
        if rank != -1:
            dataloader.sampler.set_epoch(epoch)
        pbar = enumerate(dataloader)
        logger.info(('\n' + '%10s' * 8) % ('Epoch', 'gpu_mem', 'box', 'obj', 'cls', 'total', 'targets', 'img_size'))
        if rank in [-1, 0]:
            pbar = tqdm(pbar, total=nb)  # progress bar
        optimizer.zero_grad()
        for i, (imgs, targets, paths, _) in pbar:  # batch -------------------------------------------------------------
            ni = i + nb * epoch  # number integrated batches (since train start)
            imgs = imgs.to(device, non_blocking=True).float() / 255.0  # uint8 to float32, 0-255 to 0.0-1.0

            # Warmup
            if ni <= nw:
                xi = [0, nw]  # x interp
                # model.gr = np.interp(ni, xi, [0.0, 1.0])  # iou loss ratio (obj_loss = 1.0 or iou)
                accumulate = max(1, np.interp(ni, xi, [1, nbs / total_batch_size]).round())
                for j, x in enumerate(optimizer.param_groups):
                    # bias lr falls from 0.1 to lr0, all other lrs rise from 0.0 to lr0
                    x['lr'] = np.interp(ni, xi, [hyp['warmup_bias_lr'] if j == 2 else 0.0, x['initial_lr'] * lf(epoch)])
                    if 'momentum' in x:
                        x['momentum'] = np.interp(ni, xi, [hyp['warmup_momentum'], hyp['momentum']])

            # Multi-scale
            if opt.multi_scale:
                sz = random.randrange(imgsz * 0.5, imgsz * 1.5 + gs) // gs * gs  # size
                sf = sz / max(imgs.shape[2:])  # scale factor
                if sf != 1:
                    ns = [math.ceil(x * sf / gs) * gs for x in imgs.shape[2:]]  # new shape (stretched to gs-multiple)
                    imgs = F.interpolate(imgs, size=ns, mode='bilinear', align_corners=False)

            # Forward
            with amp.autocast(enabled=cuda):
                pred = model(imgs)  # forward
                loss, loss_items = compute_loss(pred, targets.to(device), model)  # loss scaled by batch_size
                if rank != -1:
                    loss *= opt.world_size  # gradient averaged between devices in DDP mode

            # Backward
            scaler.scale(loss).backward()

            # Optimize
            if ni % accumulate == 0:
                scaler.step(optimizer)  # optimizer.step
                scaler.update()
                optimizer.zero_grad()
                if ema:
                    ema.update(model)

            # Print
            if rank in [-1, 0]:
                mloss = (mloss * i + loss_items) / (i + 1)  # update mean losses
                mem = '%.3gG' % (torch.cuda.memory_reserved() / 1E9 if torch.cuda.is_available() else 0)  # (GB)
                s = ('%10s' * 2 + '%10.4g' * 6) % (
                    '%g/%g' % (epoch, epochs - 1), mem, *mloss, targets.shape[0], imgs.shape[-1])
                pbar.set_description(s)

                # Plot
                if plots and ni < 3:
                    f = save_dir / f'train_batch{ni}.jpg'  # filename
                    plot_images(images=imgs, targets=targets, paths=paths, fname=f)
                    # if tb_writer:
                    #     tb_writer.add_image(f, result, dataformats='HWC', global_step=epoch)
                    #     tb_writer.add_graph(model, imgs)  # add model to tensorboard
                elif plots and ni == 3 and wandb:
                    wandb.log({"Mosaics": [wandb.Image(str(x), caption=x.name) for x in save_dir.glob('train*.jpg')]})

            # end batch ------------------------------------------------------------------------------------------------
        # end epoch ----------------------------------------------------------------------------------------------------

        # Scheduler
        lr = [x['lr'] for x in optimizer.param_groups]  # for tensorboard
        scheduler.step()

        # DDP process 0 or single-GPU
        if rank in [-1, 0]:
            # mAP
            if ema:
                ema.update_attr(model, include=['yaml', 'nc', 'hyp', 'gr', 'names', 'stride'])
            final_epoch = epoch + 1 == epochs
            if not opt.notest or final_epoch:  # Calculate mAP
                results, maps, times = test.test(opt.data,
                                                 batch_size=total_batch_size,
                                                 imgsz=imgsz_test,
                                                 model=ema.ema,
                                                 single_cls=opt.single_cls,
                                                 dataloader=testloader,
                                                 save_dir=save_dir,
                                                 plots=plots and final_epoch,
                                                 log_imgs=opt.log_imgs if wandb else 0)

            # Write
            with open(results_file, 'a') as f:
                f.write(s + '%10.4g' * 7 % results + '\n')  # P, R, mAP@.5, mAP@.5-.95, val_loss(box, obj, cls)
            if len(opt.name) and opt.bucket:
                os.system('gsutil cp %s gs://%s/results/results%s.txt' % (results_file, opt.bucket, opt.name))

            # Log
            tags = ['train/box_loss', 'train/obj_loss', 'train/cls_loss',  # train loss
                    'metrics/precision', 'metrics/recall', 'metrics/mAP_0.5', 'metrics/mAP_0.5:0.95',
                    'val/box_loss', 'val/obj_loss', 'val/cls_loss',  # val loss
                    'x/lr0', 'x/lr1', 'x/lr2']  # params
            for x, tag in zip(list(mloss[:-1]) + list(results) + lr, tags):
                if tb_writer:
                    tb_writer.add_scalar(tag, x, epoch)  # tensorboard
                if wandb:
                    wandb.log({tag: x})  # W&B

            # Update best mAP
            fi = fitness(np.array(results).reshape(1, -1))  # weighted combination of [P, R, mAP@.5, mAP@.5-.95]
            if fi > best_fitness:
                best_fitness = fi

            # Save model
            save = (not opt.nosave) or (final_epoch and not opt.evolve)
            if save:
                with open(results_file, 'r') as f:  # create checkpoint
                    ckpt = {'epoch': epoch,
                            'best_fitness': best_fitness,
                            'training_results': f.read(),
                            'model': ema.ema,
                            'optimizer': None if final_epoch else optimizer.state_dict(),
                            'wandb_id': wandb_run.id if wandb else None}

                # Save last, best and delete
                torch.save(ckpt, last)
                if best_fitness == fi:
                    torch.save(ckpt, best)
                del ckpt
        # end epoch ----------------------------------------------------------------------------------------------------
    # end training

    if rank in [-1, 0]:
        # Strip optimizers
        n = opt.name if opt.name.isnumeric() else ''
        fresults, flast, fbest = save_dir / f'results{n}.txt', wdir / f'last{n}.pt', wdir / f'best{n}.pt'
        for f1, f2 in zip([wdir / 'last.pt', wdir / 'best.pt', results_file], [flast, fbest, fresults]):
            if f1.exists():
                os.rename(f1, f2)  # rename
                if str(f2).endswith('.pt'):  # is *.pt
                    strip_optimizer(f2)  # strip optimizer
                    os.system('gsutil cp %s gs://%s/weights' % (f2, opt.bucket)) if opt.bucket else None  # upload
        # Finish
        if plots:
            plot_results(save_dir=save_dir)  # save as results.png
            if wandb:
                files = ['results.png', 'precision_recall_curve.png', 'confusion_matrix.png']
                wandb.log({"Results": [wandb.Image(str(save_dir / f), caption=f) for f in files
                                       if (save_dir / f).exists()]})
        logger.info('%g epochs completed in %.3f hours.\n' % (epoch - start_epoch + 1, (time.time() - t0) / 3600))
    else:
        dist.destroy_process_group()

    wandb.run.finish() if wandb and wandb.run else None
    torch.cuda.empty_cache()
    return results


if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--weights', type=str, default='yolov5s.pt', help='initial weights path')
    parser.add_argument('--cfg', type=str, default='', help='model.yaml path')
    parser.add_argument('--data', type=str, default='data/coco128.yaml', help='data.yaml path')
    parser.add_argument('--hyp', type=str, default='data/hyp.scratch.yaml', help='hyperparameters path')
    parser.add_argument('--epochs', type=int, default=300)
    parser.add_argument('--batch-size', type=int, default=16, help='total batch size for all GPUs')
    parser.add_argument('--img-size', nargs='+', type=int, default=[640, 640], help='[train, test] image sizes')
    parser.add_argument('--rect', action='store_true', help='rectangular training')
    parser.add_argument('--resume', nargs='?', const=True, default=False, help='resume most recent training')
    parser.add_argument('--nosave', action='store_true', help='only save final checkpoint')
    parser.add_argument('--notest', action='store_true', help='only test final epoch')
    parser.add_argument('--noautoanchor', action='store_true', help='disable autoanchor check')
    parser.add_argument('--evolve', action='store_true', help='evolve hyperparameters')
    parser.add_argument('--bucket', type=str, default='', help='gsutil bucket')
    parser.add_argument('--cache-images', action='store_true', help='cache images for faster training')
    parser.add_argument('--image-weights', action='store_true', help='use weighted image selection for training')
    parser.add_argument('--device', default='', help='cuda device, i.e. 0 or 0,1,2,3 or cpu')
    parser.add_argument('--multi-scale', action='store_true', help='vary img-size +/- 50%%')
    parser.add_argument('--single-cls', action='store_true', help='train as single-class dataset')
    parser.add_argument('--adam', action='store_true', help='use torch.optim.Adam() optimizer')
    parser.add_argument('--sync-bn', action='store_true', help='use SyncBatchNorm, only available in DDP mode')
    parser.add_argument('--local_rank', type=int, default=-1, help='DDP parameter, do not modify')
    parser.add_argument('--log-imgs', type=int, default=16, help='number of images for W&B logging, max 100')
    parser.add_argument('--workers', type=int, default=8, help='maximum number of dataloader workers')
    parser.add_argument('--project', default='runs/train', help='save to project/name')
    parser.add_argument('--name', default='exp', help='save to project/name')
    parser.add_argument('--exist-ok', action='store_true', help='existing project/name ok, do not increment')
    opt = parser.parse_args()

    # Set DDP variables
    opt.total_batch_size = opt.batch_size
    opt.world_size = int(os.environ['WORLD_SIZE']) if 'WORLD_SIZE' in os.environ else 1
    opt.global_rank = int(os.environ['RANK']) if 'RANK' in os.environ else -1
    set_logging(opt.global_rank)
    if opt.global_rank in [-1, 0]:
        check_git_status()

    # Resume
    if opt.resume:  # resume an interrupted run
        ckpt = opt.resume if isinstance(opt.resume, str) else get_latest_run()  # specified or most recent path
        assert os.path.isfile(ckpt), 'ERROR: --resume checkpoint does not exist'
        with open(Path(ckpt).parent.parent / 'opt.yaml') as f:
            opt = argparse.Namespace(**yaml.load(f, Loader=yaml.FullLoader))  # replace
        opt.cfg, opt.weights, opt.resume = '', ckpt, True
        logger.info('Resuming training from %s' % ckpt)
    else:
        # opt.hyp = opt.hyp or ('hyp.finetune.yaml' if opt.weights else 'hyp.scratch.yaml')
        opt.data, opt.cfg, opt.hyp = check_file(opt.data), check_file(opt.cfg), check_file(opt.hyp)  # check files
        assert len(opt.cfg) or len(opt.weights), 'either --cfg or --weights must be specified'
        opt.img_size.extend([opt.img_size[-1]] * (2 - len(opt.img_size)))  # extend to 2 sizes (train, test)
        opt.name = 'evolve' if opt.evolve else opt.name
        opt.save_dir = increment_path(Path(opt.project) / opt.name, exist_ok=opt.exist_ok | opt.evolve)  # increment run

    # DDP mode
    device = select_device(opt.device, batch_size=opt.batch_size)
    if opt.local_rank != -1:
        assert torch.cuda.device_count() > opt.local_rank
        torch.cuda.set_device(opt.local_rank)
        device = torch.device('cuda', opt.local_rank)
        dist.init_process_group(backend='nccl', init_method='env://')  # distributed backend
        assert opt.batch_size % opt.world_size == 0, '--batch-size must be multiple of CUDA device count'
        opt.batch_size = opt.total_batch_size // opt.world_size

    # Hyperparameters
    with open(opt.hyp) as f:
        hyp = yaml.load(f, Loader=yaml.FullLoader)  # load hyps
        if 'box' not in hyp:
            warn('Compatibility: %s missing "box" which was renamed from "giou" in %s' %
                 (opt.hyp, 'https://github.com/ultralytics/yolov5/pull/1120'))
            hyp['box'] = hyp.pop('giou')

    # Train
    logger.info(opt)
    if not opt.evolve:
        tb_writer = None  # init loggers
        if opt.global_rank in [-1, 0]:
            logger.info(f'Start Tensorboard with "tensorboard --logdir {opt.project}", view at http://localhost:6006/')
            tb_writer = SummaryWriter(opt.save_dir)  # Tensorboard
        train(hyp, opt, device, tb_writer, wandb)

    # Evolve hyperparameters (optional)
    else:
        # Hyperparameter evolution metadata (mutation scale 0-1, lower_limit, upper_limit)
        meta = {'lr0': (1, 1e-5, 1e-1),  # initial learning rate (SGD=1E-2, Adam=1E-3)
                'lrf': (1, 0.01, 1.0),  # final OneCycleLR learning rate (lr0 * lrf)
                'momentum': (0.3, 0.6, 0.98),  # SGD momentum/Adam beta1
                'weight_decay': (1, 0.0, 0.001),  # optimizer weight decay
                'warmup_epochs': (1, 0.0, 5.0),  # warmup epochs (fractions ok)
                'warmup_momentum': (1, 0.0, 0.95),  # warmup initial momentum
                'warmup_bias_lr': (1, 0.0, 0.2),  # warmup initial bias lr
                'box': (1, 0.02, 0.2),  # box loss gain
                'cls': (1, 0.2, 4.0),  # cls loss gain
                'cls_pw': (1, 0.5, 2.0),  # cls BCELoss positive_weight
                'obj': (1, 0.2, 4.0),  # obj loss gain (scale with pixels)
                'obj_pw': (1, 0.5, 2.0),  # obj BCELoss positive_weight
                'iou_t': (0, 0.1, 0.7),  # IoU training threshold
                'anchor_t': (1, 2.0, 8.0),  # anchor-multiple threshold
                'anchors': (2, 2.0, 10.0),  # anchors per output grid (0 to ignore)
                'fl_gamma': (0, 0.0, 2.0),  # focal loss gamma (efficientDet default gamma=1.5)
                'hsv_h': (1, 0.0, 0.1),  # image HSV-Hue augmentation (fraction)
                'hsv_s': (1, 0.0, 0.9),  # image HSV-Saturation augmentation (fraction)
                'hsv_v': (1, 0.0, 0.9),  # image HSV-Value augmentation (fraction)
                'degrees': (1, 0.0, 45.0),  # image rotation (+/- deg)
                'translate': (1, 0.0, 0.9),  # image translation (+/- fraction)
                'scale': (1, 0.0, 0.9),  # image scale (+/- gain)
                'shear': (1, 0.0, 10.0),  # image shear (+/- deg)
                'perspective': (0, 0.0, 0.001),  # image perspective (+/- fraction), range 0-0.001
                'flipud': (1, 0.0, 1.0),  # image flip up-down (probability)
                'fliplr': (0, 0.0, 1.0),  # image flip left-right (probability)
                'mosaic': (1, 0.0, 1.0),  # image mixup (probability)
                'mixup': (1, 0.0, 1.0)}  # image mixup (probability)

        assert opt.local_rank == -1, 'DDP mode not implemented for --evolve'
        opt.notest, opt.nosave = True, True  # only test/save final epoch
        # ei = [isinstance(x, (int, float)) for x in hyp.values()]  # evolvable indices
        yaml_file = Path(opt.save_dir) / 'hyp_evolved.yaml'  # save best result here
        if opt.bucket:
            os.system('gsutil cp gs://%s/evolve.txt .' % opt.bucket)  # download evolve.txt if exists

        for _ in range(300):  # generations to evolve
            if Path('evolve.txt').exists():  # if evolve.txt exists: select best hyps and mutate
                # Select parent(s)
                parent = 'single'  # parent selection method: 'single' or 'weighted'
                x = np.loadtxt('evolve.txt', ndmin=2)
                n = min(5, len(x))  # number of previous results to consider
                x = x[np.argsort(-fitness(x))][:n]  # top n mutations
                w = fitness(x) - fitness(x).min()  # weights
                if parent == 'single' or len(x) == 1:
                    # x = x[random.randint(0, n - 1)]  # random selection
                    x = x[random.choices(range(n), weights=w)[0]]  # weighted selection
                elif parent == 'weighted':
                    x = (x * w.reshape(n, 1)).sum(0) / w.sum()  # weighted combination

                # Mutate
                mp, s = 0.8, 0.2  # mutation probability, sigma
                npr = np.random
                npr.seed(int(time.time()))
                g = np.array([x[0] for x in meta.values()])  # gains 0-1
                ng = len(meta)
                v = np.ones(ng)
                while all(v == 1):  # mutate until a change occurs (prevent duplicates)
                    v = (g * (npr.random(ng) < mp) * npr.randn(ng) * npr.random() * s + 1).clip(0.3, 3.0)
                for i, k in enumerate(hyp.keys()):  # plt.hist(v.ravel(), 300)
                    hyp[k] = float(x[i + 7] * v[i])  # mutate

            # Constrain to limits
            for k, v in meta.items():
                hyp[k] = max(hyp[k], v[1])  # lower limit
                hyp[k] = min(hyp[k], v[2])  # upper limit
                hyp[k] = round(hyp[k], 5)  # significant digits

            # Train mutation
            results = train(hyp.copy(), opt, device, wandb=wandb)

            # Write mutation results
            print_mutation(hyp.copy(), results, yaml_file, opt.bucket)

        # Plot results
        plot_evolution(yaml_file)
        print(f'Hyperparameter evolution complete. Best results saved as: {yaml_file}\n'
              f'Command to train a new model with these hyperparameters: $ python train.py --hyp {yaml_file}')
# Out:
# Writing /content/yolov5/utils/train.py

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 50 --data '../data.yaml' --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/yolov5
# Using torch 1.7.0+cu101 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='./models/custom_yolov5s.yaml', data='../data.yaml', device='', epochs=50, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[416, 416], local_rank=-1, log_imgs=16, multi_scale=False, name='yolov5s_results', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/yolov5s_results', single_cls=False, sync_bn=False, total_batch_size=16, weights='', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2021-02-02 06:09:35.252420: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Hyperparameters {'lr0': 0.01, 'lrf': 0.2, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'warmup_bias_lr': 0.1, 'box': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0}
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7257791 parameters, 7257791 gradients
#
# Optimizer groups: 62 .bias, 70 conv.weight, 59 other
# Scanning '../train/labels' for images and labels... 8691 found, 0 missing, 189 empty, 0 corrupted: 100% 8691/8691 [00:03<00:00, 2377.22it/s]
# New cache created: ../train/labels.cache
# Scanning '../train/labels.cache' for images and labels... 8691 found, 0 missing, 189 empty, 0 corrupted: 100% 8691/8691 [00:00<00:00, 65918076.07it/s]
# Caching images (4.5GB): 100% 8691/8691 [00:49<00:00, 174.23it/s]
# Scanning '../valid/labels' for images and labels... 2483 found, 0 missing, 59 empty, 0 corrupted: 100% 2483/2483 [00:02<00:00, 978.90it/s]
# New cache created: ../valid/labels.cache
# Scanning '../valid/labels.cache' for images and labels... 2483 found, 0 missing, 59 empty, 0 corrupted: 100% 2483/2483 [00:00<00:00, 19989360.52it/s]
# Caching images (1.3GB): 100% 2483/2483 [00:19<00:00, 127.05it/s]
# NumExpr defaulting to 2 threads.
#
# Analyzing anchors... anchors/target = 5.39, Best Possible Recall (BPR) = 1.0000
# Image sizes 416 train, 416 test
# Using 2 dataloader workers
# Logging results to runs/train/yolov5s_results
# Starting training for 50 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       0/49     1.86G    0.1035    0.6021   0.02403    0.7296       235       416: 100% 544/544 [01:30<00:00,  5.98it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:52<00:00,  2.99it/s]
#                  all    2.48e+03    1.43e+05      0.0988        0.28       0.138      0.0338
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       1/49     1.94G   0.08329     0.468   0.01158    0.5629        93       416: 100% 544/544 [01:23<00:00,  6.49it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:43<00:00,  3.58it/s]
#                  all    2.48e+03    1.43e+05       0.281       0.978       0.868        0.39
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       2/49     1.94G   0.07423    0.4259  0.007982    0.5081       245       416: 100% 544/544 [01:21<00:00,  6.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:41<00:00,  3.79it/s]
#                  all    2.48e+03    1.43e+05       0.351       0.986        0.93       0.468
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       3/49     1.94G   0.06817    0.4012  0.007314    0.4767       122       416: 100% 544/544 [01:21<00:00,  6.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:39<00:00,  3.97it/s]
#                  all    2.48e+03    1.43e+05       0.412       0.996       0.962       0.581
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       4/49     1.94G   0.06365    0.3716    0.0064    0.4417       128       416: 100% 544/544 [01:21<00:00,  6.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:38<00:00,  4.02it/s]
#                  all    2.48e+03    1.43e+05       0.451       0.997        0.97       0.633
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       5/49     1.94G   0.06135    0.3575  0.006334    0.4252       322       416: 100% 544/544 [01:21<00:00,  6.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:38<00:00,  4.04it/s]
#                  all    2.48e+03    1.43e+05       0.476       0.993       0.971       0.671
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       6/49     1.94G   0.05961    0.3481  0.006058    0.4138       337       416: 100% 544/544 [01:21<00:00,  6.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:37<00:00,  4.11it/s]
#                  all    2.48e+03    1.43e+05       0.479       0.993       0.972       0.694
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       7/49     1.94G   0.05819    0.3415  0.005881    0.4055       184       416: 100% 544/544 [01:21<00:00,  6.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:37<00:00,  4.15it/s]
#                  all    2.48e+03    1.43e+05        0.49       0.998       0.975        0.71
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       8/49     1.94G   0.05704    0.3315  0.005776    0.3943       242       416: 100% 544/544 [01:20<00:00,  6.73it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:37<00:00,  4.15it/s]
#                  all    2.48e+03    1.43e+05       0.488       0.995       0.975       0.732
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       9/49     1.94G   0.05638    0.3275  0.005643    0.3895       230       416: 100% 544/544 [01:21<00:00,  6.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:37<00:00,  4.17it/s]
#                  all    2.48e+03    1.43e+05       0.492       0.997       0.977       0.744
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      10/49     1.94G   0.05559    0.3219  0.005533     0.383       165       416: 100% 544/544 [01:22<00:00,  6.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:37<00:00,  4.11it/s]
#                  all    2.48e+03    1.43e+05       0.506       0.991       0.977        0.75
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      11/49     1.94G   0.05496    0.3184  0.005417    0.3788       157       416: 100% 544/544 [01:21<00:00,  6.68it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:37<00:00,  4.18it/s]
#                  all    2.48e+03    1.43e+05         0.5       0.993       0.976       0.742
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      12/49     1.94G   0.05448    0.3168  0.005338    0.3766       315       416: 100% 544/544 [01:21<00:00,  6.66it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:37<00:00,  4.15it/s]
#                  all    2.48e+03    1.43e+05       0.526        0.99       0.977       0.773
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      13/49     1.94G   0.05361     0.309  0.005278    0.3679       266       416: 100% 544/544 [01:21<00:00,  6.65it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:38<00:00,  4.09it/s]
#                  all    2.48e+03    1.43e+05       0.507       0.996       0.978       0.774
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      14/49     1.94G   0.05349    0.3077  0.005481    0.3666       149       416: 100% 544/544 [01:21<00:00,  6.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:37<00:00,  4.18it/s]
#                  all    2.48e+03    1.43e+05       0.526        0.99       0.972       0.777
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      15/49     1.94G   0.05283    0.3003  0.005319    0.3584       139       416: 100% 544/544 [01:20<00:00,  6.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:36<00:00,  4.22it/s]
#                  all    2.48e+03    1.43e+05       0.509       0.997       0.979       0.787
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      16/49     1.94G   0.05263    0.2974  0.005265    0.3553       159       416: 100% 544/544 [01:20<00:00,  6.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 156/156 [00:37<00:00,  4.19it/s]
#                  all    2.48e+03    1.43e+05       0.523       0.992       0.977        0.79
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      17/49     1.94G   0.05228     0.296  0.005173    0.3535       307       416: 100% 544/544 [01:20<00:00,  6.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95:  78% 122/156 [00:28<00:06,  5.06it/s]Traceback (most recent call last):
#   File "train.py", line 492, in <module>
#   File "train.py", line 343, in train
#     log_imgs=opt.log_imgs if wandb else 0)
#   File "/content/yolov5/test.py", line 120, in test
#     output = non_max_suppression(inf_out, conf_thres=conf_thres, iou_thres=iou_thres, labels=lb)
#   File "/content/yolov5/utils/general.py", line 333, in non_max_suppression
#     if i.shape[0] > max_det:  # limit detections
# KeyboardInterrupt
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95:  78% 122/156 [00:28<00:07,  4.27it/s]
# CPU times: user 12.4 s, sys: 2.27 s, total: 14.7 s
# Wall time: 39min 3s

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance

# %% [markdown]
# Training losses and performance metrics are saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`. (If given no name, it defaults to `results.txt`.) The results file is plotted as a png after training completes.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason... 
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)  # view results.png
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-d7ea088d00dd> in <module>()
#       1 # we can also output some older school graphs if the tensor board isn't working for whatever reason...
#       2 from utils.plots import plot_results  # plot results.txt as results.png
# ----> 3 Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)  # view results.png
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1019         self.unconfined = unconfined
#    1020         self.metadata = metadata
# -> 1021         super(Image, self).__init__(data=data, url=url, filename=filename)
#    1022
#    1023         if retina:
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in __init__(self, data, url, filename)
#     611         self.filename = None if filename is None else unicode_type(filename)
#     612
# --> 613         self.reload()
#     614         self._check_data()
#     615
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in reload(self)
#    1041         """Reload the raw data from file or URL."""
#    1042         if self.embed:
# -> 1043             super(Image,self).reload()
#    1044             if self.retina:
#    1045                 self._retina_shape()
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in reload(self)
#     629         """Reload the raw data from file or URL."""
#     630         if self.filename is not None:
# --> 631             with open(self.filename, self._read_flags) as f:
#     632                 self.data = f.read()
#     633         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/yolov5/runs/train/yolov5s_results/results.png'

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/
# Out:
# train/

# %%
# %ls runs/train/yolov5s_results
# Out:
# events.out.tfevents.1612246176.3392a7b07158.289.0  results.txt
# hyp.yaml                                           train_batch0.jpg
# labels_correlogram.png                             train_batch1.jpg
# labels.png                                         train_batch2.jpg
# opt.yaml                                           weights/

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# %cd ./yolov5
# Out:
# [Errno 2] No such file or directory: './yolov5'
# /content/yolov5

# %%
# !python detect.py --weights /content/yolov5/runs/train/yolov5s_results/weights/best.pt --conf 0.3 --source ../test/images
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.3, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../test/images', update=False, view_img=False, weights=['/content/yolov5/runs/train/yolov5s_results/weights/best.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7249215 parameters, 0 gradients
# image 1/1242 /content/test/images/2012-09-11_15_53_00_jpg.rf.8282544a640a23df05bd245a9210e663.jpg: 640x640 47 space-emptys, 75 space-occupieds, Done. (0.012s)
# image 2/1242 /content/test/images/2012-09-11_16_48_36_jpg.rf.4ecc8c87c61680ccc73edc218a2c8d7d.jpg: 640x640 36 space-emptys, 79 space-occupieds, Done. (0.015s)
# image 3/1242 /content/test/images/2012-09-12_06_36_36_jpg.rf.08869047c7e9f62f5ce9334546b52958.jpg: 640x640 110 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 4/1242 /content/test/images/2012-09-12_08_15_53_jpg.rf.025635f821fe24c12ab497efbfd3d35c.jpg: 640x640 10 space-emptys, 118 space-occupieds, Done. (0.012s)
# image 5/1242 /content/test/images/2012-09-12_09_18_46_jpg.rf.d95bc1a314fb384813111f94c25b4ef3.jpg: 640x640 6 space-emptys, 122 space-occupieds, Done. (0.015s)
# image 6/1242 /content/test/images/2012-09-12_10_05_57_jpg.rf.5f9542ab6498fd436eef35d5ac8f5c04.jpg: 640x640 5 space-emptys, 115 space-occupieds, Done. (0.013s)
# image 7/1242 /content/test/images/2012-09-12_11_19_23_jpg.rf.6117980a95928044af18001e3c3bbdb8.jpg: 640x640 21 space-emptys, 89 space-occupieds, Done. (0.012s)
# image 8/1242 /content/test/images/2012-09-12_11_56_00_jpg.rf.041680c3e728940e946ad42134b7362a.jpg: 640x640 44 space-emptys, 73 space-occupieds, Done. (0.014s)
# image 9/1242 /content/test/images/2012-09-12_12_48_19_jpg.rf.eccec03cf08ccc4f50d46b8212b2668f.jpg: 640x640 73 space-emptys, 44 space-occupieds, Done. (0.012s)
# image 10/1242 /content/test/images/2012-09-12_14_12_08_jpg.rf.667489b9945bf933e519cc5c39c3a084.jpg: 640x640 59 space-emptys, 60 space-occupieds, Done. (0.012s)
# image 11/1242 /content/test/images/2012-09-13_06_57_24_jpg.rf.0266dc68a1401a0553bec6affdcfae57.jpg: 640x640 104 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 12/1242 /content/test/images/2012-09-13_08_00_06_jpg.rf.1ea886928664eac762253de57ec7ff2a.jpg: 640x640 14 space-emptys, 107 space-occupieds, Done. (0.012s)
# image 13/1242 /content/test/images/2012-09-13_08_05_23_jpg.rf.ba4af568227bec2356b5946138015b11.jpg: 640x640 15 space-emptys, 108 space-occupieds, Done. (0.012s)
# image 14/1242 /content/test/images/2012-09-13_12_40_23_jpg.rf.e2e788b7bb9853a92ca3b55dae7a17cd.jpg: 640x640 88 space-emptys, 44 space-occupieds, Done. (0.012s)
# image 15/1242 /content/test/images/2012-09-13_13_25_24_jpg.rf.fd17435c075567f752d1aeb5dc085e3f.jpg: 640x640 70 space-emptys, 41 space-occupieds, Done. (0.012s)
# image 16/1242 /content/test/images/2012-09-13_13_35_25_jpg.rf.add202e1d57b07f24a2a6048fd9eb516.jpg: 640x640 71 space-emptys, 47 space-occupieds, Done. (0.012s)
# image 17/1242 /content/test/images/2012-09-13_17_45_35_jpg.rf.a07d5d9e9e4a2e20199f66582222ed36.jpg: 640x640 44 space-emptys, 60 space-occupieds, Done. (0.012s)
# image 18/1242 /content/test/images/2012-09-14_09_21_11_jpg.rf.764ed3c1a9473f0e2f1105afb5a6c824.jpg: 640x640 9 space-emptys, 97 space-occupieds, Done. (0.012s)
# image 19/1242 /content/test/images/2012-09-14_10_16_14_jpg.rf.6742cad49e1cdd4e335875fdf159bc23.jpg: 640x640 8 space-emptys, 96 space-occupieds, Done. (0.012s)
# image 20/1242 /content/test/images/2012-09-14_11_36_17_jpg.rf.0cdece6e4478e6c1ba4308d215080df8.jpg: 640x640 35 space-emptys, 82 space-occupieds, Done. (0.012s)
# image 21/1242 /content/test/images/2012-09-14_11_51_18_jpg.rf.356aaf9a7b058734062e47c43c0fe4f7.jpg: 640x640 42 space-emptys, 82 space-occupieds, Done. (0.012s)
# image 22/1242 /content/test/images/2012-09-14_12_16_19_jpg.rf.7bb3308fceb1708a3ff8fc5f063873be.jpg: 640x640 62 space-emptys, 57 space-occupieds, Done. (0.012s)
# image 23/1242 /content/test/images/2012-09-14_12_36_20_jpg.rf.6d952ef8e3c658fb770e865a87b0b1bb.jpg: 640x640 71 space-emptys, 46 space-occupieds, Done. (0.012s)
# image 24/1242 /content/test/images/2012-09-14_12_41_20_jpg.rf.1e0ca167fd597e71c5fb4053b1a09741.jpg: 640x640 68 space-emptys, 45 space-occupieds, Done. (0.012s)
# image 25/1242 /content/test/images/2012-09-14_13_26_22_jpg.rf.7d32e97a3056d8cc796bc088a7a5d559.jpg: 640x640 70 space-emptys, 41 space-occupieds, Done. (0.012s)
# image 26/1242 /content/test/images/2012-09-14_13_46_23_jpg.rf.2078cfb296bea9b8ca680d7a0388261f.jpg: 640x640 65 space-emptys, 54 space-occupieds, Done. (0.012s)
# image 27/1242 /content/test/images/2012-09-14_14_31_24_jpg.rf.48855e96ad7657c38dea825ce12213a1.jpg: 640x640 41 space-emptys, 74 space-occupieds, Done. (0.012s)
# image 28/1242 /content/test/images/2012-09-14_15_41_27_jpg.rf.ca488c16146f64b4f9fd8b9111863dca.jpg: 640x640 52 space-emptys, 78 space-occupieds, Done. (0.012s)
# image 29/1242 /content/test/images/2012-09-14_16_26_29_jpg.rf.fc42633f9baa59669aeed1cfe8dfbade.jpg: 640x640 43 space-emptys, 81 space-occupieds, Done. (0.013s)
# image 30/1242 /content/test/images/2012-09-15_07_02_01_jpg.rf.079ed65a302f63446ed4f99348787027.jpg: 640x640 107 space-emptys, 4 space-occupieds, Done. (0.014s)
# image 31/1242 /content/test/images/2012-09-15_10_07_09_jpg.rf.5c1e2e6264d8020dfc75498ea228cf51.jpg: 640x640 17 space-emptys, 88 space-occupieds, Done. (0.012s)
# image 32/1242 /content/test/images/2012-09-15_13_22_17_jpg.rf.94befc25527aa771c4dd6d8fc2b049bc.jpg: 640x640 89 space-emptys, 35 space-occupieds, Done. (0.012s)
# image 33/1242 /content/test/images/2012-09-15_14_32_20_jpg.rf.719b200c7c3829236a2572af8d62c8f8.jpg: 640x640 92 space-emptys, 33 space-occupieds, Done. (0.014s)
# image 34/1242 /content/test/images/2012-09-15_14_37_20_jpg.rf.55724bc9827fafd3cc5a804c51479939.jpg: 640x640 92 space-emptys, 36 space-occupieds, Done. (0.012s)
# image 35/1242 /content/test/images/2012-09-15_14_57_21_jpg.rf.986866692e7f396a959b663c817a9f17.jpg: 640x640 98 space-emptys, 30 space-occupieds, Done. (0.012s)
# image 36/1242 /content/test/images/2012-09-15_15_02_21_jpg.rf.499320b915576d670e45290c4b27bb0f.jpg: 640x640 100 space-emptys, 30 space-occupieds, Done. (0.012s)
# image 37/1242 /content/test/images/2012-09-16_07_02_57_jpg.rf.ab0e81f26cb3da260e9e94e3efd22b89.jpg: 640x640 101 space-emptys, 2 space-occupieds, Done. (0.012s)
# image 38/1242 /content/test/images/2012-09-16_07_47_58_jpg.rf.cae551291a57636e8e960e2303e93e91.jpg: 640x640 102 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 39/1242 /content/test/images/2012-09-16_10_23_05_jpg.rf.5a8cdf3847878b3dcc56731a819f7969.jpg: 640x640 115 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 40/1242 /content/test/images/2012-09-16_10_33_05_jpg.rf.d46b86ecd36133810505cac5458584a2.jpg: 640x640 113 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 41/1242 /content/test/images/2012-09-16_10_48_06_jpg.rf.aa55ec7b4aec3bf42171a95bbc229f85.jpg: 640x640 110 space-emptys, 4 space-occupieds, Done. (0.013s)
# image 42/1242 /content/test/images/2012-09-16_10_53_06_jpg.rf.36aa60d617cd59bc92ee7e6467b1990b.jpg: 640x640 112 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 43/1242 /content/test/images/2012-09-16_12_28_10_jpg.rf.8fba15e8a2850ccdcb0a9d6d7291e575.jpg: 640x640 110 space-emptys, 4 space-occupieds, Done. (0.012s)
# image 44/1242 /content/test/images/2012-09-16_13_03_11_jpg.rf.102560f88885428dd49ccb05deaf2cd0.jpg: 640x640 109 space-emptys, 2 space-occupieds, Done. (0.012s)
# image 45/1242 /content/test/images/2012-09-16_14_08_14_jpg.rf.632a6da7d8e089d4fc9260725a7e01c6.jpg: 640x640 112 space-emptys, 4 space-occupieds, Done. (0.012s)
# image 46/1242 /content/test/images/2012-09-16_14_18_15_jpg.rf.c539385566376a920ba452e3d2ac990a.jpg: 640x640 110 space-emptys, 5 space-occupieds, Done. (0.012s)
# image 47/1242 /content/test/images/2012-09-16_14_33_15_jpg.rf.046655b18010a33db88f1b78223b71fa.jpg: 640x640 111 space-emptys, 5 space-occupieds, Done. (0.012s)
# image 48/1242 /content/test/images/2012-09-16_14_58_16_jpg.rf.3320031d2613d580d48c4bbcbac72694.jpg: 640x640 111 space-emptys, 4 space-occupieds, Done. (0.012s)
# image 49/1242 /content/test/images/2012-09-16_15_28_17_jpg.rf.68d85df13a52e9eaa08a6311695fff1a.jpg: 640x640 127 space-emptys, 7 space-occupieds, Done. (0.012s)
# image 50/1242 /content/test/images/2012-09-16_16_03_19_jpg.rf.2f750c50c8a9b11dc5c110172ab064fc.jpg: 640x640 119 space-emptys, 8 space-occupieds, Done. (0.012s)
# image 51/1242 /content/test/images/2012-09-16_16_48_20_jpg.rf.4ee4e6ff09f4b8ea2cfaffadb3ee17c0.jpg: 640x640 108 space-emptys, 4 space-occupieds, Done. (0.012s)
# image 52/1242 /content/test/images/2012-09-16_17_43_22_jpg.rf.1a60372dec1eed5cf7b04d863b37bffb.jpg: 640x640 103 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 53/1242 /content/test/images/2012-09-17_06_03_49_jpg.rf.7665f6ed5ca4df2ba0d12d6f3df4a95b.jpg: 640x640 101 space-emptys, 1 space-occupieds, Done. (0.013s)
# image 54/1242 /content/test/images/2012-09-17_06_08_49_jpg.rf.b1e8179c5716c625dd71c404e4b29beb.jpg: 640x640 108 space-emptys, 1 space-occupieds, Done. (0.013s)
# image 55/1242 /content/test/images/2012-09-17_06_23_50_jpg.rf.23c7932cda3bf652680e970ae11fe348.jpg: 640x640 108 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 56/1242 /content/test/images/2012-09-17_06_38_50_jpg.rf.2c16970e7a609722934a3488a87988a8.jpg: 640x640 105 space-emptys, 2 space-occupieds, Done. (0.012s)
# image 57/1242 /content/test/images/2012-09-17_07_28_52_jpg.rf.6eaef63caea138fd75e7a92426c6219d.jpg: 640x640 73 space-emptys, 33 space-occupieds, Done. (0.012s)
# image 58/1242 /content/test/images/2012-09-17_10_14_00_jpg.rf.f5a76adda8d5da49191e77c8556f9bfc.jpg: 640x640 6 space-emptys, 118 space-occupieds, Done. (0.012s)
# image 59/1242 /content/test/images/2012-09-17_10_29_00_jpg.rf.dd5767f5257d796b54e118ea24472273.jpg: 640x640 11 space-emptys, 111 space-occupieds, Done. (0.012s)
# image 60/1242 /content/test/images/2012-09-17_12_29_06_jpg.rf.52b6b85f338407b7647edd791f4e67d7.jpg: 640x640 66 space-emptys, 53 space-occupieds, Done. (0.013s)
# image 61/1242 /content/test/images/2012-09-17_12_34_06_jpg.rf.ea577532951f394a5ccb4a19292799ce.jpg: 640x640 66 space-emptys, 50 space-occupieds, Done. (0.012s)
# image 62/1242 /content/test/images/2012-09-17_13_14_08_jpg.rf.e700bbc3e6a52913a1e7baa8767a53f8.jpg: 640x640 74 space-emptys, 47 space-occupieds, Done. (0.012s)
# image 63/1242 /content/test/images/2012-09-17_14_29_11_jpg.rf.a132e639e63da7002e005e7008fb85af.jpg: 640x640 44 space-emptys, 85 space-occupieds, Done. (0.012s)
# image 64/1242 /content/test/images/2012-09-17_14_59_13_jpg.rf.19295fd86ac2679aa0f2e22d94af2d64.jpg: 640x640 44 space-emptys, 85 space-occupieds, Done. (0.012s)
# image 65/1242 /content/test/images/2012-09-17_16_19_16_jpg.rf.b64a60153ff343c955ec354a95657a69.jpg: 640x640 28 space-emptys, 84 space-occupieds, Done. (0.012s)
# image 66/1242 /content/test/images/2012-09-17_16_29_16_jpg.rf.58c9eb48425e935d07bd9afbe67823a9.jpg: 640x640 30 space-emptys, 83 space-occupieds, Done. (0.012s)
# image 67/1242 /content/test/images/2012-09-17_17_59_20_jpg.rf.018c0e89285f202f26dd49282bc598a6.jpg: 640x640 39 space-emptys, 76 space-occupieds, Done. (0.014s)
# image 68/1242 /content/test/images/2012-09-18_05_54_47_jpg.rf.76eb7d6cf9642582011d36744b94349d.jpg: 640x640 101 space-emptys, 2 space-occupieds, Done. (0.013s)
# image 69/1242 /content/test/images/2012-09-18_06_59_50_jpg.rf.a4aa48b48111d30265f039ac6a9db512.jpg: 640x640 100 space-emptys, 7 space-occupieds, Done. (0.012s)
# image 70/1242 /content/test/images/2012-09-18_07_24_51_jpg.rf.2f5369a91b64090b303bd4ec6c67dc96.jpg: 640x640 85 space-emptys, 19 space-occupieds, Done. (0.012s)
# image 71/1242 /content/test/images/2012-09-18_08_24_53_jpg.rf.4ac192da73cca67c81ff736b9ad92131.jpg: 640x640 12 space-emptys, 100 space-occupieds, Done. (0.012s)
# image 72/1242 /content/test/images/2012-09-18_09_29_56_jpg.rf.6374b39c744746ffdc252cf5e4063b8f.jpg: 640x640 12 space-emptys, 98 space-occupieds, Done. (0.013s)
# image 73/1242 /content/test/images/2012-09-18_09_39_57_jpg.rf.a4fa6a02578c79978b0c1a0010b8016b.jpg: 640x640 13 space-emptys, 96 space-occupieds, Done. (0.012s)
# image 74/1242 /content/test/images/2012-09-18_10_24_59_jpg.rf.781324f4645c6e8bf0b4bdbc8f41d657.jpg: 640x640 14 space-emptys, 100 space-occupieds, Done. (0.012s)
# image 75/1242 /content/test/images/2012-09-18_10_39_59_jpg.rf.d81db51a291d1129cc3cef7ebf514e8a.jpg: 640x640 16 space-emptys, 101 space-occupieds, Done. (0.012s)
# image 76/1242 /content/test/images/2012-09-18_10_45_00_jpg.rf.80031e2e2ddb96518db1a431204fc77d.jpg: 640x640 15 space-emptys, 105 space-occupieds, Done. (0.012s)
# image 77/1242 /content/test/images/2012-09-18_11_20_01_jpg.rf.5fd82a7e9658371deb0142c8c4f0f088.jpg: 640x640 31 space-emptys, 88 space-occupieds, Done. (0.012s)
# image 78/1242 /content/test/images/2012-09-18_11_25_01_jpg.rf.fddcbb78aac993220111369d8dd8c5db.jpg: 640x640 33 space-emptys, 88 space-occupieds, Done. (0.012s)
# image 79/1242 /content/test/images/2012-09-18_11_50_03_jpg.rf.283e4a59fccc5209039a076f0920edc2.jpg: 640x640 58 space-emptys, 67 space-occupieds, Done. (0.012s)
# image 80/1242 /content/test/images/2012-09-18_12_35_04_jpg.rf.854104452c86fa676498969fbb0b252e.jpg: 640x640 73 space-emptys, 41 space-occupieds, Done. (0.012s)
# image 81/1242 /content/test/images/2012-09-18_13_40_07_jpg.rf.c18cd85b25b56429ee268598b2564c8a.jpg: 640x640 62 space-emptys, 53 space-occupieds, Done. (0.012s)
# image 82/1242 /content/test/images/2012-09-18_14_25_09_jpg.rf.d7ae716726f07d466c49666187843651.jpg: 640x640 51 space-emptys, 68 space-occupieds, Done. (0.012s)
# image 83/1242 /content/test/images/2012-09-18_15_10_11_jpg.rf.66a439b06d6b6f2ca9768282f075e366.jpg: 640x640 42 space-emptys, 75 space-occupieds, Done. (0.012s)
# image 84/1242 /content/test/images/2012-09-18_15_25_12_jpg.rf.66adfb175ef02d31c983fda00494686b.jpg: 640x640 43 space-emptys, 74 space-occupieds, Done. (0.014s)
# image 85/1242 /content/test/images/2012-09-18_16_05_14_jpg.rf.d801ab3675fa600ad71c0d30cdf340f9.jpg: 640x640 40 space-emptys, 77 space-occupieds, Done. (0.012s)
# image 86/1242 /content/test/images/2012-09-18_16_45_16_jpg.rf.10fb46c9ae07ea13945e9dda43e77cc0.jpg: 640x640 43 space-emptys, 77 space-occupieds, Done. (0.012s)
# image 87/1242 /content/test/images/2012-09-18_17_10_17_jpg.rf.9737176450f2af6f772763bc20fa1ae2.jpg: 640x640 42 space-emptys, 73 space-occupieds, Done. (0.012s)
# image 88/1242 /content/test/images/2012-09-18_17_45_19_jpg.rf.995b961787645f49a883f9e5270d79bc.jpg: 640x640 48 space-emptys, 74 space-occupieds, Done. (0.012s)
# image 89/1242 /content/test/images/2012-09-18_17_50_19_jpg.rf.f1179b5312ea0ebae3e27a0d635b3b7b.jpg: 640x640 41 space-emptys, 77 space-occupieds, Done. (0.012s)
# image 90/1242 /content/test/images/2012-09-19_08_10_53_jpg.rf.a37e4b4b4a0ed916c010141ab8f31a12.jpg: 640x640 14 space-emptys, 101 space-occupieds, Done. (0.013s)
# image 91/1242 /content/test/images/2012-09-19_09_18_25_jpg.rf.7dcc621b05d2e89d66f5929aface56d4.jpg: 640x640 13 space-emptys, 112 space-occupieds, Done. (0.012s)
# image 92/1242 /content/test/images/2012-09-19_11_03_30_jpg.rf.1a099e262606ad2b19079fefa6e0b2ce.jpg: 640x640 21 space-emptys, 99 space-occupieds, Done. (0.012s)
# image 93/1242 /content/test/images/2012-09-19_11_13_30_jpg.rf.de75e761f1ccb66e3fb0c88ce1edad52.jpg: 640x640 30 space-emptys, 87 space-occupieds, Done. (0.012s)
# image 94/1242 /content/test/images/2012-09-19_12_13_33_jpg.rf.44df18ec102fc1b76929b9bfd066c678.jpg: 640x640 62 space-emptys, 53 space-occupieds, Done. (0.012s)
# image 95/1242 /content/test/images/2012-09-19_12_28_33_jpg.rf.1792f8f7c17101cec646c1adca8b886b.jpg: 640x640 70 space-emptys, 50 space-occupieds, Done. (0.012s)
# image 96/1242 /content/test/images/2012-09-19_12_53_34_jpg.rf.a8cf1e178f452a2dff7096b55a955cb0.jpg: 640x640 74 space-emptys, 48 space-occupieds, Done. (0.012s)
# image 97/1242 /content/test/images/2012-09-19_12_58_35_jpg.rf.a5adb54ddd5417b79a1ed0cab4e9e3a0.jpg: 640x640 73 space-emptys, 50 space-occupieds, Done. (0.012s)
# image 98/1242 /content/test/images/2012-09-19_13_03_35_jpg.rf.235f0b0ccd3f43d2b51e47e226217162.jpg: 640x640 74 space-emptys, 48 space-occupieds, Done. (0.012s)
# image 99/1242 /content/test/images/2012-09-19_13_13_35_jpg.rf.a81bf6420e6147cd9c441c6dde128dd2.jpg: 640x640 76 space-emptys, 49 space-occupieds, Done. (0.012s)
# image 100/1242 /content/test/images/2012-09-19_15_08_40_jpg.rf.45d4c71f3caccc363b0deeb5d87899ca.jpg: 640x640 37 space-emptys, 90 space-occupieds, Done. (0.012s)
# image 101/1242 /content/test/images/2012-09-19_15_53_42_jpg.rf.9fb617e57331ab527b30cca98bc92fac.jpg: 640x640 31 space-emptys, 90 space-occupieds, Done. (0.012s)
# image 102/1242 /content/test/images/2012-09-19_16_38_44_jpg.rf.ebf24466f264c1ad61c4bbf9616e9e04.jpg: 640x640 29 space-emptys, 91 space-occupieds, Done. (0.012s)
# image 103/1242 /content/test/images/2012-09-19_17_23_46_jpg.rf.c4e1a59b541a1ffc54e59c2f961ee042.jpg: 640x640 37 space-emptys, 83 space-occupieds, Done. (0.012s)
# image 104/1242 /content/test/images/2012-09-19_18_03_47_jpg.rf.20e356fd2ca8a699629d2a45d20f56bb.jpg: 640x640 43 space-emptys, 67 space-occupieds, Done. (0.012s)
# image 105/1242 /content/test/images/2012-09-20_07_54_18_jpg.rf.38bb40e59726cae985498264813dd63c.jpg: 640x640 26 space-emptys, 95 space-occupieds, Done. (0.013s)
# image 106/1242 /content/test/images/2012-09-20_07_59_18_jpg.rf.49adc24e94dcbceb4a9bd9bd172fe08e.jpg: 640x640 25 space-emptys, 106 space-occupieds, Done. (0.012s)
# image 107/1242 /content/test/images/2012-09-20_09_24_22_jpg.rf.954343036c855f0de3f87ae45d26a485.jpg: 640x640 11 space-emptys, 101 space-occupieds, Done. (0.012s)
# image 108/1242 /content/test/images/2012-09-20_09_39_23_jpg.rf.e24465975d14ee5e1345b6d6bd68cb18.jpg: 640x640 8 space-emptys, 106 space-occupieds, Done. (0.012s)
# image 109/1242 /content/test/images/2012-09-20_12_24_30_jpg.rf.6a92f5435897a0018e960fdedab3b1cb.jpg: 640x640 68 space-emptys, 58 space-occupieds, Done. (0.012s)
# image 110/1242 /content/test/images/2012-09-20_13_39_34_jpg.rf.05bccd3b9c1d3caf2bc99daef40ea35d.jpg: 640x640 74 space-emptys, 57 space-occupieds, Done. (0.012s)
# image 111/1242 /content/test/images/2012-09-20_16_44_41_jpg.rf.888d1105f91b958bf5440a6b2143bbae.jpg: 640x640 34 space-emptys, 79 space-occupieds, Done. (0.012s)
# image 112/1242 /content/test/images/2012-09-20_17_29_43_jpg.rf.628570c262193307c079d1724bda9b9a.jpg: 640x640 40 space-emptys, 81 space-occupieds, Done. (0.012s)
# image 113/1242 /content/test/images/2012-09-20_17_59_44_jpg.rf.514a3df4c863dad73a00622369a33be8.jpg: 640x640 40 space-emptys, 71 space-occupieds, Done. (0.013s)
# image 114/1242 /content/test/images/2012-09-21_06_15_11_jpg.rf.700d0875e6e6d882425c713f1f28e44c.jpg: 640x640 115 space-emptys, 1 space-occupieds, Done. (0.013s)
# image 115/1242 /content/test/images/2012-09-21_06_35_11_jpg.rf.b3120831351aab32cfea10c9060af5aa.jpg: 640x640 112 space-emptys, 2 space-occupieds, Done. (0.012s)
# image 116/1242 /content/test/images/2012-09-21_06_50_12_jpg.rf.0463225607a4bde17be0d7e1e1170b8a.jpg: 640x640 110 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 117/1242 /content/test/images/2012-09-21_06_55_12_jpg.rf.213989fcc67713273acccba3ea99b15e.jpg: 640x640 110 space-emptys, 6 space-occupieds, Done. (0.012s)
# image 118/1242 /content/test/images/2012-09-21_07_00_12_jpg.rf.a6c7c2f39f77399ac675f280c5dcf082.jpg: 640x640 107 space-emptys, 5 space-occupieds, Done. (0.012s)
# image 119/1242 /content/test/images/2012-09-21_07_05_12_jpg.rf.1e88fe4eb85dccdf7ce28b7a4cc361d7.jpg: 640x640 106 space-emptys, 8 space-occupieds, Done. (0.012s)
# image 120/1242 /content/test/images/2012-09-21_07_20_13_jpg.rf.0606b43f93ed03f40e1b4504cf41d7be.jpg: 640x640 101 space-emptys, 14 space-occupieds, Done. (0.012s)
# image 121/1242 /content/test/images/2012-09-21_08_50_17_jpg.rf.ef2de236b70843d39646ab1045814947.jpg: 640x640 13 space-emptys, 117 space-occupieds, Done. (0.013s)
# image 122/1242 /content/test/images/2012-09-21_09_20_18_jpg.rf.8534c023f43191b92630246a973aa21a.jpg: 640x640 10 space-emptys, 121 space-occupieds, Done. (0.012s)
# image 123/1242 /content/test/images/2012-09-21_10_55_23_jpg.rf.fd886036d67d6715e34221c45a1722f5.jpg: 640x640 17 space-emptys, 103 space-occupieds, Done. (0.012s)
# image 124/1242 /content/test/images/2012-09-21_12_00_25_jpg.rf.19f0f1aa5edf9890d53a5ccf098f1ccb.jpg: 640x640 48 space-emptys, 70 space-occupieds, Done. (0.012s)
# image 125/1242 /content/test/images/2012-09-21_12_20_26_jpg.rf.f241bb96499221557548412f4cff2352.jpg: 640x640 61 space-emptys, 61 space-occupieds, Done. (0.012s)
# image 126/1242 /content/test/images/2012-09-21_13_30_28_jpg.rf.2d3b19e6ea3c0127239f2ed548b5cbf1.jpg: 640x640 73 space-emptys, 46 space-occupieds, Done. (0.012s)
# image 127/1242 /content/test/images/2012-09-21_14_55_32_jpg.rf.933cba9d4351e13cb04dbe7e32ca141c.jpg: 640x640 54 space-emptys, 73 space-occupieds, Done. (0.012s)
# image 128/1242 /content/test/images/2012-09-21_15_25_34_jpg.rf.534ee4423c51d30a279fbc5a01cdabc7.jpg: 640x640 54 space-emptys, 72 space-occupieds, Done. (0.012s)
# image 129/1242 /content/test/images/2012-09-21_16_25_36_jpg.rf.b723b2e9dad8cc6a55982d814f352e5f.jpg: 640x640 46 space-emptys, 70 space-occupieds, Done. (0.012s)
# image 130/1242 /content/test/images/2012-09-21_16_30_37_jpg.rf.f6a23ddf8854497c9d599a1bc4b03a99.jpg: 640x640 43 space-emptys, 69 space-occupieds, Done. (0.012s)
# image 131/1242 /content/test/images/2012-09-28_05_45_56_jpg.rf.a693ba02421f35af137d833bcfe1c1eb.jpg: 640x640 110 space-emptys, Done. (0.012s)
# image 132/1242 /content/test/images/2012-09-28_06_00_57_jpg.rf.415f3ccb15acd5dd2d4e28a14805769e.jpg: 640x640 111 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 133/1242 /content/test/images/2012-09-28_06_10_58_jpg.rf.088027df8679e2e21deac1217d9ed309.jpg: 640x640 110 space-emptys, 1 space-occupieds, Done. (0.013s)
# image 134/1242 /content/test/images/2012-09-28_08_01_02_jpg.rf.32faef3763d8f23e1030add2fb0573cf.jpg: 640x640 41 space-emptys, 85 space-occupieds, Done. (0.012s)
# image 135/1242 /content/test/images/2012-09-28_08_11_03_jpg.rf.ac5912fc2a47b22e98b22f6badb2c4a3.jpg: 640x640 26 space-emptys, 98 space-occupieds, Done. (0.013s)
# image 136/1242 /content/test/images/2012-09-28_09_01_05_jpg.rf.b7c69a2ea5afdd2d74543c41ad7cfa87.jpg: 640x640 11 space-emptys, 115 space-occupieds, Done. (0.012s)
# image 137/1242 /content/test/images/2012-09-28_09_56_08_jpg.rf.1c46c5327e69500853ebee34eab9b780.jpg: 640x640 5 space-emptys, 120 space-occupieds, Done. (0.012s)
# image 138/1242 /content/test/images/2012-09-28_10_11_09_jpg.rf.792ab6f8bef371e9ee380ec8d235290d.jpg: 640x640 9 space-emptys, 109 space-occupieds, Done. (0.013s)
# image 139/1242 /content/test/images/2012-09-28_10_46_10_jpg.rf.f334f1580cb54365ea3a3692dd2442f8.jpg: 640x640 16 space-emptys, 101 space-occupieds, Done. (0.013s)
# image 140/1242 /content/test/images/2012-09-28_11_11_12_jpg.rf.82217b133927d0ea403b37789de22298.jpg: 640x640 23 space-emptys, 96 space-occupieds, Done. (0.013s)
# image 141/1242 /content/test/images/2012-09-28_11_21_12_jpg.rf.a9f0d294bcb6b2190fd712a19745bd5f.jpg: 640x640 31 space-emptys, 91 space-occupieds, Done. (0.012s)
# image 142/1242 /content/test/images/2012-09-28_12_01_14_jpg.rf.b6da01ba8c400d6c2e9485b2403452b5.jpg: 640x640 52 space-emptys, 67 space-occupieds, Done. (0.012s)
# image 143/1242 /content/test/images/2012-09-28_15_51_24_jpg.rf.0d609dc3950234e10a1d535952e97ec0.jpg: 640x640 45 space-emptys, 76 space-occupieds, Done. (0.012s)
# image 144/1242 /content/test/images/2012-09-28_17_01_27_jpg.rf.4815770c6a127114432aa712129f6563.jpg: 640x640 46 space-emptys, 76 space-occupieds, Done. (0.012s)
# image 145/1242 /content/test/images/2012-09-28_17_36_29_jpg.rf.807fb3bf81520a7a5773912ed44e6cb1.jpg: 640x640 58 space-emptys, 61 space-occupieds, Done. (0.013s)
# image 146/1242 /content/test/images/2012-09-29_06_52_04_jpg.rf.b183c585a1c7ee47fd6eda18e3f49eb9.jpg: 640x640 111 space-emptys, Done. (0.012s)
# image 147/1242 /content/test/images/2012-10-05_08_37_50_jpg.rf.1c2fabd4119cb0ea2b032a3287c6f445.jpg: 640x640 13 space-emptys, 110 space-occupieds, Done. (0.012s)
# image 148/1242 /content/test/images/2012-10-11_07_46_49_jpg.rf.33c2e7f8accebcdcafec151bccf266cb.jpg: 640x640 72 space-emptys, 44 space-occupieds, Done. (0.012s)
# image 149/1242 /content/test/images/2012-10-11_07_57_00_jpg.rf.9f49b8221834c83a12232b8f7a40cc73.jpg: 640x640 55 space-emptys, 65 space-occupieds, Done. (0.012s)
# image 150/1242 /content/test/images/2012-10-11_07_57_32_jpg.rf.4768949839782414d46bcbb5aec561bc.jpg: 640x640 53 space-emptys, 66 space-occupieds, Done. (0.012s)
# image 151/1242 /content/test/images/2012-10-11_07_59_35_jpg.rf.78c814f04eb292f91ce1391f606f276a.jpg: 640x640 51 space-emptys, 70 space-occupieds, Done. (0.012s)
# image 152/1242 /content/test/images/2012-10-11_08_00_49_jpg.rf.28ae831b30ea3e1dbf4d38cf8401af49.jpg: 640x640 47 space-emptys, 76 space-occupieds, Done. (0.012s)
# image 153/1242 /content/test/images/2012-10-11_08_16_32_jpg.rf.85c0dc2d8b217b8a75da617fbb973d8f.jpg: 640x640 25 space-emptys, 100 space-occupieds, Done. (0.012s)
# image 154/1242 /content/test/images/2012-10-11_08_51_34_jpg.rf.6f3d919846a6aee30318150f96a6610f.jpg: 640x640 7 space-emptys, 110 space-occupieds, Done. (0.012s)
# image 155/1242 /content/test/images/2012-10-11_09_01_34_jpg.rf.e3bcda671ae03da23aacf902df72fc51.jpg: 640x640 5 space-emptys, 115 space-occupieds, Done. (0.012s)
# image 156/1242 /content/test/images/2012-10-11_09_26_35_jpg.rf.25bf9f5a7263ceb120d19007faa7e9a1.jpg: 640x640 4 space-emptys, 108 space-occupieds, Done. (0.012s)
# image 157/1242 /content/test/images/2012-10-11_09_51_36_jpg.rf.063d03d59ec965d7a48d88b7b8c55d04.jpg: 640x640 8 space-emptys, 105 space-occupieds, Done. (0.012s)
# image 158/1242 /content/test/images/2012-10-11_10_41_39_jpg.rf.77020a5b23daa16a675cd4e987014059.jpg: 640x640 8 space-emptys, 105 space-occupieds, Done. (0.012s)
# image 159/1242 /content/test/images/2012-10-11_11_46_42_jpg.rf.df4c0a164dbdae15310e0adc60e1b4e3.jpg: 640x640 37 space-emptys, 80 space-occupieds, Done. (0.012s)
# image 160/1242 /content/test/images/2012-10-11_13_16_46_jpg.rf.fde06f001616ac8b938c0836ebe6b783.jpg: 640x640 64 space-emptys, 48 space-occupieds, Done. (0.012s)
# image 161/1242 /content/test/images/2012-10-11_14_06_48_jpg.rf.9aca9555e2bb7f815e73d11a35a864aa.jpg: 640x640 42 space-emptys, 72 space-occupieds, Done. (0.012s)
# image 162/1242 /content/test/images/2012-10-11_14_11_48_jpg.rf.e797dad403bcaeced64eafbb2af5f20b.jpg: 640x640 43 space-emptys, 73 space-occupieds, Done. (0.012s)
# image 163/1242 /content/test/images/2012-10-11_14_41_49_jpg.rf.97e3afb413d4bc0497144266daab5cfb.jpg: 640x640 38 space-emptys, 80 space-occupieds, Done. (0.012s)
# image 164/1242 /content/test/images/2012-10-11_15_31_51_jpg.rf.7bf6cac0d0e087af74752bf1409ba700.jpg: 640x640 37 space-emptys, 76 space-occupieds, Done. (0.013s)
# image 165/1242 /content/test/images/2012-10-11_15_56_52_jpg.rf.1eee10edeb26b77d6a9c0ba55cc7abf6.jpg: 640x640 37 space-emptys, 77 space-occupieds, Done. (0.012s)
# image 166/1242 /content/test/images/2012-10-11_16_01_52_jpg.rf.8b291a13e7076442bb6f73698cc93dc2.jpg: 640x640 36 space-emptys, 80 space-occupieds, Done. (0.012s)
# image 167/1242 /content/test/images/2012-10-11_16_26_53_jpg.rf.da7784becca9dc8190194e9516c3d08c.jpg: 640x640 38 space-emptys, 76 space-occupieds, Done. (0.012s)
# image 168/1242 /content/test/images/2012-10-11_17_16_55_jpg.rf.cff6929ba1732a13b5d57e0045fd07ee.jpg: 640x640 57 space-emptys, 64 space-occupieds, Done. (0.012s)
# image 169/1242 /content/test/images/2012-10-11_17_51_57_jpg.rf.bbaf1bee4b30bcf99fe70258977ba8b8.jpg: 640x640 72 space-emptys, 49 space-occupieds, Done. (0.013s)
# image 170/1242 /content/test/images/2012-10-11_17_56_57_jpg.rf.8c325b5fa2c876230c9d816a33138306.jpg: 640x640 73 space-emptys, 49 space-occupieds, Done. (0.012s)
# image 171/1242 /content/test/images/2012-10-11_18_01_57_jpg.rf.c3dd87e290b5c26eac656a5b503aadba.jpg: 640x640 74 space-emptys, 45 space-occupieds, Done. (0.012s)
# image 172/1242 /content/test/images/2012-10-11_18_16_58_jpg.rf.066c08f71501c9fb38a9a73d692973e6.jpg: 640x640 82 space-emptys, 37 space-occupieds, Done. (0.012s)
# image 173/1242 /content/test/images/2012-10-12_06_32_31_jpg.rf.2ca1726244819abb9e6f5d204f666a62.jpg: 640x640 113 space-emptys, Done. (0.012s)
# image 174/1242 /content/test/images/2012-10-12_07_57_34_jpg.rf.9a6ecbe717d3892f9dbc32a012ee2009.jpg: 640x640 109 space-emptys, Done. (0.012s)
# image 175/1242 /content/test/images/2012-10-12_09_02_37_jpg.rf.7060b426e1d5293a5eb8446489e17900.jpg: 640x640 117 space-emptys, Done. (0.013s)
# image 176/1242 /content/test/images/2012-10-12_09_22_38_jpg.rf.0fa76b753d3876d9eb8690682deb5ad5.jpg: 640x640 120 space-emptys, Done. (0.012s)
# image 177/1242 /content/test/images/2012-10-12_09_32_39_jpg.rf.1425590a48e2082a0e1dc4d7348926d7.jpg: 640x640 119 space-emptys, Done. (0.012s)
# image 178/1242 /content/test/images/2012-10-12_09_52_40_jpg.rf.f930ea375021f39b88a3d10cf26973fb.jpg: 640x640 118 space-emptys, Done. (0.012s)
# image 179/1242 /content/test/images/2012-10-12_10_12_41_jpg.rf.43daec581cff81cf2c21808720505c33.jpg: 640x640 116 space-emptys, Done. (0.012s)
# image 180/1242 /content/test/images/2012-10-12_11_47_45_jpg.rf.bb956df5e3a000d4f46cf29b674cb634.jpg: 640x640 117 space-emptys, Done. (0.012s)
# image 181/1242 /content/test/images/2012-10-12_11_57_45_jpg.rf.f376b3cf69c52c39b3919b57e624f8a7.jpg: 640x640 114 space-emptys, Done. (0.012s)
# image 182/1242 /content/test/images/2012-10-12_12_52_47_jpg.rf.9f49b600e5fcddfc815c3edd2a2bfe6a.jpg: 640x640 115 space-emptys, Done. (0.012s)
# image 183/1242 /content/test/images/2012-10-12_13_22_49_jpg.rf.aa1830a35eb581b2a865b61d6e050157.jpg: 640x640 123 space-emptys, Done. (0.013s)
# image 184/1242 /content/test/images/2012-10-12_14_32_52_jpg.rf.fe45c95e1238dd9a120bf3fbc5651723.jpg: 640x640 119 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 185/1242 /content/test/images/2012-10-12_15_07_54_jpg.rf.c28ab85783ac5691f474d59ed68d417e.jpg: 640x640 122 space-emptys, Done. (0.013s)
# image 186/1242 /content/test/images/2012-10-12_16_52_57_jpg.rf.1d6b16a14bb29ce490b564ca1ba7ddd1.jpg: 640x640 123 space-emptys, 2 space-occupieds, Done. (0.012s)
# image 187/1242 /content/test/images/2012-10-12_16_57_58_jpg.rf.0f483e1ad98677f979fd2b8a89740ab8.jpg: 640x640 120 space-emptys, 1 space-occupieds, Done. (0.013s)
# image 188/1242 /content/test/images/2012-10-12_17_12_58_jpg.rf.df960d7edb22e78b7ddb68dda2e07239.jpg: 640x640 120 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 189/1242 /content/test/images/2012-10-13_05_38_33_jpg.rf.2fcb04a388870d58a2f2f1aa313ec3cd.jpg: 640x640 116 space-emptys, Done. (0.012s)
# image 190/1242 /content/test/images/2012-10-13_06_13_34_jpg.rf.ed7636345afb35c528f862aea60ba5af.jpg: 640x640 110 space-emptys, Done. (0.012s)
# image 191/1242 /content/test/images/2012-10-13_07_13_37_jpg.rf.1364bcf566bf8ac82ad19daaa37d7d77.jpg: 640x640 116 space-emptys, Done. (0.012s)
# image 192/1242 /content/test/images/2012-10-13_07_23_37_jpg.rf.945dc6ca68f2111c2acf8f2c4f946238.jpg: 640x640 113 space-emptys, Done. (0.012s)
# image 193/1242 /content/test/images/2012-10-13_08_33_40_jpg.rf.9ca392a2904063535674d50a7c2dbf5e.jpg: 640x640 116 space-emptys, Done. (0.012s)
# image 194/1242 /content/test/images/2012-10-13_08_58_41_jpg.rf.f2bd2e862fdf97647e5a6948adde3e8a.jpg: 640x640 116 space-emptys, Done. (0.013s)
# image 195/1242 /content/test/images/2012-10-13_09_48_43_jpg.rf.94a1151d06eb270cfe39469abf780ef6.jpg: 640x640 121 space-emptys, Done. (0.012s)
# image 196/1242 /content/test/images/2012-10-13_13_18_51_jpg.rf.3c44234aa3e81e9912fd37bd1b431cf6.jpg: 640x640 117 space-emptys, 1 space-occupieds, Done. (0.015s)
# image 197/1242 /content/test/images/2012-10-13_13_48_53_jpg.rf.5b8f69148bce71c61c03c8e386fed855.jpg: 640x640 118 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 198/1242 /content/test/images/2012-10-13_14_08_54_jpg.rf.d6354a6f6ec896dc26bd855ce624097f.jpg: 640x640 121 space-emptys, 1 space-occupieds, Done. (0.013s)
# image 199/1242 /content/test/images/2012-10-13_15_08_56_jpg.rf.f3bf8e222a8d8e3ae8fa47a9f85c6a08.jpg: 640x640 117 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 200/1242 /content/test/images/2012-10-13_15_48_58_jpg.rf.c524936e6dcd98f5cb2dea0a394bfe96.jpg: 640x640 115 space-emptys, 1 space-occupieds, Done. (0.013s)
# image 201/1242 /content/test/images/2012-10-13_16_54_01_jpg.rf.447fa1971bec543e562b43d75643b867.jpg: 640x640 118 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 202/1242 /content/test/images/2012-10-14_05_59_35_jpg.rf.715c12876416871c9360b6095378a2c4.jpg: 640x640 121 space-emptys, Done. (0.012s)
# image 203/1242 /content/test/images/2012-10-14_07_59_40_jpg.rf.a8c766746259efd266c1d5415abf57d6.jpg: 640x640 122 space-emptys, Done. (0.012s)
# image 204/1242 /content/test/images/2012-10-14_08_04_41_jpg.rf.b1e4bdf1bf1f2fa4fdf1fa71e2343745.jpg: 640x640 122 space-emptys, Done. (0.012s)
# image 205/1242 /content/test/images/2012-10-14_08_29_42_jpg.rf.7f266332895d7e80d5c5565636a53e42.jpg: 640x640 126 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 206/1242 /content/test/images/2012-10-14_08_39_42_jpg.rf.2e5990fb202d657b520d787d8fdbce0d.jpg: 640x640 122 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 207/1242 /content/test/images/2012-10-14_08_49_43_jpg.rf.2bc18c494d3c27b7c7cf05ed90f9497f.jpg: 640x640 123 space-emptys, Done. (0.013s)
# image 208/1242 /content/test/images/2012-10-14_09_14_44_jpg.rf.b1aba9c10ec25bbbfc50a21980013088.jpg: 640x640 117 space-emptys, Done. (0.012s)
# image 209/1242 /content/test/images/2012-10-14_09_29_44_jpg.rf.eb6e5c6e3747bd8267830cfd275de24b.jpg: 640x640 119 space-emptys, Done. (0.012s)
# image 210/1242 /content/test/images/2012-10-14_09_34_45_jpg.rf.7f0fc027e4438eb1f12696e7622cee4d.jpg: 640x640 117 space-emptys, Done. (0.012s)
# image 211/1242 /content/test/images/2012-10-14_10_29_47_jpg.rf.2cd2abecc3a5920657ea9d1a9c8773f9.jpg: 640x640 121 space-emptys, Done. (0.012s)
# image 212/1242 /content/test/images/2012-10-14_11_39_50_jpg.rf.7681ec43f38cc9c6243f691747728de5.jpg: 640x640 118 space-emptys, 1 space-occupieds, Done. (0.016s)
# image 213/1242 /content/test/images/2012-10-14_12_14_52_jpg.rf.e94b373e9d1854df25225eaf57c4c004.jpg: 640x640 119 space-emptys, Done. (0.012s)
# image 214/1242 /content/test/images/2012-10-14_12_59_54_jpg.rf.22d1c70f8723c62336d3a279224e3c06.jpg: 640x640 121 space-emptys, Done. (0.012s)
# image 215/1242 /content/test/images/2012-10-14_13_14_54_jpg.rf.c4e49f412ed0ec80d1076e3bd0415ca0.jpg: 640x640 123 space-emptys, Done. (0.012s)
# image 216/1242 /content/test/images/2012-10-14_13_34_55_jpg.rf.96af6ddfc9f2746abafdeb7131bc8b9f.jpg: 640x640 119 space-emptys, Done. (0.012s)
# image 217/1242 /content/test/images/2012-10-14_14_34_58_jpg.rf.b1ff27b02156f0aa8ab037491c4871b3.jpg: 640x640 114 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 218/1242 /content/test/images/2012-10-14_16_20_02_jpg.rf.54c1c58390e97f94fafaa1a081e4bcad.jpg: 640x640 115 space-emptys, 2 space-occupieds, Done. (0.012s)
# image 219/1242 /content/test/images/2012-10-14_16_25_03_jpg.rf.c009f1eb8e102e3882416988d7470368.jpg: 640x640 119 space-emptys, 2 space-occupieds, Done. (0.012s)
# image 220/1242 /content/test/images/2012-10-14_16_55_04_jpg.rf.4d671fb5875e07d25f45c5aaae711d2a.jpg: 640x640 119 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 221/1242 /content/test/images/2012-10-14_18_05_07_jpg.rf.f578ef8650d0a19584205fc31561ceba.jpg: 640x640 120 space-emptys, Done. (0.012s)
# image 222/1242 /content/test/images/2012-10-14_18_15_08_jpg.rf.13271cfa0bed8eeb70db1eebeea1b5d2.jpg: 640x640 123 space-emptys, Done. (0.012s)
# image 223/1242 /content/test/images/2012-10-15_07_10_43_jpg.rf.3d63420facffc9d28e4109601f00d39a.jpg: 640x640 106 space-emptys, Done. (0.012s)
# image 224/1242 /content/test/images/2012-10-15_07_30_44_jpg.rf.594a29ea7be03c7f9d6888ad944f88e5.jpg: 640x640 112 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 225/1242 /content/test/images/2012-10-15_08_50_48_jpg.rf.93c31daf50b0345c382f47e1c5f4b61d.jpg: 640x640 112 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 226/1242 /content/test/images/2012-10-15_08_55_48_jpg.rf.bbea7d89afa8ec14fb3135103715edfe.jpg: 640x640 109 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 227/1242 /content/test/images/2012-10-15_12_50_58_jpg.rf.618c04e66630667980beead686ee6ace.jpg: 640x640 119 space-emptys, 4 space-occupieds, Done. (0.013s)
# image 228/1242 /content/test/images/2012-10-15_16_16_06_jpg.rf.582a7d3fcc9d643b37d3533f3ff0ece2.jpg: 640x640 104 space-emptys, 5 space-occupieds, Done. (0.012s)
# image 229/1242 /content/test/images/2012-10-15_16_31_07_jpg.rf.f4fef9487619f691346250679c30898f.jpg: 640x640 104 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 230/1242 /content/test/images/2012-10-15_16_46_07_jpg.rf.eda4b11852aac06131e7c792d3de8226.jpg: 640x640 111 space-emptys, 5 space-occupieds, Done. (0.012s)
# image 231/1242 /content/test/images/2012-10-15_16_51_07_jpg.rf.605640f5d4b27091741d3b2ee2cec401.jpg: 640x640 109 space-emptys, 6 space-occupieds, Done. (0.013s)
# image 232/1242 /content/test/images/2012-10-15_17_16_09_jpg.rf.b512f277ed8803e51cdc1ccc2519dee9.jpg: 640x640 109 space-emptys, 4 space-occupieds, Done. (0.012s)
# image 233/1242 /content/test/images/2012-10-15_17_21_09_jpg.rf.73c378d16468d1e30fbf5b074f5c6151.jpg: 640x640 116 space-emptys, 5 space-occupieds, Done. (0.012s)
# image 234/1242 /content/test/images/2012-10-16_06_06_43_jpg.rf.e0eb9df27376c7cad56c0adc41760d37.jpg: 640x640 113 space-emptys, 2 space-occupieds, Done. (0.012s)
# image 235/1242 /content/test/images/2012-10-16_10_53_34_jpg.rf.853c37badf68065821bebf54b256167a.jpg: 640x640 17 space-emptys, 105 space-occupieds, Done. (0.012s)
# image 236/1242 /content/test/images/2012-10-16_11_23_35_jpg.rf.459436fe8bf0e9f13478fd2466da2d02.jpg: 640x640 32 space-emptys, 89 space-occupieds, Done. (0.012s)
# image 237/1242 /content/test/images/2012-10-16_11_43_37_jpg.rf.22327ebbbb6c13c9f9a9ad1d18fd4129.jpg: 640x640 40 space-emptys, 80 space-occupieds, Done. (0.012s)
# image 238/1242 /content/test/images/2012-10-16_12_48_39_jpg.rf.a2b959834a005488963a7044283c4ecf.jpg: 640x640 77 space-emptys, 49 space-occupieds, Done. (0.012s)
# image 239/1242 /content/test/images/2012-10-16_14_43_45_jpg.rf.0e0b80aee0be9b5515292116438750f6.jpg: 640x640 46 space-emptys, 76 space-occupieds, Done. (0.013s)
# image 240/1242 /content/test/images/2012-10-16_15_58_49_jpg.rf.5129b28ea012f9a5e1f6d43d62b69edc.jpg: 640x640 39 space-emptys, 78 space-occupieds, Done. (0.012s)
# image 241/1242 /content/test/images/2012-10-16_16_53_52_jpg.rf.11dd50055c725984c74909c634c25193.jpg: 640x640 42 space-emptys, 78 space-occupieds, Done. (0.012s)
# image 242/1242 /content/test/images/2012-10-17_06_14_31_jpg.rf.2b8ce26d3e794e8b4b96caef6507f7dc.jpg: 640x640 102 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 243/1242 /content/test/images/2012-10-17_06_29_32_jpg.rf.69e19a64e8812f2313542bb66c2eb537.jpg: 640x640 100 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 244/1242 /content/test/images/2012-10-17_08_34_38_jpg.rf.00872f80c0883729955f0df9dd126653.jpg: 640x640 13 space-emptys, 99 space-occupieds, Done. (0.012s)
# image 245/1242 /content/test/images/2012-10-17_08_39_38_jpg.rf.6545f15878f43315e63f4af3351e8951.jpg: 640x640 7 space-emptys, 99 space-occupieds, Done. (0.012s)
# image 246/1242 /content/test/images/2012-10-17_10_04_42_jpg.rf.390bf6a8eed36b06cf04c55bdb67999b.jpg: 640x640 9 space-emptys, 112 space-occupieds, Done. (0.012s)
# image 247/1242 /content/test/images/2012-10-17_10_14_43_jpg.rf.050566b083dedc47b4efa5ef726e1d0b.jpg: 640x640 6 space-emptys, 112 space-occupieds, Done. (0.012s)
# image 248/1242 /content/test/images/2012-10-23_08_25_51_jpg.rf.1da68f1dd8720018fcd2bc11db730feb.jpg: 640x640 15 space-emptys, 115 space-occupieds, Done. (0.012s)
# image 249/1242 /content/test/images/2012-10-25_09_33_23_jpg.rf.978a13460b34709b20a0b51c786a201c.jpg: 640x640 6 space-emptys, 119 space-occupieds, Done. (0.012s)
# image 250/1242 /content/test/images/2012-10-25_10_28_26_jpg.rf.bde4f6c2971d4ad45db10adaab221149.jpg: 640x640 10 space-emptys, 115 space-occupieds, Done. (0.012s)
# image 251/1242 /content/test/images/2012-10-25_11_13_28_jpg.rf.9c68f6131e6266c2d9656edd06048636.jpg: 640x640 15 space-emptys, 98 space-occupieds, Done. (0.012s)
# image 252/1242 /content/test/images/2012-10-25_11_28_29_jpg.rf.8d548b09450972d8d07521aeed3c1c57.jpg: 640x640 35 space-emptys, 91 space-occupieds, Done. (0.015s)
# image 253/1242 /content/test/images/2012-10-25_11_48_30_jpg.rf.05a22e56c83a81d3dd21a6e0cbec6896.jpg: 640x640 43 space-emptys, 81 space-occupieds, Done. (0.012s)
# image 254/1242 /content/test/images/2012-10-25_11_58_30_jpg.rf.d50176558af8e4560f65f0290d107e06.jpg: 640x640 50 space-emptys, 70 space-occupieds, Done. (0.012s)
# image 255/1242 /content/test/images/2012-10-25_12_23_32_jpg.rf.1b221b0a4b9aae3296c26888bd6e5316.jpg: 640x640 66 space-emptys, 56 space-occupieds, Done. (0.012s)
# image 256/1242 /content/test/images/2012-10-25_12_28_32_jpg.rf.fd7f7ffb395e20d71bc41af2a398efd2.jpg: 640x640 63 space-emptys, 54 space-occupieds, Done. (0.012s)
# image 257/1242 /content/test/images/2012-10-25_13_58_36_jpg.rf.7b3024aff83beba84fdadcc981243485.jpg: 640x640 54 space-emptys, 69 space-occupieds, Done. (0.013s)
# image 258/1242 /content/test/images/2012-10-25_14_13_37_jpg.rf.b05e78944572a1d307003d0f02476eda.jpg: 640x640 46 space-emptys, 74 space-occupieds, Done. (0.013s)
# image 259/1242 /content/test/images/2012-10-25_14_23_37_jpg.rf.0877c9694b106d2931ab1e191b46fe25.jpg: 640x640 41 space-emptys, 79 space-occupieds, Done. (0.012s)
# image 260/1242 /content/test/images/2012-10-25_15_18_40_jpg.rf.2d0701c9eda2c4fc88085e267634fa72.jpg: 640x640 32 space-emptys, 85 space-occupieds, Done. (0.012s)
# image 261/1242 /content/test/images/2012-10-25_16_28_44_jpg.rf.a344e2e475e43daeadabbc9508c933ec.jpg: 640x640 34 space-emptys, 83 space-occupieds, Done. (0.012s)
# image 262/1242 /content/test/images/2012-10-25_16_43_45_jpg.rf.ecf9b7747958dfe8c543143a7c3b3353.jpg: 640x640 41 space-emptys, 84 space-occupieds, Done. (0.012s)
# image 263/1242 /content/test/images/2012-10-25_17_33_48_jpg.rf.6f438681750dfda15519d50a1b271cb1.jpg: 640x640 40 space-emptys, 76 space-occupieds, Done. (0.012s)
# image 264/1242 /content/test/images/2012-10-25_17_38_48_jpg.rf.347496fbdd1e5b3416df9ba74233bfa0.jpg: 640x640 42 space-emptys, 76 space-occupieds, Done. (0.012s)
# image 265/1242 /content/test/images/2012-10-25_19_03_53_jpg.rf.2d6fafdc004a8ab83ae5489c4e1535cf.jpg: 640x640 109 space-occupieds, Done. (0.014s)
# image 266/1242 /content/test/images/2012-10-25_19_13_53_jpg.rf.42e3c38c0adbf466d0d241b15c4df5c8.jpg: 640x640 1 space-emptys, 107 space-occupieds, Done. (0.012s)
# image 267/1242 /content/test/images/2012-10-25_19_38_54_jpg.rf.f0ba9798e4fd4c97a791ef6e65bb4176.jpg: 640x640 5 space-emptys, 103 space-occupieds, Done. (0.012s)
# image 268/1242 /content/test/images/2012-10-26_07_04_26_jpg.rf.d4504d56713883e1c40fa7d314ed5ad6.jpg: 640x640 99 space-emptys, 14 space-occupieds, Done. (0.012s)
# image 269/1242 /content/test/images/2012-10-26_07_29_28_jpg.rf.b0a958c2d5e8126d6020ac7a0f743b06.jpg: 640x640 94 space-emptys, 24 space-occupieds, Done. (0.012s)
# image 270/1242 /content/test/images/2012-10-26_08_44_31_jpg.rf.f6e4d9413376d44b0d9b50ffd7482781.jpg: 640x640 10 space-emptys, 120 space-occupieds, Done. (0.012s)
# image 271/1242 /content/test/images/2012-10-26_09_39_35_jpg.rf.7d0fd549135e37245f54f5a495f9bc17.jpg: 640x640 6 space-emptys, 121 space-occupieds, Done. (0.012s)
# image 272/1242 /content/test/images/2012-10-26_11_19_40_jpg.rf.e78f116506c3630269b51c11ceed7883.jpg: 640x640 16 space-emptys, 107 space-occupieds, Done. (0.012s)
# image 273/1242 /content/test/images/2012-10-26_11_29_40_jpg.rf.4b09c9c47a0033751d7945c70b7b7ac5.jpg: 640x640 16 space-emptys, 104 space-occupieds, Done. (0.012s)
# image 274/1242 /content/test/images/2012-10-26_11_34_40_jpg.rf.0ed29fedbbc253bd3338ab98d1ab3f1e.jpg: 640x640 20 space-emptys, 103 space-occupieds, Done. (0.012s)
# image 275/1242 /content/test/images/2012-10-26_11_39_41_jpg.rf.88504eb418890ff5c66eee80bbe37b5f.jpg: 640x640 20 space-emptys, 98 space-occupieds, Done. (0.012s)
# image 276/1242 /content/test/images/2012-10-26_12_04_42_jpg.rf.06b453a7a9b397befa948df3afc59276.jpg: 640x640 43 space-emptys, 80 space-occupieds, Done. (0.012s)
# image 277/1242 /content/test/images/2012-10-26_12_24_43_jpg.rf.a71e59708cce1c39a3627bfa71116ab3.jpg: 640x640 57 space-emptys, 68 space-occupieds, Done. (0.013s)
# image 278/1242 /content/test/images/2012-10-26_15_29_53_jpg.rf.080942f76e62b38d02f04a745f6b9d15.jpg: 640x640 30 space-emptys, 92 space-occupieds, Done. (0.012s)
# image 279/1242 /content/test/images/2012-10-26_16_39_56_jpg.rf.704d4caa082bb8fe691ab66f3190b1d8.jpg: 640x640 34 space-emptys, 80 space-occupieds, Done. (0.012s)
# image 280/1242 /content/test/images/2012-10-26_17_39_59_jpg.rf.dffd35b85f996b9a2a713687490d1ea5.jpg: 640x640 62 space-emptys, 58 space-occupieds, Done. (0.012s)
# image 281/1242 /content/test/images/2012-10-26_17_55_00_jpg.rf.c2a41f1973924ceaa32c0e4b07db851b.jpg: 640x640 81 space-emptys, 41 space-occupieds, Done. (0.012s)
# image 282/1242 /content/test/images/2012-10-26_18_20_01_jpg.rf.435febee32c6e9c7157059b34bcf4540.jpg: 640x640 70 space-emptys, 47 space-occupieds, Done. (0.013s)
# image 283/1242 /content/test/images/2012-10-26_19_05_03_jpg.rf.1fed94c1c70cdca4c21f40121c22e104.jpg: 640x640 7 space-emptys, 119 space-occupieds, Done. (0.012s)
# image 284/1242 /content/test/images/2012-10-27_08_05_40_jpg.rf.d855285c2dadb0ef3a0afbe74e6d5ba3.jpg: 640x640 106 space-emptys, 1 space-occupieds, Done. (0.013s)
# image 285/1242 /content/test/images/2012-10-27_08_10_40_jpg.rf.4528ba4a84529ddb0adaf5a7e7604d96.jpg: 640x640 103 space-emptys, 2 space-occupieds, Done. (0.012s)
# image 286/1242 /content/test/images/2012-10-27_08_40_42_jpg.rf.151afdf377329446aa16b89489d7d930.jpg: 640x640 99 space-emptys, 10 space-occupieds, Done. (0.012s)
# image 287/1242 /content/test/images/2012-10-27_09_30_44_jpg.rf.e43c648c4b14c608b378b67dbdd86b48.jpg: 640x640 86 space-emptys, 27 space-occupieds, Done. (0.012s)
# image 288/1242 /content/test/images/2012-10-27_10_15_47_jpg.rf.1e6bfc573be307a82a63e98399307da3.jpg: 640x640 75 space-emptys, 53 space-occupieds, Done. (0.013s)
# image 289/1242 /content/test/images/2012-10-27_11_00_49_jpg.rf.229fb671ec16af21b738eb6eae7d2120.jpg: 640x640 63 space-emptys, 53 space-occupieds, Done. (0.014s)
# image 290/1242 /content/test/images/2012-10-27_11_20_51_jpg.rf.60a0ae931f753b09d50d0e8e7496e791.jpg: 640x640 75 space-emptys, 49 space-occupieds, Done. (0.012s)
# image 291/1242 /content/test/images/2012-10-27_12_10_53_jpg.rf.5c8c86f11bbde7ae5f2af8bce1640d88.jpg: 640x640 85 space-emptys, 30 space-occupieds, Done. (0.013s)
# image 292/1242 /content/test/images/2012-10-27_12_25_54_jpg.rf.40746d12ef772d8c06e962ea2282682c.jpg: 640x640 90 space-emptys, 25 space-occupieds, Done. (0.012s)
# image 293/1242 /content/test/images/2012-10-27_12_35_54_jpg.rf.a3ce6e96ee71791d26f16e498c6da5c2.jpg: 640x640 97 space-emptys, 23 space-occupieds, Done. (0.012s)
# image 294/1242 /content/test/images/2012-10-27_13_15_56_jpg.rf.a775a1540cff316ce13090212e969f2e.jpg: 640x640 100 space-emptys, 23 space-occupieds, Done. (0.012s)
# image 295/1242 /content/test/images/2012-10-27_13_30_57_jpg.rf.c355a91bd431a0f7c3ace2d76a9598a9.jpg: 640x640 104 space-emptys, 23 space-occupieds, Done. (0.012s)
# image 296/1242 /content/test/images/2012-10-27_16_06_05_jpg.rf.3765e79dd13719f555282aafa366c658.jpg: 640x640 106 space-emptys, 20 space-occupieds, Done. (0.012s)
# image 297/1242 /content/test/images/2012-10-27_16_36_06_jpg.rf.d1bba6a67e969eff0767cdc62305e7c5.jpg: 640x640 103 space-emptys, 17 space-occupieds, Done. (0.012s)
# image 298/1242 /content/test/images/2012-10-27_17_31_09_jpg.rf.58680a1891a8be8d085f7ca6e2516eee.jpg: 640x640 108 space-emptys, 9 space-occupieds, Done. (0.012s)
# image 299/1242 /content/test/images/2012-10-27_18_41_13_jpg.rf.262adbf3d01ef6975d2e0b824f10fcce.jpg: 640x640 118 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 300/1242 /content/test/images/2012-10-28_07_31_48_jpg.rf.80404ecbe8d30ec4a8795c8c92518da5.jpg: 640x640 118 space-emptys, 1 space-occupieds, Done. (0.012s)
# ...
# image 1143/1242 /content/test/images/2013-04-09_07_30_01_jpg.rf.72eee91817dff9a6c3c67e4669e912cb.jpg: 640x640 33 space-emptys, 10 space-occupieds, Done. (0.012s)
# image 1144/1242 /content/test/images/2013-04-09_08_05_02_jpg.rf.5e61ad74b931969d8ca246e4e1af2314.jpg: 640x640 20 space-emptys, 27 space-occupieds, Done. (0.012s)
# image 1145/1242 /content/test/images/2013-04-09_09_15_03_jpg.rf.8598661ded5366d19d13de2d672b0f67.jpg: 640x640 1 space-emptys, 43 space-occupieds, Done. (0.012s)
# image 1146/1242 /content/test/images/2013-04-09_09_40_04_jpg.rf.47bb5b2c8af5a6e6c26a315966eded63.jpg: 640x640 42 space-occupieds, Done. (0.012s)
# image 1147/1242 /content/test/images/2013-04-09_10_30_05_jpg.rf.7f18436427d92d540e16f50d0748a65d.jpg: 640x640 43 space-occupieds, Done. (0.012s)
# image 1148/1242 /content/test/images/2013-04-09_11_00_05_jpg.rf.adef326ba2b9bede4c6c639d68059219.jpg: 640x640 41 space-occupieds, Done. (0.012s)
# image 1149/1242 /content/test/images/2013-04-09_11_35_06_jpg.rf.93229bc18e11e41364444c5089446446.jpg: 640x640 2 space-emptys, 40 space-occupieds, Done. (0.012s)
# image 1150/1242 /content/test/images/2013-04-09_12_15_07_jpg.rf.8e33d293086d8f2c3a6802c7de7dd5cb.jpg: 640x640 8 space-emptys, 36 space-occupieds, Done. (0.012s)
# image 1151/1242 /content/test/images/2013-04-09_12_35_07_jpg.rf.4fb2f0dafdb2e2bfa50c9e4ddcecc807.jpg: 640x640 10 space-emptys, 33 space-occupieds, Done. (0.012s)
# image 1152/1242 /content/test/images/2013-04-09_12_45_07_jpg.rf.c966117b6079e080142dbaa4f46dd3ac.jpg: 640x640 7 space-emptys, 35 space-occupieds, Done. (0.012s)
# image 1153/1242 /content/test/images/2013-04-09_13_25_08_jpg.rf.252c6080caa8d984c45b15bc0dbd657a.jpg: 640x640 1 space-emptys, 43 space-occupieds, Done. (0.012s)
# image 1154/1242 /content/test/images/2013-04-09_13_50_09_jpg.rf.e4723158b3c68280929e37f7253304e8.jpg: 640x640 2 space-emptys, 41 space-occupieds, Done. (0.012s)
# image 1155/1242 /content/test/images/2013-04-09_14_00_09_jpg.rf.ae22ea94681aa8bc151070052ef64600.jpg: 640x640 1 space-emptys, 41 space-occupieds, Done. (0.012s)
# image 1156/1242 /content/test/images/2013-04-09_16_40_12_jpg.rf.bb602e055019dc202d4b628b1970e8bc.jpg: 640x640 7 space-emptys, 40 space-occupieds, Done. (0.012s)
# image 1157/1242 /content/test/images/2013-04-09_17_55_13_jpg.rf.bca65860faa496fc9f7559e5d1041306.jpg: 640x640 8 space-emptys, 36 space-occupieds, Done. (0.012s)
# image 1158/1242 /content/test/images/2013-04-10_06_50_00_jpg.rf.e2aee577e87a93b3b5d2e53963c93028.jpg: 640x640 41 space-emptys, Done. (0.012s)
# image 1159/1242 /content/test/images/2013-04-10_07_05_01_jpg.rf.0459cfef0efabbe1d47edb012b5f9d98.jpg: 640x640 40 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 1160/1242 /content/test/images/2013-04-10_08_30_02_jpg.rf.d708f66b0f79eaac8a72585e2734ad94.jpg: 640x640 15 space-emptys, 30 space-occupieds, Done. (0.012s)
# image 1161/1242 /content/test/images/2013-04-10_08_40_03_jpg.rf.8a27ba1af56bccbfce9c92ad45a2130b.jpg: 640x640 11 space-emptys, 34 space-occupieds, Done. (0.012s)
# image 1162/1242 /content/test/images/2013-04-10_10_25_04_jpg.rf.cb4bcf753197051bd70d5395d534407e.jpg: 640x640 1 space-emptys, 41 space-occupieds, Done. (0.012s)
# image 1163/1242 /content/test/images/2013-04-10_10_55_05_jpg.rf.bc7366a055dffaca341b57cb3310dfd9.jpg: 640x640 1 space-emptys, 41 space-occupieds, Done. (0.012s)
# image 1164/1242 /content/test/images/2013-04-10_11_10_05_jpg.rf.4d69761e3745225c78c1bc86ec52df05.jpg: 640x640 42 space-occupieds, Done. (0.012s)
# image 1165/1242 /content/test/images/2013-04-10_13_25_08_jpg.rf.51ba86d7dee38758b7c95f38b59f1aed.jpg: 640x640 10 space-emptys, 32 space-occupieds, Done. (0.012s)
# image 1166/1242 /content/test/images/2013-04-10_13_35_08_jpg.rf.c6be0deac61d5db1e0322bb1ca48db70.jpg: 640x640 8 space-emptys, 36 space-occupieds, Done. (0.012s)
# image 1167/1242 /content/test/images/2013-04-10_13_55_08_jpg.rf.bb837be4b2658161dd56cce6ad59291a.jpg: 640x640 1 space-emptys, 42 space-occupieds, Done. (0.012s)
# image 1168/1242 /content/test/images/2013-04-10_14_05_09_jpg.rf.05d7fe204368d141e1cfb79afb610c84.jpg: 640x640 42 space-occupieds, Done. (0.012s)
# image 1169/1242 /content/test/images/2013-04-10_14_15_09_jpg.rf.32d5b21f0712e1dc7073dde88a78a6c7.jpg: 640x640 43 space-occupieds, Done. (0.012s)
# image 1170/1242 /content/test/images/2013-04-10_18_10_13_jpg.rf.a8ffcaa2e72f0a8abae05cbcaac7806e.jpg: 640x640 7 space-emptys, 35 space-occupieds, Done. (0.012s)
# image 1171/1242 /content/test/images/2013-04-11_06_25_00_jpg.rf.fde77b8ff9150e5e20c1b39f36b625d7.jpg: 640x640 40 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 1172/1242 /content/test/images/2013-04-11_06_55_01_jpg.rf.b8150f41c7eeb0daa555269432a01d0c.jpg: 640x640 39 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 1173/1242 /content/test/images/2013-04-11_07_50_02_jpg.rf.5762104573f59d2456f8ff99e0408ab7.jpg: 640x640 31 space-emptys, 16 space-occupieds, Done. (0.012s)
# image 1174/1242 /content/test/images/2013-04-11_08_45_03_jpg.rf.a068c5182adf55c98eeb2b44b7d4befb.jpg: 640x640 11 space-emptys, 34 space-occupieds, Done. (0.012s)
# image 1175/1242 /content/test/images/2013-04-11_09_25_03_jpg.rf.dbc9ff5b4a4bc97e867736d570f295ab.jpg: 640x640 2 space-emptys, 43 space-occupieds, Done. (0.012s)
# image 1176/1242 /content/test/images/2013-04-11_10_00_04_jpg.rf.a011647c5d38e30b15c3525480643387.jpg: 640x640 1 space-emptys, 43 space-occupieds, Done. (0.012s)
# image 1177/1242 /content/test/images/2013-04-11_10_40_05_jpg.rf.049e486719f30f1a5f8600940fe31708.jpg: 640x640 1 space-emptys, 41 space-occupieds, Done. (0.012s)
# image 1178/1242 /content/test/images/2013-04-11_10_55_05_jpg.rf.8f005b7af4eb925ea385df26100bf5b7.jpg: 640x640 2 space-emptys, 41 space-occupieds, Done. (0.012s)
# image 1179/1242 /content/test/images/2013-04-11_11_05_05_jpg.rf.282b7c8ccecbd8582dcaf9fc1b9d35a8.jpg: 640x640 2 space-emptys, 42 space-occupieds, Done. (0.012s)
# image 1180/1242 /content/test/images/2013-04-11_11_45_06_jpg.rf.6212987299570f080e2c7cc32b44e875.jpg: 640x640 2 space-emptys, 42 space-occupieds, Done. (0.012s)
# image 1181/1242 /content/test/images/2013-04-11_12_10_06_jpg.rf.bec6295f2ecc75256b558ff8af0310a2.jpg: 640x640 6 space-emptys, 36 space-occupieds, Done. (0.012s)
# image 1182/1242 /content/test/images/2013-04-11_14_25_09_jpg.rf.6eb5a17e33a0f82aac7b93e8f9d20529.jpg: 640x640 3 space-emptys, 42 space-occupieds, Done. (0.013s)
# image 1183/1242 /content/test/images/2013-04-11_17_40_12_jpg.rf.a186a5a2b31d89dbebb61a50c40cd1f8.jpg: 640x640 7 space-emptys, 34 space-occupieds, Done. (0.012s)
# image 1184/1242 /content/test/images/2013-04-12_07_05_01_jpg.rf.2a2758527f2e45cb2ee09241faf31857.jpg: 640x640 40 space-emptys, 1 space-occupieds, Done. (0.013s)
# image 1185/1242 /content/test/images/2013-04-12_08_55_03_jpg.rf.aadff07004b934d88b9b3c0c343c352c.jpg: 640x640 19 space-emptys, 22 space-occupieds, Done. (0.012s)
# image 1186/1242 /content/test/images/2013-04-12_09_35_03_jpg.rf.667074d7017cce2de0911bb5620fd7af.jpg: 640x640 7 space-emptys, 35 space-occupieds, Done. (0.012s)
# image 1187/1242 /content/test/images/2013-04-12_10_35_05_jpg.rf.8c6af22727dacf5e82e7e3da54c77eae.jpg: 640x640 1 space-emptys, 43 space-occupieds, Done. (0.012s)
# image 1188/1242 /content/test/images/2013-04-12_10_45_05_jpg.rf.67e06005163b1a8fe2fef3959f65079f.jpg: 640x640 2 space-emptys, 40 space-occupieds, Done. (0.014s)
# image 1189/1242 /content/test/images/2013-04-12_11_35_06_jpg.rf.b8de8edb49a3ee510508b8b6eec76f35.jpg: 640x640 5 space-emptys, 35 space-occupieds, Done. (0.012s)
# image 1190/1242 /content/test/images/2013-04-12_11_40_06_jpg.rf.f4ad58d9daa00f5073fb678d2ff5608a.jpg: 640x640 3 space-emptys, 39 space-occupieds, Done. (0.012s)
# image 1191/1242 /content/test/images/2013-04-12_13_35_08_jpg.rf.2877efd86d0bb23a94d89247cd29453d.jpg: 640x640 12 space-emptys, 30 space-occupieds, Done. (0.012s)
# image 1192/1242 /content/test/images/2013-04-12_14_50_09_jpg.rf.d69d34ca657c3e71f40e86afc6bb60bd.jpg: 640x640 41 space-occupieds, Done. (0.012s)
# image 1193/1242 /content/test/images/2013-04-12_16_00_11_jpg.rf.72ca39f1a58ea032a5a562fbe1e023e2.jpg: 640x640 1 space-emptys, 44 space-occupieds, Done. (0.012s)
# image 1194/1242 /content/test/images/2013-04-12_16_50_11_jpg.rf.98ef03829219fa72b4189a7c83c72221.jpg: 640x640 7 space-emptys, 35 space-occupieds, Done. (0.012s)
# image 1195/1242 /content/test/images/2013-04-13_06_50_01_jpg.rf.7079b749e3a86ff2ac97f2ce4e78dde7.jpg: 640x640 42 space-emptys, Done. (0.012s)
# image 1196/1242 /content/test/images/2013-04-13_07_50_02_jpg.rf.94fc534af0b1ad1545bac78170fc2e9c.jpg: 640x640 41 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 1197/1242 /content/test/images/2013-04-13_07_55_02_jpg.rf.79510b1b1d01038cd8c31d9dd5da383e.jpg: 640x640 42 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 1198/1242 /content/test/images/2013-04-13_08_15_02_jpg.rf.fa430415ad55aa8599b7b21ff9a59b57.jpg: 640x640 41 space-emptys, Done. (0.012s)
# image 1199/1242 /content/test/images/2013-04-13_09_25_03_jpg.rf.b437e5e2f00b2657dff2d163ce917f6f.jpg: 640x640 39 space-emptys, 3 space-occupieds, Done. (0.013s)
# image 1200/1242 /content/test/images/2013-04-13_09_30_04_jpg.rf.d3367628a075cfafd282e09704ecc90f.jpg: 640x640 39 space-emptys, 3 space-occupieds, Done. (0.012s)
# image 1201/1242 /content/test/images/2013-04-13_12_45_07_jpg.rf.77bc06610f9505ff5c12084eb1d899b7.jpg: 640x640 26 space-emptys, 17 space-occupieds, Done. (0.012s)
# image 1202/1242 /content/test/images/2013-04-13_13_55_08_jpg.rf.470f2e1cf90628183df1436ae7c94ea4.jpg: 640x640 26 space-emptys, 16 space-occupieds, Done. (0.012s)
# image 1203/1242 /content/test/images/2013-04-13_14_25_09_jpg.rf.efd95bf253aa2227d5b6319996e2f29c.jpg: 640x640 27 space-emptys, 17 space-occupieds, Done. (0.012s)
# image 1204/1242 /content/test/images/2013-04-13_15_45_10_jpg.rf.8104b61bca969f2dcce0bb97b1b7332c.jpg: 640x640 33 space-emptys, 10 space-occupieds, Done. (0.012s)
# image 1205/1242 /content/test/images/2013-04-13_15_55_11_jpg.rf.b588072a1c82cb29e0aaac12940f3a56.jpg: 640x640 32 space-emptys, 9 space-occupieds, Done. (0.012s)
# image 1206/1242 /content/test/images/2013-04-13_16_00_11_jpg.rf.78debadccfda2f36ccd1fb34fdbdcbf0.jpg: 640x640 32 space-emptys, 9 space-occupieds, Done. (0.012s)
# image 1207/1242 /content/test/images/2013-04-13_16_35_11_jpg.rf.026a0ff9a9709d43b386b884e3dd93d8.jpg: 640x640 34 space-emptys, 10 space-occupieds, Done. (0.012s)
# image 1208/1242 /content/test/images/2013-04-13_17_25_12_jpg.rf.112d13762db80e6546817a41e03e34d9.jpg: 640x640 35 space-emptys, 7 space-occupieds, Done. (0.013s)
# image 1209/1242 /content/test/images/2013-04-13_17_45_13_jpg.rf.186e7a6b927c306bfcd445dd1a02ef85.jpg: 640x640 34 space-emptys, 7 space-occupieds, Done. (0.012s)
# image 1210/1242 /content/test/images/2013-04-14_07_00_01_jpg.rf.1d067535321ee030a1c04d54b46c63d1.jpg: 640x640 41 space-emptys, Done. (0.012s)
# image 1211/1242 /content/test/images/2013-04-14_07_35_01_jpg.rf.7a249550b6a2eb0e1e26974b4df738a6.jpg: 640x640 41 space-emptys, Done. (0.012s)
# image 1212/1242 /content/test/images/2013-04-14_08_10_02_jpg.rf.4172d0cbf0a58f4eb1c3fff83aa23253.jpg: 640x640 41 space-emptys, 1 space-occupieds, Done. (0.012s)
# image 1213/1242 /content/test/images/2013-04-14_08_45_03_jpg.rf.1fcc3a8ab847be33f17474b5737c8bf4.jpg: 640x640 39 space-emptys, 4 space-occupieds, Done. (0.012s)
# image 1214/1242 /content/test/images/2013-04-14_09_15_03_jpg.rf.dee10bd50b2adcb0138461946ef427c7.jpg: 640x640 33 space-emptys, 10 space-occupieds, Done. (0.012s)
# image 1215/1242 /content/test/images/2013-04-14_13_05_07_jpg.rf.9c5a93058fc857e00c75096adf70c1f0.jpg: 640x640 18 space-emptys, 23 space-occupieds, Done. (0.012s)
# image 1216/1242 /content/test/images/2013-04-14_13_40_08_jpg.rf.73806c83468062b4d7bbbf3bba554d41.jpg: 640x640 16 space-emptys, 25 space-occupieds, Done. (0.012s)
# image 1217/1242 /content/test/images/2013-04-14_14_10_09_jpg.rf.aca94975b9f24b5d917787ea12ca5ea2.jpg: 640x640 15 space-emptys, 27 space-occupieds, Done. (0.012s)
# image 1218/1242 /content/test/images/2013-04-14_14_25_09_jpg.rf.ef7b9a917fe372d76d1cab6c7ea783fa.jpg: 640x640 15 space-emptys, 27 space-occupieds, Done. (0.012s)
# image 1219/1242 /content/test/images/2013-04-14_15_35_10_jpg.rf.df52b7799e9ae4a469f67d121b0f45ab.jpg: 640x640 17 space-emptys, 27 space-occupieds, Done. (0.012s)
# image 1220/1242 /content/test/images/2013-04-14_16_40_11_jpg.rf.060aa1de0576ed19b0f96505df27aa72.jpg: 640x640 18 space-emptys, 31 space-occupieds, Done. (0.013s)
# image 1221/1242 /content/test/images/2013-04-14_17_25_12_jpg.rf.a1709842e4fddfc544b9aec2eadec498.jpg: 640x640 12 space-emptys, 30 space-occupieds, Done. (0.012s)
# image 1222/1242 /content/test/images/2013-04-14_17_45_12_jpg.rf.bf64a5cec46ad24af1550885dc39a71f.jpg: 640x640 15 space-emptys, 28 space-occupieds, Done. (0.012s)
# image 1223/1242 /content/test/images/2013-04-15_07_05_01_jpg.rf.b9971ea7737a3afd8030350e8ea6d3b9.jpg: 640x640 33 space-emptys, 10 space-occupieds, Done. (0.012s)
# image 1224/1242 /content/test/images/2013-04-15_07_25_01_jpg.rf.0b9308d366b5eeac7be3c36ce6251470.jpg: 640x640 8 space-emptys, 39 space-occupieds, Done. (0.012s)
# image 1225/1242 /content/test/images/2013-04-15_07_40_02_jpg.rf.55bf21277d91ae4a092f6584eb4c4df4.jpg: 640x640 6 space-emptys, 40 space-occupieds, Done. (0.012s)
# image 1226/1242 /content/test/images/2013-04-15_07_55_02_jpg.rf.9cd7f1cbdacc12134d24f09e83978f05.jpg: 640x640 7 space-emptys, 40 space-occupieds, Done. (0.012s)
# image 1227/1242 /content/test/images/2013-04-15_08_00_02_jpg.rf.0b280d820f0c62cb390cbe794148cad6.jpg: 640x640 7 space-emptys, 43 space-occupieds, Done. (0.012s)
# image 1228/1242 /content/test/images/2013-04-15_08_45_03_jpg.rf.a1e72e71ab3eeb2addf3ccdbb4a49d61.jpg: 640x640 1 space-emptys, 42 space-occupieds, Done. (0.012s)
# image 1229/1242 /content/test/images/2013-04-15_08_50_03_jpg.rf.fba29ba5ed7fe50daf28c3315835dfa5.jpg: 640x640 6 space-emptys, 43 space-occupieds, Done. (0.012s)
# image 1230/1242 /content/test/images/2013-04-15_09_05_03_jpg.rf.11f9ff6dcfc851de9b780af804b1ef3d.jpg: 640x640 4 space-emptys, 45 space-occupieds, Done. (0.012s)
# image 1231/1242 /content/test/images/2013-04-15_09_45_04_jpg.rf.71e89b75dda3edd053e8e2d25bb48186.jpg: 640x640 1 space-emptys, 42 space-occupieds, Done. (0.012s)
# image 1232/1242 /content/test/images/2013-04-15_11_35_06_jpg.rf.99f9158f9a33130447fa1830165fb43c.jpg: 640x640 9 space-emptys, 33 space-occupieds, Done. (0.012s)
# image 1233/1242 /content/test/images/2013-04-15_12_25_07_jpg.rf.2eb06de03e1671ee8ae93e57fe35b39e.jpg: 640x640 9 space-emptys, 31 space-occupieds, Done. (0.012s)
# image 1234/1242 /content/test/images/2013-04-15_15_00_09_jpg.rf.4d41bba54bc641aba21a52f64a94d89d.jpg: 640x640 5 space-emptys, 37 space-occupieds, Done. (0.013s)
# image 1235/1242 /content/test/images/2013-04-15_15_40_10_jpg.rf.d72fe528f0ef2bd7d77df37119a06632.jpg: 640x640 9 space-emptys, 37 space-occupieds, Done. (0.013s)
# image 1236/1242 /content/test/images/2013-04-15_15_45_10_jpg.rf.61d41dc83eb05c3832f9315f8a40c2c8.jpg: 640x640 7 space-emptys, 37 space-occupieds, Done. (0.012s)
# image 1237/1242 /content/test/images/2013-04-15_15_55_10_jpg.rf.e32ca978d229733d98535a5ddefb1623.jpg: 640x640 7 space-emptys, 38 space-occupieds, Done. (0.012s)
# image 1238/1242 /content/test/images/2013-04-15_17_20_12_jpg.rf.645df113036e52e572510730e7d84235.jpg: 640x640 12 space-emptys, 28 space-occupieds, Done. (0.012s)
# image 1239/1242 /content/test/images/2013-04-15_17_40_12_jpg.rf.a6d4f6f69f8320b5fa04170ecbff8d5a.jpg: 640x640 10 space-emptys, 32 space-occupieds, Done. (0.012s)
# image 1240/1242 /content/test/images/2013-04-15_18_00_13_jpg.rf.a81662bde9d55256a28a145c46770be3.jpg: 640x640 15 space-emptys, 28 space-occupieds, Done. (0.012s)
# image 1241/1242 /content/test/images/2013-04-16_10_05_04_jpg.rf.1b2b800b350cffd72a24ade7f8485d52.jpg: 640x640 3 space-emptys, 40 space-occupieds, Done. (0.012s)
# image 1242/1242 /content/test/images/2013-04-16_10_20_04_jpg.rf.cf2eeba0fef298a616a157669246fabe.jpg: 640x640 3 space-emptys, 42 space-occupieds, Done. (0.012s)
# Results saved to runs/detect/exp2
# Done. (71.726s)

# %%
#display inference on ALL test images
#this looks much better with longer training above

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp2/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Export Trained Weights for Future Inference
#
# Now that you have trained your custom detector, you can export the trained weights you have made here for inference on your device elsewhere

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cp /content/yolov5/runs/exp0_yolov5s_results/weights/best.pt /content/gdrive/My\ Drive

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !!python detect.py --weights yolov5s.pt --img 320 --conf 0.20 --source ../images/
# Out:
# ["Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.2, device='', exist_ok=False, img_size=320, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../images/', update=False, view_img=False, weights=['yolov5s.pt'])",
#  'Using torch 1.7.0+cu101 CUDA:0 (Tesla K80, 11441MB)',
#  '',
#  'Fusing layers... ',
#  'Model Summary: 232 layers, 7459581 parameters, 0 gradients',
#  'image 1/6 /content/images/c1.jpg: 224x320 1 spoons, 1 bowls, 1 sandwichs, 1 cakes, 2 dining tables, Done. (0.027s)',
#  'image 2/6 /content/images/c2.jpg: 256x320 1 cakes, Done. (0.022s)',
#  'image 3/6 /content/images/m1.jpg: 320x320 1 donuts, Done. (0.022s)',
#  'image 4/6 /content/images/m2.jpg: 256x320 1 bowls, 1 dining tables, Done. (0.022s)',
#  'image 5/6 /content/images/s3.jpg: 192x320 1 sandwichs, Done. (0.022s)',
#  'image 6/6 /content/images/s4.jpg: 224x320 2 hot dogs, 1 dining tables, Done. (0.022s)',
#  'Results saved to runs/detect/exp7',
#  'Done. (0.248s)']

# %% [markdown]
# ## Congrats!
#
# Hope you enjoyed this!
#
# --Team [Roboflow](https://roboflow.ai)
